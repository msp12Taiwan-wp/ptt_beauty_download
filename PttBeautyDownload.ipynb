# %%
# -*- coding: MS950 -*-
import unittest
from PttWebCrawler.crawler import *
import codecs, json, os
from imgurdownloader import *
import re,os

# %%
FROM=2340
FOLDER="newDownload"
TO=2300

# %%
def get_articles(index):
    c = PttWebCrawler(as_lib=True)
    t=c.parse_articles(index,index, 'beauty')
    return (t)

# %%
def get_contents(t):
    with open(t, 'r',encoding = 'utf8') as f:
        data=json.load(f)
    contents=[]
    titles=[]
    article_id=[]
    for article in data['articles']:
        contents.append(article['content'])
        titles.append(article['article_title'])
        article_id.append(article['article_id'])
    print(article_id[1:5])
    return(contents,titles,article_id)

# %%
def download_urls(urls,article_id,index,article_num,folder):
    j=0
    for url in urls:
        if url.startswith(('https://i.imgur','http://i.imgur','https://imgur','http://imgur')):# or url.startswith('http://imgur') or url.startswith('https://imgur') or url.startswith('http://i.imgur'):
            filename=str(index)+"_"+str(article_num)+"_"+str(j)
            print("Processing image:",filename,url)
            downloader = ImgurDownloader(url,FOLDER,filename)
            if (not os.path.exists(folder+"/"+filename+".jpg")) and (not os.path.exists(folder+"/"+filename+".png")):
                downloader.on_image_download(downloader.save_images())
                print("save",filename)
            else:
                print(filename,"already exist")
    j=j+1

# %%
INDEX=FROM
while(INDEX>TO):
    t=".\\beauty-"+str(INDEX)+"-"+str(INDEX)+".json"
    if not os.path.exists(t):
        t=get_articles(INDEX)
    contents,titles,article_id=get_contents(t)
    i=0
    for content in contents:
        if titles[i].startswith('[正妹]'):
            urls = re.findall('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', content)
            print("start article:",titles[i])
            download_urls(urls,article_id,INDEX,i,FOLDER)
        i=i+1
    INDEX=INDEX-1
    if INDEX!=FROM:
        os.remove(t)
# Out:
# Processing index: 2340
# Processing article: M.1513251655.A.F79
# Processing article: M.1513252164.A.691
# Processing article: M.1513253550.A.21C
# Processing article: M.1513255883.A.B1A
# Processing article: M.1513261968.A.0A1
# Processing article: M.1513263825.A.7BB
# Processing article: M.1513264213.A.AD0
# Processing article: M.1513298679.A.7B9
# Processing article: M.1513299168.A.45B
# Processing article: M.1513307844.A.6C6
# Processing article: M.1513310408.A.77C
# Processing article: M.1513312315.A.26C
# Processing article: M.1513317377.A.713
# Processing article: M.1513321140.A.0BE
# Processing article: M.1513327218.A.B70
# Processing article: M.1513327872.A.521
# Processing article: M.1513342023.A.935
# Processing article: M.1513344385.A.EDC
# Processing article: M.1513345647.A.AEF
# Processing article: M.1513350673.A.3CD
# ['M.1513252164.A.691', 'M.1513253550.A.21C', 'M.1513255883.A.B1A', 'M.1513261968.A.0A1']
# start article: [正妹] 2張
# Processing image: 2340_0_0 https://i.imgur.com/46osbvP.jpg
# 2340_0_0 already exist
# Processing image: 2340_0_0 https://i.imgur.com/2eV5ubX.jpg
# 2340_0_0 already exist
# start article: [正妹] ＝中山女高＝
# Processing image: 2340_2_0 https://i.imgur.com/OAYbAJv.jpg
# 2340_2_0 already exist
# Processing image: 2340_2_0 https://i.imgur.com/oijSEtn.jpg
# 2340_2_0 already exist
# Processing image: 2340_2_0 https://i.imgur.com/p7mxhBw.jpg
# 2340_2_0 already exist
# Processing image: 2340_2_0 https://i.imgur.com/BI0267r.jpg
# 2340_2_0 already exist
# Processing image: 2340_2_0 https://i.imgur.com/EYWYTyn.jpg
# 2340_2_0 already exist
# Processing image: 2340_2_0 https://i.imgur.com/9AiKeme.jpg
# 2340_2_0 already exist
# Processing image: 2340_2_0 https://i.imgur.com/xkIBtOu.jpg
# 2340_2_0 already exist
# Processing image: 2340_2_0 https://i.imgur.com/XEJnVAf.jpg
# 2340_2_0 already exist
# Processing image: 2340_2_0 https://i.imgur.com/zsUTXVj.jpg
# 2340_2_0 already exist
# Processing image: 2340_2_0 https://i.imgur.com/v6KRxYb.jpg
# 2340_2_0 already exist
# Processing image: 2340_2_0 https://i.imgur.com/uUbegal.jpg
# 2340_2_0 already exist
# Processing image: 2340_2_0 https://i.imgur.com/gV9IUVg.jpg
# 2340_2_0 already exist
# Processing image: 2340_2_0 https://i.imgur.com/sXsyjE1.jpg
# 2340_2_0 already exist
# Processing image: 2340_2_0 https://i.imgur.com/vs5qHtq.jpg
# 2340_2_0 already exist
# Processing image: 2340_2_0 https://i.imgur.com/B6eQS94.jpg
# 2340_2_0 already exist
# Processing image: 2340_2_0 https://i.imgur.com/74Ct4LM.jpg
# 2340_2_0 already exist
# Processing image: 2340_2_0 https://i.imgur.com/s1uFbHj.jpg
# 2340_2_0 already exist
# Processing image: 2340_2_0 https://i.imgur.com/hd5Fpuq.jpg
# 2340_2_0 already exist
# Processing image: 2340_2_0 https://i.imgur.com/zValBLD.jpg
# 2340_2_0 already exist
# Processing image: 2340_2_0 https://i.imgur.com/8sMUSgG.jpg
# 2340_2_0 already exist
# Processing image: 2340_2_0 https://i.imgur.com/erG2t4u.jpg
# 2340_2_0 already exist
# Processing image: 2340_2_0 https://i.imgur.com/JX1RTeq.jpg
# 2340_2_0 already exist
# Processing image: 2340_2_0 https://i.imgur.com/1DkFi8N.jpg
# 2340_2_0 already exist
# start article: [正妹] 這樣好嗎
# Processing image: 2340_3_0 https://i.imgur.com/QhYUTDA.jpg
# 2340_3_0 already exist
# Processing image: 2340_3_0 https://i.imgur.com/mUZLMyq.jpg
# 2340_3_0 already exist
# Processing image: 2340_3_0 https://i.imgur.com/X5D0GZS.jpg
# 2340_3_0 already exist
# Processing image: 2340_3_0 https://i.imgur.com/tWRLtoq.jpg
# 2340_3_0 already exist
# Processing image: 2340_3_0 https://i.imgur.com/2n2vJyh.jpg
# 2340_3_0 already exist
# Processing image: 2340_3_0 https://i.imgur.com/sjLciYM.jpg
# 2340_3_0 already exist
# Processing image: 2340_3_0 https://i.imgur.com/fYLinOS.jpg
# 2340_3_0 already exist
# Processing image: 2340_3_0 https://i.imgur.com/9B23GSQ.jpg
# 2340_3_0 already exist
# start article: [正妹] 廢工寮
# Processing image: 2340_4_0 https://i.imgur.com/tLpqH3T.jpg
# 2340_4_0 already exist
# Processing image: 2340_4_0 https://i.imgur.com/xKAbMQ0.jpg
# 2340_4_0 already exist
# Processing image: 2340_4_0 https://i.imgur.com/hn1oGQL.jpg
# 2340_4_0 already exist
# Processing image: 2340_4_0 https://i.imgur.com/65mMsko.jpg
# 2340_4_0 already exist
# Processing image: 2340_4_0 https://i.imgur.com/SfcLR2w.jpg
# 2340_4_0 already exist
# Processing image: 2340_4_0 https://i.imgur.com/Ndj3nlB.jpg
# 2340_4_0 already exist
# Processing image: 2340_4_0 https://i.imgur.com/GrhrqWy.jpg
# 2340_4_0 already exist
# start article: [正妹] 拍賣網站看到的
# start article: [正妹] 笑容不錯的女孩
# Processing image: 2340_8_0 https://imgur.com/h5DXLxE.jpg
# 2340_8_0 already exist
# Processing image: 2340_8_0 https://imgur.com/spE5TQh.jpg
# 2340_8_0 already exist
# Processing image: 2340_8_0 https://imgur.com/QKwfQQL.jpg
# 2340_8_0 already exist
# Processing image: 2340_8_0 https://imgur.com/UQoR0uG.jpg
# 2340_8_0 already exist
# Processing image: 2340_8_0 https://imgur.com/tckg4jM.jpg
# 2340_8_0 already exist
# Processing image: 2340_8_0 https://imgur.com/cXL5YKm.jpg
# 2340_8_0 already exist
# Processing image: 2340_8_0 https://imgur.com/OM1PbFZ.jpg
# 2340_8_0 already exist
# Processing image: 2340_8_0 https://imgur.com/1dfW523.jpg
# 2340_8_0 already exist
# start article: [正妹] 一張
# Processing image: 2340_9_0 https://i.imgur.com/KDay2ig.jpg
# 2340_9_0 already exist
# start article: [正妹] 腿長長的女孩
# Processing image: 2340_11_0 https://i.imgur.com/afvuQ82.jpg
# 2340_11_0 already exist
# Processing image: 2340_11_0 https://i.imgur.com/ykKQbFo.jpg
# 2340_11_0 already exist
# Processing image: 2340_11_0 https://i.imgur.com/ynCeLBl.jpg
# 2340_11_0 already exist
# Processing image: 2340_11_0 https://i.imgur.com/C5HAxl9.jpg
# 2340_11_0 already exist
# Processing image: 2340_11_0 https://i.imgur.com/Mcz4FCk.jpg
# 2340_11_0 already exist
# Processing image: 2340_11_0 https://i.imgur.com/G0zEg8F.jpg
# 2340_11_0 already exist
# Processing image: 2340_11_0 https://i.imgur.com/aAVGd8s.jpg
# 2340_11_0 already exist
# Processing image: 2340_11_0 https://i.imgur.com/3Jufvm4.jpg
# 2340_11_0 already exist
# Processing image: 2340_11_0 https://i.imgur.com/J68grRj.jpg
# 2340_11_0 already exist
# Processing image: 2340_11_0 https://i.imgur.com/N1zAirT.jpg
# 2340_11_0 already exist
# Processing image: 2340_11_0 https://i.imgur.com/VQ4XyaF.jpg
# 2340_11_0 already exist
# Processing image: 2340_11_0 https://i.imgur.com/1u6bykj.jpg
# 2340_11_0 already exist
# Processing image: 2340_11_0 https://i.imgur.com/wWthB3J.jpg
# 2340_11_0 already exist
# Processing image: 2340_11_0 https://i.imgur.com/aWlRtRu.jpg
# 2340_11_0 already exist
# start article: [正妹] 上上禮拜天的玩具槍展 SHOW GIRL
# start article: [正妹] 道重沙由美
# Processing image: 2340_14_0 https://i.imgur.com/C0iTIoI.jpg
# 2340_14_0 already exist
# Processing image: 2340_14_0 https://i.imgur.com/i74MKFN.jpg
# 2340_14_0 already exist
# Processing image: 2340_14_0 https://i.imgur.com/Aamymba.jpg
# 2340_14_0 already exist
# Processing image: 2340_14_0 https://i.imgur.com/Bo0kpXZ.jpg
# 2340_14_0 already exist
# Processing image: 2340_14_0 https://i.imgur.com/eY3URWO.jpg
# 2340_14_0 already exist
# Processing image: 2340_14_0 https://i.imgur.com/UEbsLr9.jpg
# 2340_14_0 already exist
# Processing image: 2340_14_0 https://i.imgur.com/q0fEyY0.jpg
# 2340_14_0 already exist
# Processing image: 2340_14_0 https://i.imgur.com/DtTGCBY.jpg
# 2340_14_0 already exist
# Processing image: 2340_14_0 https://i.imgur.com/sJmRm34.jpg
# 2340_14_0 already exist
# Processing image: 2340_14_0 https://i.imgur.com/5J8CW28.jpg
# 2340_14_0 already exist
# start article: [正妹] 超美人卓君澤專訪
# Processing image: 2340_15_0 https://i.imgur.com/BUwHU4r.jpg
# 2340_15_0 already exist
# start article: [正妹] 花蓮高農
# Processing image: 2340_16_0 https://i.imgur.com/01ayH5k.jpg
# 2340_16_0 already exist
# Processing image: 2340_16_0 https://i.imgur.com/JnlBzC7.jpg
# 2340_16_0 already exist
# Processing image: 2340_16_0 https://i.imgur.com/b8VLSuj.jpg
# 2340_16_0 already exist
# Processing image: 2340_16_0 https://i.imgur.com/Y31y2vv.jpg
# 2340_16_0 already exist
# Processing image: 2340_16_0 https://i.imgur.com/njaT0Hy.jpg
# 2340_16_0 already exist
# Processing image: 2340_16_0 https://i.imgur.com/uwQaxbE.jpg
# 2340_16_0 already exist
# Processing image: 2340_16_0 https://i.imgur.com/nr0RZSS.jpg
# 2340_16_0 already exist
# Processing image: 2340_16_0 https://i.imgur.com/4YViTNK.jpg
# 2340_16_0 already exist
# Processing image: 2340_16_0 https://i.imgur.com/sEXXs4s.jpg
# 2340_16_0 already exist
# Processing image: 2340_16_0 https://i.imgur.com/i411zeA.jpg
# 2340_16_0 already exist
# Processing image: 2340_16_0 https://i.imgur.com/6FnX4Rp.jpg
# 2340_16_0 already exist
# Processing image: 2340_16_0 https://i.imgur.com/RjDpAsb.jpg
# 2340_16_0 already exist
# Processing image: 2340_16_0 https://i.imgur.com/OarYVJH.jpg
# 2340_16_0 already exist
# Processing image: 2340_16_0 https://i.imgur.com/hmkJKFL.jpg
# 2340_16_0 already exist
# Processing image: 2340_16_0 https://i.imgur.com/lUDkKOW.jpg
# 2340_16_0 already exist
# Processing image: 2340_16_0 https://i.imgur.com/REyxcVZ.jpg
# 2340_16_0 already exist
# Processing image: 2340_16_0 https://i.imgur.com/BM9KrOd.jpg
# 2340_16_0 already exist
# Processing image: 2340_16_0 https://i.imgur.com/kMmVtpF.jpg
# 2340_16_0 already exist
# Processing image: 2340_16_0 https://i.imgur.com/e8pr0Gh.jpg
# 2340_16_0 already exist
# Processing image: 2340_16_0 https://i.imgur.com/CyuSG2w.jpg
# 2340_16_0 already exist
# Processing image: 2340_16_0 https://i.imgur.com/XoVlNed.jpg
# 2340_16_0 already exist
# Processing image: 2340_16_0 https://i.imgur.com/rKuLpu7.jpg
# 2340_16_0 already exist
# Processing image: 2340_16_0 https://i.imgur.com/wG5y5tg.jpg
# 2340_16_0 already exist
# Processing image: 2340_16_0 https://i.imgur.com/958zGMe.jpg
# 2340_16_0 already exist
# start article: [正妹] 淡淡
# Processing image: 2340_17_0 https://i.imgur.com/KoOLOj8.jpg
# 2340_17_0 already exist
# Processing image: 2340_17_0 https://i.imgur.com/qki4XOY.jpg
# 2340_17_0 already exist
# Processing image: 2340_17_0 https://i.imgur.com/avQAbBS.jpg
# 2340_17_0 already exist
# Processing image: 2340_17_0 https://i.imgur.com/FGMycYE.jpg
# 2340_17_0 already exist
# Processing image: 2340_17_0 https://i.imgur.com/Gyojfhf.jpg
# 2340_17_0 already exist
# Processing image: 2340_17_0 https://i.imgur.com/jL24qA6.jpg
# 2340_17_0 already exist
# Processing image: 2340_17_0 https://i.imgur.com/dPip9oN.jpg
# 2340_17_0 already exist
# Processing image: 2340_17_0 https://i.imgur.com/bMHFyhi.jpg
# 2340_17_0 already exist
# Processing image: 2340_17_0 https://i.imgur.com/M3Uzoho.jpg
# 2340_17_0 already exist
# Processing image: 2340_17_0 https://i.imgur.com/hhy1mgp.jpg
# 2340_17_0 already exist
# Processing image: 2340_17_0 https://i.imgur.com/oZxqlGW.jpg
# 2340_17_0 already exist
# Processing image: 2340_17_0 https://i.imgur.com/8WFT4nm.jpg
# 2340_17_0 already exist
# Processing image: 2340_17_0 https://i.imgur.com/Z35FVRy.jpg
# 2340_17_0 already exist
# start article: [正妹] 眼鏡妹壞脾氣
# Processing image: 2340_18_0 https://i.imgur.com/uAR8UZ3.jpg
# 2340_18_0 already exist
# Processing image: 2340_18_0 https://i.imgur.com/bwQQlY7.jpg
# 2340_18_0 already exist
# Processing image: 2340_18_0 https://i.imgur.com/43oIikt.jpg
# 2340_18_0 already exist
# Processing image: 2340_18_0 https://i.imgur.com/S9JkE56.jpg
# 2340_18_0 already exist
# Processing image: 2340_18_0 https://i.imgur.com/fi82kXp.jpg
# 2340_18_0 already exist
# Processing image: 2340_18_0 https://i.imgur.com/7BRcjkS.jpg
# 2340_18_0 already exist
# Processing image: 2340_18_0 https://i.imgur.com/JWXcPnz.jpg
# 2340_18_0 already exist
# Processing image: 2340_18_0 https://i.imgur.com/kAXlFO0.jpg
# 2340_18_0 already exist
# start article: [正妹] 橋本環奈。常に全盛期
# Processing image: 2340_19_0 https://i.imgur.com/pRGtDbJ.jpg
# 2340_19_0 already exist
# Processing image: 2340_19_0 https://i.imgur.com/38i2JUz.jpg
# 2340_19_0 already exist
# Processing image: 2340_19_0 https://i.imgur.com/PN0k06z.jpg
# 2340_19_0 already exist
# Processing image: 2340_19_0 https://i.imgur.com/4xuIKJb.jpg
# 2340_19_0 already exist
# Processing image: 2340_19_0 https://i.imgur.com/HAMm1df.jpg
# 2340_19_0 already exist
# Processing image: 2340_19_0 https://i.imgur.com/NXNPX3B.jpg
# 2340_19_0 already exist
# Processing image: 2340_19_0 https://i.imgur.com/yLmSi8Y.jpg
# 2340_19_0 already exist
# ['M.1513171107.A.76D', 'M.1513185981.A.437', 'M.1513210248.A.D37', 'M.1513211160.A.46E']
# start article: [正妹] 清純姊妹
# Processing image: 2339_0_0 https://i.imgur.com/mUZiZ2G.jpg
# 2339_0_0 already exist
# Processing image: 2339_0_0 https://i.imgur.com/QHqVfbR.jpg
# 2339_0_0 already exist
# Processing image: 2339_0_0 https://i.imgur.com/Ygotzp8.jpg
# 2339_0_0 already exist
# Processing image: 2339_0_0 https://i.imgur.com/0Y2RKiL.jpg
# 2339_0_0 already exist
# Processing image: 2339_0_0 https://i.imgur.com/Nr84W7f.jpg
# 2339_0_0 already exist
# Processing image: 2339_0_0 https://i.imgur.com/bWYX7Lw.jpg
# 2339_0_0 already exist
# Processing image: 2339_0_0 https://i.imgur.com/BcfUURf.jpg
# 2339_0_0 already exist
# Processing image: 2339_0_0 https://i.imgur.com/9Vnj2iW.jpg
# 2339_0_0 already exist
# Processing image: 2339_0_0 https://i.imgur.com/EtBUq0d.jpg
# 2339_0_0 already exist
# Processing image: 2339_0_0 https://i.imgur.com/01tIBeX.jpg
# 2339_0_0 already exist
# Processing image: 2339_0_0 https://i.imgur.com/0BhDWz6.jpg
# 2339_0_0 already exist
# Processing image: 2339_0_0 https://i.imgur.com/7Rijg3S.jpg
# 2339_0_0 already exist
# start article: [正妹] 餐飲女孩
# Processing image: 2339_1_0 https://i.imgur.com/5ZZlcj6.jpg
# 2339_1_0 already exist
# Processing image: 2339_1_0 https://i.imgur.com/RKMFwq9.jpg
# 2339_1_0 already exist
# Processing image: 2339_1_0 https://i.imgur.com/AF0LL9D.jpg
# 2339_1_0 already exist
# start article: [正妹] 厭世眼神的清秀女孩
# Processing image: 2339_2_0 https://i.imgur.com/ZWAFbw9.jpg
# 2339_2_0 already exist
# Processing image: 2339_2_0 https://i.imgur.com/UOIMOH5.jpg
# 2339_2_0 already exist
# Processing image: 2339_2_0 https://i.imgur.com/CMFWjCJ.jpg
# 2339_2_0 already exist
# Processing image: 2339_2_0 https://i.imgur.com/34XnVpS.jpg
# 2339_2_0 already exist
# Processing image: 2339_2_0 https://i.imgur.com/zlDi0q2.jpg
# 2339_2_0 already exist
# Processing image: 2339_2_0 https://i.imgur.com/yh9u7Wx.jpg
# 2339_2_0 already exist
# Processing image: 2339_2_0 https://i.imgur.com/Wjjk7yU.jpg
# 2339_2_0 already exist
# Processing image: 2339_2_0 https://i.imgur.com/uQ82ep0.jpg
# 2339_2_0 already exist
# Processing image: 2339_2_0 https://i.imgur.com/6o263o5.jpg
# 2339_2_0 already exist
# Processing image: 2339_2_0 https://i.imgur.com/RO0S6w4.jpg
# 2339_2_0 already exist
# Processing image: 2339_2_0 https://i.imgur.com/mesy1Y1.jpg
# 2339_2_0 already exist
# Processing image: 2339_2_0 https://i.imgur.com/RnGgqCk.jpg
# 2339_2_0 already exist
# Processing image: 2339_2_0 https://i.imgur.com/SnXS5vY.jpg
# 2339_2_0 already exist
# Processing image: 2339_2_0 https://i.imgur.com/krBPsbU.jpg
# 2339_2_0 already exist
# Processing image: 2339_2_0 https://i.imgur.com/rn1g1Ux.jpg
# 2339_2_0 already exist
# start article: [正妹] 蔡依珊
# Processing image: 2339_4_0 https://i.imgur.com/fCEHHgp.jpg
# 2339_4_0 already exist
# Processing image: 2339_4_0 https://i.imgur.com/PqCE68x.jpg
# 2339_4_0 already exist
# start article: [正妹] 三國手遊廣告大小喬
# Processing image: 2339_5_0 https://i.imgur.com/RwcSaF4.jpg
# 2339_5_0 already exist
# Processing image: 2339_5_0 https://i.imgur.com/87Ml5lF.jpg
# 2339_5_0 already exist
# Processing image: 2339_5_0 https://i.imgur.com/7L4r5FK.jpg
# 2339_5_0 already exist
# start article: [正妹] 有點虎牙
# Processing image: 2339_6_0 https://i.imgur.com/hTQlPhG.jpg
# 2339_6_0 already exist
# Processing image: 2339_6_0 https://i.imgur.com/NorFpe7.jpg
# 2339_6_0 already exist
# Processing image: 2339_6_0 https://i.imgur.com/81VyjJF.jpg
# 2339_6_0 already exist
# Processing image: 2339_6_0 https://i.imgur.com/TB4J4r8.jpg
# 2339_6_0 already exist
# Processing image: 2339_6_0 https://i.imgur.com/PZplvv7.jpg
# 2339_6_0 already exist
# Processing image: 2339_6_0 https://i.imgur.com/xSfLMlK.jpg
# 2339_6_0 already exist
# Processing image: 2339_6_0 https://i.imgur.com/WKofkEA.jpg
# 2339_6_0 already exist
# start article: [正妹] 啦啦隊朋友
# Processing image: 2339_7_0 https://i.imgur.com/Td72XhP.jpg
# 2339_7_0 already exist
# Processing image: 2339_7_0 https://i.imgur.com/8W0U7HH.jpg
# 2339_7_0 already exist
# Processing image: 2339_7_0 https://i.imgur.com/qJlFyLL.jpg
# 2339_7_0 already exist
# Processing image: 2339_7_0 https://i.imgur.com/4UxsTBR.jpg
# 2339_7_0 already exist
# Processing image: 2339_7_0 https://i.imgur.com/38XA3BO.jpg
# 2339_7_0 already exist
# Processing image: 2339_7_0 https://i.imgur.com/mM0E0Nb.jpg
# 2339_7_0 already exist
# Processing image: 2339_7_0 https://i.imgur.com/ow3JUci.jpg
# 2339_7_0 already exist
# Processing image: 2339_7_0 https://i.imgur.com/PyA34vl.jpg
# 2339_7_0 already exist
# Processing image: 2339_7_0 https://i.imgur.com/kIpMxvd.jpg
# 2339_7_0 already exist
# Processing image: 2339_7_0 https://i.imgur.com/gRVOiBe.jpg
# 2339_7_0 already exist
# Processing image: 2339_7_0 https://i.imgur.com/Ai2EhHr.jpg
# 2339_7_0 already exist
# Processing image: 2339_7_0 https://i.imgur.com/jWL6o0V.jpg
# 2339_7_0 already exist
# Processing image: 2339_7_0 https://i.imgur.com/IWjCRJ4.jpg
# 2339_7_0 already exist
# Processing image: 2339_7_0 https://i.imgur.com/swIA7F2.jpg
# 2339_7_0 already exist
# Processing image: 2339_7_0 https://i.imgur.com/2aUs0Sn.jpg
# 2339_7_0 already exist
# Processing image: 2339_7_0 https://i.imgur.com/ZDq4qYF.jpg
# 2339_7_0 already exist
# Processing image: 2339_7_0 https://i.imgur.com/IPKOe2g.jpg
# 2339_7_0 already exist
# start article: [正妹] 伊東紗冶子
# Processing image: 2339_8_0 https://i.imgur.com/BpbZ8O8.jpg
# 2339_8_0 already exist
# Processing image: 2339_8_0 https://i.imgur.com/eSzQKl1.jpg
# 2339_8_0 already exist
# Processing image: 2339_8_0 https://i.imgur.com/uVPbcQP.jpg
# 2339_8_0 already exist
# Processing image: 2339_8_0 https://i.imgur.com/eZSBg97.jpg
# 2339_8_0 already exist
# Processing image: 2339_8_0 https://i.imgur.com/yNOfMBj.jpg
# 2339_8_0 already exist
# Processing image: 2339_8_0 https://i.imgur.com/FCLhdSt.jpg
# 2339_8_0 already exist
# Processing image: 2339_8_0 https://i.imgur.com/TvH6u32.jpg
# 2339_8_0 already exist
# Processing image: 2339_8_0 https://i.imgur.com/QQk7WwD.jpg
# 2339_8_0 already exist
# Processing image: 2339_8_0 https://i.imgur.com/2uv6m0O.jpg
# 2339_8_0 already exist
# start article: [正妹] DJ∵∴∵
# Processing image: 2339_9_0 https://i.imgur.com/qFteL22.jpg
# 2339_9_0 already exist
# Processing image: 2339_9_0 https://i.imgur.com/Fhwwx9d.jpg
# 2339_9_0 already exist
# Processing image: 2339_9_0 https://i.imgur.com/rCgPYg3.jpg
# 2339_9_0 already exist
# Processing image: 2339_9_0 https://i.imgur.com/gqgQ3uu.jpg
# 2339_9_0 already exist
# Processing image: 2339_9_0 https://i.imgur.com/j7F4WvQ.jpg
# 2339_9_0 already exist
# Processing image: 2339_9_0 https://i.imgur.com/zFX2v83.jpg
# 2339_9_0 already exist
# Processing image: 2339_9_0 https://i.imgur.com/02S0KEP.jpg
# 2339_9_0 already exist
# Processing image: 2339_9_0 https://i.imgur.com/CEMrN9p.jpg
# 2339_9_0 already exist
# Processing image: 2339_9_0 https://i.imgur.com/GkJL7ry.jpg
# 2339_9_0 already exist
# Processing image: 2339_9_0 https://i.imgur.com/GdEjar1.jpg
# 2339_9_0 already exist
# start article: [正妹] 裙子有點緊？
# Processing image: 2339_11_0 https://i.imgur.com/hsWjrQF.jpg
# 2339_11_0 already exist
# Processing image: 2339_11_0 https://i.imgur.com/EEwGqfW.jpg
# 2339_11_0 already exist
# Processing image: 2339_11_0 https://i.imgur.com/LuZUQsz.jpg
# 2339_11_0 already exist
# Processing image: 2339_11_0 https://i.imgur.com/xelm9Du.jpg
# 2339_11_0 already exist
# Processing image: 2339_11_0 https://i.imgur.com/jeWiTRF.jpg
# 2339_11_0 already exist
# Processing image: 2339_11_0 https://i.imgur.com/7DRvlvZ.jpg
# 2339_11_0 already exist
# Processing image: 2339_11_0 https://i.imgur.com/HrN78wQ.jpg
# 2339_11_0 already exist
# Processing image: 2339_11_0 https://i.imgur.com/wTepIfe.jpg
# 2339_11_0 already exist
# Processing image: 2339_11_0 https://i.imgur.com/JaXBQ6b.jpg
# 2339_11_0 already exist
# start article: [正妹] 兔牙
# Processing image: 2339_12_0 https://i.imgur.com/E3BnKEi.jpg
# 2339_12_0 already exist
# Processing image: 2339_12_0 https://i.imgur.com/dJLNpdH.jpg
# 2339_12_0 already exist
# Processing image: 2339_12_0 https://i.imgur.com/kPtnkVX.jpg
# 2339_12_0 already exist
# Processing image: 2339_12_0 https://i.imgur.com/FMkZfzv.jpg
# 2339_12_0 already exist
# Processing image: 2339_12_0 https://i.imgur.com/DZg0PIl.jpg
# 2339_12_0 already exist
# Processing image: 2339_12_0 https://i.imgur.com/EAiqEPK.jpg
# 2339_12_0 already exist
# Processing image: 2339_12_0 https://i.imgur.com/MUOBnh6.jpg
# 2339_12_0 already exist
# Processing image: 2339_12_0 https://i.imgur.com/8VgpFmt.jpg
# 2339_12_0 already exist
# Processing image: 2339_12_0 https://i.imgur.com/8UtGnVY.jpg
# 2339_12_0 already exist
# Processing image: 2339_12_0 https://i.imgur.com/dtwij8h.jpg
# 2339_12_0 already exist
# Processing image: 2339_12_0 https://i.imgur.com/8lHZpXw.jpg
# 2339_12_0 already exist
# Processing image: 2339_12_0 https://i.imgur.com/IeHCo7u.jpg
# 2339_12_0 already exist
# Processing image: 2339_12_0 https://i.imgur.com/Hmidbol.jpg
# 2339_12_0 already exist
# Processing image: 2339_12_0 https://i.imgur.com/pRFd4Uk.jpg
# 2339_12_0 already exist
# Processing image: 2339_12_0 https://i.imgur.com/YX4UEs0.jpg
# 2339_12_0 already exist
# Processing image: 2339_12_0 https://i.imgur.com/bNmIHAu.jpg
# 2339_12_0 already exist
# start article: [正妹] 長髮短髮都好看
# Processing image: 2339_14_0 https://imgur.com/BFKzOWw
# save 2339_14_0
# Processing image: 2339_14_0 https://imgur.com/PlxOUkO
# 2339_14_0 already exist
# Processing image: 2339_14_0 https://imgur.com/zsASYKA
# 2339_14_0 already exist
# Processing image: 2339_14_0 https://imgur.com/CIsKm83
# 2339_14_0 already exist
# Processing image: 2339_14_0 https://imgur.com/CITMLCQ
# 2339_14_0 already exist
# Processing image: 2339_14_0 https://imgur.com/ozn7DZu
# 2339_14_0 already exist
# start article: [正妹] 短髮氣質
# Processing image: 2339_15_0 https://i.imgur.com/azcjpp2.jpg
# save 2339_15_0
# Processing image: 2339_15_0 https://i.imgur.com/CgfkvYB.jpg
# save 2339_15_0
# Processing image: 2339_15_0 https://i.imgur.com/rovDqt5.jpg
# 2339_15_0 already exist
# Processing image: 2339_15_0 https://i.imgur.com/wMypwlE.jpg
# 2339_15_0 already exist
# Processing image: 2339_15_0 https://i.imgur.com/F00YBeJ.jpg
# 2339_15_0 already exist
# Processing image: 2339_15_0 https://i.imgur.com/x8ffTJ7.jpg
# 2339_15_0 already exist
# Processing image: 2339_15_0 https://i.imgur.com/foxXshe.jpg
# 2339_15_0 already exist
# Processing image: 2339_15_0 https://i.imgur.com/Pu7sOeQ.jpg
# 2339_15_0 already exist
# Processing image: 2339_15_0 https://i.imgur.com/6p5X4lE.jpg
# 2339_15_0 already exist
# Processing image: 2339_15_0 https://i.imgur.com/vOrQFaB.jpg
# 2339_15_0 already exist
# Processing image: 2339_15_0 https://i.imgur.com/ToZEMLe.jpg
# 2339_15_0 already exist
# start article: [正妹] 阿純兩張
# Processing image: 2339_17_0 https://i.imgur.com/0xmVxgO.jpg
# save 2339_17_0
# Processing image: 2339_17_0 https://i.imgur.com/G4OAAPi.jpg
# 2339_17_0 already exist
# Processing index: 2338
# Processing article: M.1513083123.A.895
# Processing article: M.1513089990.A.851
# Processing article: M.1513091394.A.85D
# Processing article: M.1513093658.A.143
# Processing article: M.1513095976.A.E38
# Processing article: M.1513096077.A.3CA
# Processing article: M.1513097642.A.A09
# Processing article: M.1513103318.A.A2E
# Processing article: M.1513126390.A.FA5
# Processing article: M.1513126416.A.66B
# Processing article: M.1513129782.A.DD8
# Processing article: M.1513136343.A.EC3
# Processing article: M.1513138111.A.EBF
# Processing article: M.1513141794.A.0AC
# Processing article: M.1513146484.A.CEA
# Processing article: M.1513148620.A.8A2
# Processing article: M.1513152991.A.254
# Processing article: M.1513167206.A.FEF
# Processing article: M.1513168048.A.F4D
# Processing article: M.1513168921.A.CB3
# ['M.1513089990.A.851', 'M.1513091394.A.85D', 'M.1513093658.A.143', 'M.1513095976.A.E38']
# start article: [正妹] 想
# Processing image: 2338_2_0 https://i.imgur.com/od0Ejgy.jpg
# save 2338_2_0
# Processing image: 2338_2_0 https://i.imgur.com/uPCfykz.jpg
# 2338_2_0 already exist
# Processing image: 2338_2_0 https://i.imgur.com/F9gPY1t.jpg
# 2338_2_0 already exist
# Processing image: 2338_2_0 https://i.imgur.com/xu4UUaU.jpg
# 2338_2_0 already exist
# Processing image: 2338_2_0 https://i.imgur.com/u9h5wAe.jpg
# 2338_2_0 already exist
# Processing image: 2338_2_0 https://i.imgur.com/6HInqMy.jpg
# 2338_2_0 already exist
# Processing image: 2338_2_0 https://i.imgur.com/AxlGs7V.jpg
# 2338_2_0 already exist
# Processing image: 2338_2_0 https://i.imgur.com/ekQwuQJ.jpg
# 2338_2_0 already exist
# Processing image: 2338_2_0 https://i.imgur.com/NbZKld6.jpg
# 2338_2_0 already exist
# Processing image: 2338_2_0 https://i.imgur.com/YP9iKIb.jpg
# 2338_2_0 already exist
# Processing image: 2338_2_0 https://i.imgur.com/vYXHXVS.jpg
# 2338_2_0 already exist
# Processing image: 2338_2_0 https://i.imgur.com/wmWIUUP.jpg
# 2338_2_0 already exist
# start article: [正妹] 妳
# Processing image: 2338_3_0 https://i.imgur.com/bReP5T0.jpg
# save 2338_3_0
# Processing image: 2338_3_0 https://i.imgur.com/aTFmrSJ.jpg
# 2338_3_0 already exist
# Processing image: 2338_3_0 https://i.imgur.com/Yuhkwn5.jpg
# 2338_3_0 already exist
# Processing image: 2338_3_0 https://i.imgur.com/VBYLlOJ.jpg
# 2338_3_0 already exist
# start article: [正妹] 牙齒很白
# Processing image: 2338_4_0 https://i.imgur.com/tzBUI9a.jpg
# save 2338_4_0
# Processing image: 2338_4_0 https://i.imgur.com/Q24BL0q.jpg
# 2338_4_0 already exist
# Processing image: 2338_4_0 https://i.imgur.com/2t8EtL1.jpg
# 2338_4_0 already exist
# start article: [正妹] 睡前衝一波.....
# Processing image: 2338_5_0 https://i.imgur.com/wjvNAov.jpg
# save 2338_5_0
# Processing image: 2338_5_0 https://i.imgur.com/v9A1fN1.jpg
# 2338_5_0 already exist
# Processing image: 2338_5_0 https://i.imgur.com/06mpWbY.jpg
# 2338_5_0 already exist
# Processing image: 2338_5_0 https://i.imgur.com/4fD31bW.jpg
# 2338_5_0 already exist
# Processing image: 2338_5_0 https://i.imgur.com/toyqqCQ.jpg
# 2338_5_0 already exist
# Processing image: 2338_5_0 https://i.imgur.com/kFTR4Nb.jpg
# 2338_5_0 already exist
# Processing image: 2338_5_0 https://i.imgur.com/mNLtRCv.jpg
# 2338_5_0 already exist
# Processing image: 2338_5_0 https://i.imgur.com/wx7dcAA.jpg
# 2338_5_0 already exist
# Processing image: 2338_5_0 https://i.imgur.com/lp0RnFU.jpg
# 2338_5_0 already exist
# Processing image: 2338_5_0 https://i.imgur.com/ab1uOjE.jpg
# 2338_5_0 already exist
# Processing image: 2338_5_0 https://i.imgur.com/lvmKvFU.jpg
# 2338_5_0 already exist
# Processing image: 2338_5_0 https://i.imgur.com/tlUdPZa.jpg
# 2338_5_0 already exist
# Processing image: 2338_5_0 https://i.imgur.com/0uvdoGy.jpg
# 2338_5_0 already exist
# Processing image: 2338_5_0 https://i.imgur.com/sCPn3G9.jpg
# 2338_5_0 already exist
# Processing image: 2338_5_0 https://i.imgur.com/H7xBMvF.jpg
# 2338_5_0 already exist
# Processing image: 2338_5_0 https://i.imgur.com/4nYz1Jj.jpg
# 2338_5_0 already exist
# Processing image: 2338_5_0 https://i.imgur.com/DXS07HW.jpg
# 2338_5_0 already exist
# Processing image: 2338_5_0 https://i.imgur.com/WVxygOX.jpg
# 2338_5_0 already exist
# Processing image: 2338_5_0 https://i.imgur.com/oby74NA.jpg
# 2338_5_0 already exist
# Processing image: 2338_5_0 https://i.imgur.com/JBaHHYy.jpg
# 2338_5_0 already exist
# Processing image: 2338_5_0 https://i.imgur.com/DoMDhYr.jpg
# 2338_5_0 already exist
# Processing image: 2338_5_0 https://i.imgur.com/8DIkaSs.jpg
# 2338_5_0 already exist
# Processing image: 2338_5_0 https://i.imgur.com/YtszfUv.jpg
# 2338_5_0 already exist
# Processing image: 2338_5_0 https://i.imgur.com/3do8Di4.jpg
# 2338_5_0 already exist
# Processing image: 2338_5_0 https://i.imgur.com/gyxuLN1.jpg
# 2338_5_0 already exist
# Processing image: 2338_5_0 https://i.imgur.com/JfuWBQH.jpg
# 2338_5_0 already exist
# start article: [正妹] 這腿幾分?
# Processing image: 2338_6_0 https://i.imgur.com/EwrAwn1.jpg
# save 2338_6_0
# start article: [正妹] 就 景嵐
# Processing image: 2338_7_0 https://i.imgur.com/GSYMybU.jpg
# save 2338_7_0
# Processing image: 2338_7_0 https://i.imgur.com/spcIpXv.jpg
# 2338_7_0 already exist
# Processing image: 2338_7_0 https://i.imgur.com/6CBGY1f.jpg
# 2338_7_0 already exist
# Processing image: 2338_7_0 https://i.imgur.com/2MbKuZJ.jpg
# 2338_7_0 already exist
# Processing image: 2338_7_0 https://i.imgur.com/YXAtyPi.jpg
# 2338_7_0 already exist
# Processing image: 2338_7_0 https://i.imgur.com/o8TeXRS.jpg
# 2338_7_0 already exist
# Processing image: 2338_7_0 https://i.imgur.com/chOglyi.jpg
# 2338_7_0 already exist
# Processing image: 2338_7_0 https://i.imgur.com/RXLYyIM.jpg
# 2338_7_0 already exist
# Processing image: 2338_7_0 https://i.imgur.com/aROXHkJ.jpg
# 2338_7_0 already exist
# Processing image: 2338_7_0 https://i.imgur.com/XurakaU.jpg
# 2338_7_0 already exist
# start article: [正妹] 有點像廣末涼子...吧
# Processing image: 2338_9_0 https://i.imgur.com/GcjcHkf.jpg
# save 2338_9_0
# Processing image: 2338_9_0 https://i.imgur.com/sj2JedG.jpg
# 2338_9_0 already exist
# Processing image: 2338_9_0 https://i.imgur.com/AthyvqL.jpg
# 2338_9_0 already exist
# Processing image: 2338_9_0 https://i.imgur.com/UstBVlc.jpg
# 2338_9_0 already exist
# Processing image: 2338_9_0 https://i.imgur.com/wdqnXqw.jpg
# 2338_9_0 already exist
# Processing image: 2338_9_0 https://i.imgur.com/qp2JXUE.jpg
# 2338_9_0 already exist
# Processing image: 2338_9_0 https://i.imgur.com/Zv0ekcx.jpg
# 2338_9_0 already exist
# Processing image: 2338_9_0 https://i.imgur.com/SJdHCzn.jpg
# 2338_9_0 already exist
# start article: [正妹] 不知火舞cosplay
# Processing image: 2338_10_0 https://i.imgur.com/rciE5E3.jpg
# save 2338_10_0
# Processing image: 2338_10_0 https://i.imgur.com/gdBbzLQ.jpg
# 2338_10_0 already exist
# Processing image: 2338_10_0 https://i.imgur.com/pURDfrY.jpg
# 2338_10_0 already exist
# Processing image: 2338_10_0 https://i.imgur.com/ZimN7xB.jpg
# 2338_10_0 already exist
# Processing image: 2338_10_0 https://i.imgur.com/I1rkpBL.jpg
# 2338_10_0 already exist
# Processing image: 2338_10_0 https://i.imgur.com/pSQnl3k.jpg
# 2338_10_0 already exist
# Processing image: 2338_10_0 https://i.imgur.com/cubiqpU.jpg
# 2338_10_0 already exist
# Processing image: 2338_10_0 https://i.imgur.com/nhRgrOw.jpg
# 2338_10_0 already exist
# Processing image: 2338_10_0 https://i.imgur.com/gtpyruc.jpg
# 2338_10_0 already exist
# Processing image: 2338_10_0 https://i.imgur.com/P34FrcS.jpg
# 2338_10_0 already exist
# start article: [正妹] 加賴
# Processing image: 2338_11_0 https://i.imgur.com/eHDmj4u.jpg
# save 2338_11_0
# Processing image: 2338_11_0 https://i.imgur.com/ViWgj2Q.jpg
# 2338_11_0 already exist
# Processing image: 2338_11_0 https://i.imgur.com/srlAIsV.jpg
# 2338_11_0 already exist
# Processing image: 2338_11_0 https://i.imgur.com/XLIxNRK.jpg
# 2338_11_0 already exist
# start article: [正妹] 馬場ふみか
# Processing image: 2338_12_0 https://i.imgur.com/ct9qT0S.jpg
# save 2338_12_0
# Processing image: 2338_12_0 https://i.imgur.com/ZT297VF.jpg
# 2338_12_0 already exist
# Processing image: 2338_12_0 https://i.imgur.com/0xlrWqN.jpg
# 2338_12_0 already exist
# Processing image: 2338_12_0 https://i.imgur.com/FEhYagk.jpg
# 2338_12_0 already exist
# Processing image: 2338_12_0 https://i.imgur.com/YmJSiiE.jpg
# 2338_12_0 already exist
# Processing image: 2338_12_0 https://i.imgur.com/y8KT54j.jpg
# 2338_12_0 already exist
# Processing image: 2338_12_0 https://i.imgur.com/nmZGyKK.jpg
# 2338_12_0 already exist
# Processing image: 2338_12_0 https://i.imgur.com/WISsCAf.jpg
# 2338_12_0 already exist
# Processing image: 2338_12_0 https://i.imgur.com/hTjQ7RW.jpg
# 2338_12_0 already exist
# Processing image: 2338_12_0 https://i.imgur.com/wAteGr0.jpg
# 2338_12_0 already exist
# start article: [正妹] 陳儀潔
# Processing image: 2338_13_0 https://i.imgur.com/FIaCRyO.jpg
# save 2338_13_0
# Processing image: 2338_13_0 https://i.imgur.com/IKfl1hP.jpg
# 2338_13_0 already exist
# Processing image: 2338_13_0 https://i.imgur.com/sdSUYDq.jpg
# 2338_13_0 already exist
# Processing image: 2338_13_0 https://i.imgur.com/5utIAuC.jpg
# 2338_13_0 already exist
# Processing image: 2338_13_0 https://i.imgur.com/c3fN94X.jpg
# 2338_13_0 already exist
# Processing image: 2338_13_0 https://i.imgur.com/FZZAbTf.jpg
# 2338_13_0 already exist
# start article: [正妹] 東森 蔡慧君
# Processing image: 2338_14_0 https://i.imgur.com/nSSRfDK.jpg
# save 2338_14_0
# Processing image: 2338_14_0 https://i.imgur.com/USGRFIK.jpg
# 2338_14_0 already exist
# Processing image: 2338_14_0 https://i.imgur.com/Cx4BZp7.jpg
# 2338_14_0 already exist
# Processing image: 2338_14_0 https://i.imgur.com/W7FC0oS.jpg
# 2338_14_0 already exist
# start article: [正妹] 2017/12/10 資訊月 Show Girl
# start article: [正妹] 自白1000人斬的女孩
# Processing image: 2338_16_0 https://i.imgur.com/L1Yyicm.jpg
# save 2338_16_0
# Processing image: 2338_16_0 https://i.imgur.com/VMVMPhw.jpg
# 2338_16_0 already exist
# Processing image: 2338_16_0 https://i.imgur.com/MBOvsNc.jpg
# 2338_16_0 already exist
# Processing image: 2338_16_0 https://i.imgur.com/0Zg21gO.jpg
# 2338_16_0 already exist
# Processing image: 2338_16_0 https://i.imgur.com/GFzw20X.jpg
# 2338_16_0 already exist
# Processing image: 2338_16_0 https://i.imgur.com/BuwrjZ7.jpg
# 2338_16_0 already exist
# Processing image: 2338_16_0 https://i.imgur.com/vvcv3Ar.jpg
# 2338_16_0 already exist
# Processing image: 2338_16_0 https://i.imgur.com/d4qWa8b.jpg
# 2338_16_0 already exist
# start article: [正妹] 小冰女孩
# Processing image: 2338_17_0 https://i.imgur.com/uLSuCSh.jpg
# save 2338_17_0
# Processing image: 2338_17_0 https://i.imgur.com/x1VJfPD.jpg
# 2338_17_0 already exist
# Processing image: 2338_17_0 https://i.imgur.com/FTl2xMG.jpg
# 2338_17_0 already exist
# Processing image: 2338_17_0 https://i.imgur.com/lCmg0od.jpg
# 2338_17_0 already exist
# start article: [正妹] 雷理莎
# Processing image: 2338_18_0 https://i.imgur.com/ZDjoMiJ.jpg
# save 2338_18_0
# Processing image: 2338_18_0 https://i.imgur.com/mhHyja8.jpg
# 2338_18_0 already exist
# Processing image: 2338_18_0 https://i.imgur.com/55LkgVl.jpg
# 2338_18_0 already exist
# Processing image: 2338_18_0 https://i.imgur.com/nDJWNjz.jpg
# 2338_18_0 already exist
# Processing image: 2338_18_0 https://i.imgur.com/VPlKnGx.jpg
# 2338_18_0 already exist
# Processing image: 2338_18_0 https://i.imgur.com/JNe0RL1.jpg
# 2338_18_0 already exist
# Processing image: 2338_18_0 https://i.imgur.com/Wr8HD4a.jpg
# 2338_18_0 already exist
# Processing image: 2338_18_0 https://i.imgur.com/SaWWtYH.jpg
# 2338_18_0 already exist
# Processing image: 2338_18_0 https://i.imgur.com/3aDH8eQ.jpg
# 2338_18_0 already exist
# Processing image: 2338_18_0 https://i.imgur.com/lPpx2V8.jpg
# 2338_18_0 already exist
# Processing image: 2338_18_0 https://i.imgur.com/FYLGT0M.jpg
# 2338_18_0 already exist
# Processing image: 2338_18_0 https://i.imgur.com/nPj7oJS.jpg
# 2338_18_0 already exist
# Processing image: 2338_18_0 https://i.imgur.com/d507764.jpg
# 2338_18_0 already exist
# Processing image: 2338_18_0 https://i.imgur.com/a2RaMxJ.jpg
# 2338_18_0 already exist
# Processing image: 2338_18_0 https://i.imgur.com/1BqBgAA.jpg
# 2338_18_0 already exist
# Processing image: 2338_18_0 https://i.imgur.com/SVUHhvY.jpg
# 2338_18_0 already exist
# Processing image: 2338_18_0 https://i.imgur.com/Q2OfkzA.jpg
# 2338_18_0 already exist
# Processing image: 2338_18_0 https://i.imgur.com/lNdCE7a.jpg
# 2338_18_0 already exist
# Processing image: 2338_18_0 https://i.imgur.com/dOJ2i7R.jpg
# 2338_18_0 already exist
# Processing image: 2338_18_0 https://i.imgur.com/yvnvajn.jpg
# 2338_18_0 already exist
# Processing image: 2338_18_0 https://i.imgur.com/jByWGxM.jpg
# 2338_18_0 already exist
# Processing index: 2337
# Processing article: M.1513001332.A.599
# Processing article: M.1513006969.A.26C
# Processing article: M.1513007751.A.145
# Processing article: M.1513011943.A.EFE
# Processing article: M.1513012886.A.722
# Processing article: M.1513012997.A.0BC
# Processing article: M.1513023105.A.E8A
# Processing article: M.1513043636.A.FDE
# Processing article: M.1513046367.A.E12
# Processing article: M.1513047333.A.74C
# Processing article: M.1513057856.A.9D7
# Processing article: M.1513058690.A.3DA
# Processing article: M.1513062124.A.D35
# Processing article: M.1513064409.A.A17
# Processing article: M.1513065700.A.076
# Processing article: M.1513067744.A.78A
# Processing article: M.1513067823.A.F5D
# Processing article: M.1513075791.A.2D5
# Processing article: M.1513076345.A.4E2
# Processing article: M.1513076621.A.370
# ['M.1513006969.A.26C', 'M.1513007751.A.145', 'M.1513011943.A.EFE', 'M.1513012886.A.722']
# start article: [正妹] 東海大學 應用物理系
# Processing image: 2337_0_0 https://i.imgur.com/VUytHKW.jpg
# save 2337_0_0
# Processing image: 2337_0_0 https://i.imgur.com/uP78hWN.png
# 2337_0_0 already exist
# Processing image: 2337_0_0 https://i.imgur.com/PfhTOgf.jpg
# 2337_0_0 already exist
# Processing image: 2337_0_0 https://i.imgur.com/PjVtMn9.png
# 2337_0_0 already exist
# Processing image: 2337_0_0 https://i.imgur.com/4gKBQZC.jpg
# 2337_0_0 already exist
# Processing image: 2337_0_0 https://i.imgur.com/7jfRIB4.jpg
# 2337_0_0 already exist
# Processing image: 2337_0_0 https://i.imgur.com/d0rmXOm.jpg
# 2337_0_0 already exist
# Processing image: 2337_0_0 https://i.imgur.com/Y4fiFlv.png
# 2337_0_0 already exist
# Processing image: 2337_0_0 https://i.imgur.com/xeKtrbG.jpg
# 2337_0_0 already exist
# start article: [正妹] 46
# Processing image: 2337_1_0 https://i.imgur.com/Zx3WIMa.jpg
# save 2337_1_0
# Processing image: 2337_1_0 https://i.imgur.com/3tya8dA.jpg
# 2337_1_0 already exist
# Processing image: 2337_1_0 https://i.imgur.com/UECkJPT.jpg
# 2337_1_0 already exist
# Processing image: 2337_1_0 https://i.imgur.com/qhct6W3.jpg
# 2337_1_0 already exist
# Processing image: 2337_1_0 https://i.imgur.com/TV0QOp8.jpg
# 2337_1_0 already exist
# Processing image: 2337_1_0 https://i.imgur.com/sj8iqjI.jpg
# 2337_1_0 already exist
# Processing image: 2337_1_0 https://i.imgur.com/5nd7Vvf.jpg
# 2337_1_0 already exist
# Processing image: 2337_1_0 https://i.imgur.com/PAFK2bs.jpg
# 2337_1_0 already exist
# start article: [正妹] 無題
# Processing image: 2337_2_0 https://i.imgur.com/6KRBDH3.jpg
# save 2337_2_0
# Processing image: 2337_2_0 https://i.imgur.com/ZRu7CqW.jpg
# 2337_2_0 already exist
# Processing image: 2337_2_0 https://i.imgur.com/NuTIbfk.jpg
# 2337_2_0 already exist
# Processing image: 2337_2_0 https://i.imgur.com/ZlzSYJa.jpg
# 2337_2_0 already exist
# Processing image: 2337_2_0 https://i.imgur.com/wwiQnIe.jpg
# 2337_2_0 already exist
# Processing image: 2337_2_0 https://i.imgur.com/xYLikqy.jpg
# 2337_2_0 already exist
# Processing image: 2337_2_0 https://i.imgur.com/jadlm51.jpg
# 2337_2_0 already exist
# Processing image: 2337_2_0 https://i.imgur.com/OLrQEKW.jpg
# 2337_2_0 already exist
# Processing image: 2337_2_0 https://i.imgur.com/feiTqW7.jpg
# 2337_2_0 already exist
# Processing image: 2337_2_0 https://i.imgur.com/Vm8vqhO.jpg
# 2337_2_0 already exist
# start article: [正妹] Day3 要他命-吉岡里帆
# Processing image: 2337_3_0 http://i.imgur.com/0JTERHb.jpg
# save 2337_3_0
# Processing image: 2337_3_0 http://i.imgur.com/KBu2wAr.jpg
# 2337_3_0 already exist
# Processing image: 2337_3_0 http://i.imgur.com/Z33mlL6.jpg
# 2337_3_0 already exist
# Processing image: 2337_3_0 http://i.imgur.com/ZbvsORr.jpg
# 2337_3_0 already exist
# Processing image: 2337_3_0 http://i.imgur.com/pr5EQEj.jpg
# 2337_3_0 already exist
# Processing image: 2337_3_0 http://i.imgur.com/jAzGeVt.jpg
# 2337_3_0 already exist
# Processing image: 2337_3_0 http://i.imgur.com/hRCip9d.jpg
# 2337_3_0 already exist
# Processing image: 2337_3_0 http://i.imgur.com/uo4TPk7.jpg
# 2337_3_0 already exist
# Processing image: 2337_3_0 http://i.imgur.com/VOTMab4.jpg
# 2337_3_0 already exist
# Processing image: 2337_3_0 http://i.imgur.com/OPcsDJd.jpg
# 2337_3_0 already exist
# Processing image: 2337_3_0 http://i.imgur.com/wWF1OrW.jpg
# 2337_3_0 already exist
# Processing image: 2337_3_0 http://i.imgur.com/irdPS6o.jpg
# 2337_3_0 already exist
# Processing image: 2337_3_0 http://i.imgur.com/XJZLCwX.jpg
# 2337_3_0 already exist
# Processing image: 2337_3_0 http://i.imgur.com/6GbiHdY.jpg
# 2337_3_0 already exist
# Processing image: 2337_3_0 http://i.imgur.com/pFeyqkt.jpg
# 2337_3_0 already exist
# Processing image: 2337_3_0 http://i.imgur.com/xfc2wkC.jpg
# 2337_3_0 already exist
# Processing image: 2337_3_0 http://i.imgur.com/OF9BxeQ.jpg
# 2337_3_0 already exist
# Processing image: 2337_3_0 http://i.imgur.com/KYVT5qy.jpg
# 2337_3_0 already exist
# Processing image: 2337_3_0 http://i.imgur.com/XU2K4Sx.jpg
# 2337_3_0 already exist
# start article: [正妹] 鄰家
# Processing image: 2337_4_0 https://i.imgur.com/EZUtSCD.jpg
# save 2337_4_0
# Processing image: 2337_4_0 https://i.imgur.com/VmWFc66.jpg
# 2337_4_0 already exist
# Processing image: 2337_4_0 https://i.imgur.com/kWiIuqz.jpg
# 2337_4_0 already exist
# Processing image: 2337_4_0 https://i.imgur.com/qjogwlp.jpg
# 2337_4_0 already exist
# Processing image: 2337_4_0 https://i.imgur.com/GLSaF6R.jpg
# 2337_4_0 already exist
# start article: [正妹] 菜乃花 溫泉入浴
# Processing image: 2337_5_0 https://i.imgur.com/2MD0YxY.jpg
# save 2337_5_0
# Processing image: 2337_5_0 https://i.imgur.com/4zFChKr.jpg
# 2337_5_0 already exist
# Processing image: 2337_5_0 https://i.imgur.com/2OmLw2D.jpg
# 2337_5_0 already exist
# Processing image: 2337_5_0 https://i.imgur.com/7a5TjXc.jpg
# 2337_5_0 already exist
# Processing image: 2337_5_0 https://i.imgur.com/5bxU2Hy.jpg
# 2337_5_0 already exist
# Processing image: 2337_5_0 https://i.imgur.com/CDPLtcI.jpg
# 2337_5_0 already exist
# Processing image: 2337_5_0 https://i.imgur.com/QmdFXl5.jpg
# 2337_5_0 already exist
# Processing image: 2337_5_0 https://i.imgur.com/Un05sDz.jpg
# 2337_5_0 already exist
# Processing image: 2337_5_0 https://i.imgur.com/BeCCjJJ.jpg
# 2337_5_0 already exist
# Processing image: 2337_5_0 https://i.imgur.com/RSH9FPv.jpg
# 2337_5_0 already exist
# Processing image: 2337_5_0 https://i.imgur.com/gbYnzA0.jpg
# 2337_5_0 already exist
# Processing image: 2337_5_0 https://i.imgur.com/knlkspQ.jpg
# 2337_5_0 already exist
# Processing image: 2337_5_0 https://i.imgur.com/XlcwGCG.jpg
# 2337_5_0 already exist
# Processing image: 2337_5_0 https://i.imgur.com/GZ5uBgg.jpg
# 2337_5_0 already exist
# Processing image: 2337_5_0 https://i.imgur.com/OIX8SIE.jpg
# 2337_5_0 already exist
# Processing image: 2337_5_0 https://i.imgur.com/iyFfgwo.jpg
# 2337_5_0 already exist
# Processing image: 2337_5_0 https://i.imgur.com/747LIDK.jpg
# 2337_5_0 already exist
# Processing image: 2337_5_0 https://i.imgur.com/0bUT1DF.jpg
# 2337_5_0 already exist
# Processing image: 2337_5_0 https://i.imgur.com/G7kvbl4.jpg
# 2337_5_0 already exist
# start article: [正妹] 網路上看到的好看Coser
# Processing image: 2337_6_0 https://i.imgur.com/4jr4zzx.jpg
# save 2337_6_0
# Processing image: 2337_6_0 https://i.imgur.com/U5stXV0.jpg
# 2337_6_0 already exist
# Processing image: 2337_6_0 https://i.imgur.com/3ztZELI.jpg
# 2337_6_0 already exist
# Processing image: 2337_6_0 https://i.imgur.com/08PDDag.jpg
# 2337_6_0 already exist
# Processing image: 2337_6_0 https://i.imgur.com/Oi2R0P9.jpg
# 2337_6_0 already exist
# Processing image: 2337_6_0 https://i.imgur.com/IkartbP.jpg
# 2337_6_0 already exist
# Processing image: 2337_6_0 https://i.imgur.com/crb7YYG.jpg
# 2337_6_0 already exist
# start article: [正妹] 華村あすか
# Processing image: 2337_8_0 https://i.imgur.com/i6DlJTW.jpg
# save 2337_8_0
# Processing image: 2337_8_0 https://i.imgur.com/0uZ6AQl.jpg
# 2337_8_0 already exist
# Processing image: 2337_8_0 https://i.imgur.com/6a4yrab.jpg
# 2337_8_0 already exist
# Processing image: 2337_8_0 https://i.imgur.com/nNFbKbf.jpg
# 2337_8_0 already exist
# Processing image: 2337_8_0 https://i.imgur.com/TQVAAoJ.jpg
# 2337_8_0 already exist
# Processing image: 2337_8_0 https://i.imgur.com/KQk5clN.jpg
# 2337_8_0 already exist
# Processing image: 2337_8_0 https://i.imgur.com/X48YCUD.jpg
# 2337_8_0 already exist
# Processing image: 2337_8_0 https://i.imgur.com/QdtXpZq.jpg
# 2337_8_0 already exist
# Processing image: 2337_8_0 https://i.imgur.com/iyj99BP.jpg
# 2337_8_0 already exist
# start article: [正妹] 我覺得後面滑水道不錯好玩……
# Processing image: 2337_9_0 https://i.imgur.com/6d5w1hS.jpg
# save 2337_9_0
# start article: [正妹] 汽車業務
# start article: [正妹] 武田玲奈
# Processing image: 2337_12_0 http://i.imgur.com/ec6U7r1.jpg
# save 2337_12_0
# Processing image: 2337_12_0 http://i.imgur.com/W0vzmpv.jpg
# 2337_12_0 already exist
# Processing image: 2337_12_0 http://i.imgur.com/ra1CX46.jpg
# 2337_12_0 already exist
# Processing image: 2337_12_0 http://i.imgur.com/Jd7LB7z.jpg
# 2337_12_0 already exist
# Processing image: 2337_12_0 http://i.imgur.com/0HXZxvz.jpg
# 2337_12_0 already exist
# Processing image: 2337_12_0 http://i.imgur.com/aESfk1G.jpg
# 2337_12_0 already exist
# Processing image: 2337_12_0 http://i.imgur.com/izQq6zB.jpg
# 2337_12_0 already exist
# Processing image: 2337_12_0 http://i.imgur.com/jnWyNhi.jpg
# 2337_12_0 already exist
# Processing image: 2337_12_0 http://i.imgur.com/R25PGCS.jpg
# 2337_12_0 already exist
# Processing image: 2337_12_0 http://i.imgur.com/RarONXG.jpg
# 2337_12_0 already exist
# Processing image: 2337_12_0 http://i.imgur.com/Tt8ApPl.jpg
# 2337_12_0 already exist
# Processing image: 2337_12_0 http://i.imgur.com/QMgBGXn.jpg
# 2337_12_0 already exist
# start article: [正妹] 姊妹二張
# Processing image: 2337_14_0 https://i.imgur.com/wujXfs6.jpg
# save 2337_14_0
# Processing image: 2337_14_0 https://i.imgur.com/X9zYRNG.jpg
# 2337_14_0 already exist
# start article: [正妹] 應該算可愛
# Processing image: 2337_15_0 https://i.imgur.com/pV8kOZI.jpg
# save 2337_15_0
# Processing image: 2337_15_0 https://i.imgur.com/3URIfvD.jpg
# 2337_15_0 already exist
# Processing image: 2337_15_0 https://i.imgur.com/hgOHdlE.jpg
# 2337_15_0 already exist
# Processing image: 2337_15_0 https://i.imgur.com/A7Q7dC6.jpg
# 2337_15_0 already exist
# Processing image: 2337_15_0 https://i.imgur.com/YhAM94w.jpg
# 2337_15_0 already exist
# Processing image: 2337_15_0 https://i.imgur.com/5G8lBiO.jpg
# 2337_15_0 already exist
# Processing image: 2337_15_0 https://i.imgur.com/96Au6Zb.jpg
# 2337_15_0 already exist
# Processing image: 2337_15_0 https://i.imgur.com/gUc0Pvx.jpg
# 2337_15_0 already exist
# Processing image: 2337_15_0 https://i.imgur.com/wPxFItb.jpg
# 2337_15_0 already exist
# Processing image: 2337_15_0 https://i.imgur.com/bC7hUhg.jpg
# 2337_15_0 already exist
# Processing image: 2337_15_0 https://i.imgur.com/EpJWjVi.jpg
# 2337_15_0 already exist
# start article: [正妹] 韓國車模
# Processing image: 2337_16_0 https://i.imgur.com/UgImxs6.jpg
# save 2337_16_0
# Processing image: 2337_16_0 https://i.imgur.com/gHQzaGg.jpg
# 2337_16_0 already exist
# Processing image: 2337_16_0 https://i.imgur.com/GuoL2K1.jpg
# 2337_16_0 already exist
# Processing image: 2337_16_0 https://i.imgur.com/MjNGqTn.jpg
# 2337_16_0 already exist
# Processing image: 2337_16_0 https://i.imgur.com/h6jks42.jpg
# 2337_16_0 already exist
# start article: [正妹] 芬蘭ASMR妹子
# Processing image: 2337_17_0 https://i.imgur.com/eLJ6iO8.jpg
# save 2337_17_0
# Processing image: 2337_17_0 https://i.imgur.com/jssp9YZ.jpg
# 2337_17_0 already exist
# Processing image: 2337_17_0 https://i.imgur.com/OZdl8A3.jpg
# 2337_17_0 already exist
# Processing image: 2337_17_0 https://i.imgur.com/uJvAXEW.jpg
# 2337_17_0 already exist
# Processing image: 2337_17_0 https://i.imgur.com/nauZ98j.jpg
# 2337_17_0 already exist
# Processing image: 2337_17_0 https://i.imgur.com/hFrCctB.jpg
# 2337_17_0 already exist
# Processing image: 2337_17_0 https://i.imgur.com/RpQmjNe.jpg
# 2337_17_0 already exist
# Processing image: 2337_17_0 https://i.imgur.com/Cks5Lnj.jpg
# 2337_17_0 already exist
# Processing image: 2337_17_0 https://i.imgur.com/oZBqCA6.jpg
# 2337_17_0 already exist
# Processing image: 2337_17_0 https://i.imgur.com/fFClnWP.jpg
# 2337_17_0 already exist
# Processing index: 2336
# Processing article: M.1512924270.A.323
# Processing article: M.1512957255.A.3F0
# Processing article: M.1512959748.A.5D5
# Processing article: M.1512962133.A.A26
# Processing article: M.1512962566.A.D80
# Processing article: M.1512968318.A.B57
# Processing article: M.1512970243.A.59B
# Processing article: M.1512971592.A.05B
# Processing article: M.1512976677.A.C51
# Processing article: M.1512978043.A.7F7
# Processing article: M.1512980408.A.3F2
# Processing article: M.1512981668.A.FCD
# Processing article: M.1512981952.A.9EA
# Processing article: M.1512982859.A.7EE
# Processing article: M.1512983323.A.EF5
# Processing article: M.1512986737.A.75E
# Processing article: M.1512987160.A.BFA
# Processing article: M.1512989545.A.3FA
# Processing article: M.1512992884.A.75C
# Processing article: M.1512995500.A.3F9
# ['M.1512957255.A.3F0', 'M.1512959748.A.5D5', 'M.1512962133.A.A26', 'M.1512962566.A.D80']
# start article: [正妹] RaMu ラム
# Processing image: 2336_3_0 https://i.imgur.com/N1RWVcg.jpg
# save 2336_3_0
# Processing image: 2336_3_0 https://i.imgur.com/UpTdTzR.jpg
# 2336_3_0 already exist
# Processing image: 2336_3_0 https://i.imgur.com/0VFvAPp.jpg
# 2336_3_0 already exist
# Processing image: 2336_3_0 https://i.imgur.com/tQtjR7F.jpg
# 2336_3_0 already exist
# Processing image: 2336_3_0 https://i.imgur.com/d6L43VH.jpg
# 2336_3_0 already exist
# Processing image: 2336_3_0 https://i.imgur.com/gBhj1W3.jpg
# 2336_3_0 already exist
# Processing image: 2336_3_0 https://i.imgur.com/gRo7LUI.jpg
# 2336_3_0 already exist
# Processing image: 2336_3_0 https://i.imgur.com/cIMGu9M.jpg
# 2336_3_0 already exist
# Processing image: 2336_3_0 https://i.imgur.com/wzgu5P7.jpg
# 2336_3_0 already exist
# start article: [正妹] 要你命系列-白石麻衣
# Processing image: 2336_4_0 http://i.imgur.com/xLXuOjS.jpg
# save 2336_4_0
# Processing image: 2336_4_0 http://i.imgur.com/RhgbOJW.jpg
# 2336_4_0 already exist
# Processing image: 2336_4_0 http://i.imgur.com/MpCyzw2.jpg
# 2336_4_0 already exist
# Processing image: 2336_4_0 http://i.imgur.com/08z3UjW.jpg
# 2336_4_0 already exist
# Processing image: 2336_4_0 http://i.imgur.com/cJJm6Rr.jpg
# 2336_4_0 already exist
# Processing image: 2336_4_0 http://i.imgur.com/ZoOQlVu.jpg
# 2336_4_0 already exist
# Processing image: 2336_4_0 http://i.imgur.com/DsZQYgi.jpg
# 2336_4_0 already exist
# Processing image: 2336_4_0 http://i.imgur.com/IrPlCCe.jpg
# 2336_4_0 already exist
# Processing image: 2336_4_0 http://i.imgur.com/Q4uTaEW.jpg
# 2336_4_0 already exist
# Processing image: 2336_4_0 http://i.imgur.com/M8XFpT4.jpg
# 2336_4_0 already exist
# Processing image: 2336_4_0 http://i.imgur.com/39nfW9r.jpg
# 2336_4_0 already exist
# Processing image: 2336_4_0 http://i.imgur.com/2hPjjx4.jpg
# 2336_4_0 already exist
# Processing image: 2336_4_0 http://i.imgur.com/kD8Uqa8.jpg
# 2336_4_0 already exist
# Processing image: 2336_4_0 http://i.imgur.com/LgIBXsw.jpg
# 2336_4_0 already exist
# Processing image: 2336_4_0 http://i.imgur.com/ABjxOvc.jpg
# 2336_4_0 already exist
# start article: [正妹] Day2 要你命-玉置成實
# Processing image: 2336_7_0 http://i.imgur.com/jGnlGqT.jpg
# save 2336_7_0
# Processing image: 2336_7_0 http://i.imgur.com/FL7mDA4.jpg
# 2336_7_0 already exist
# Processing image: 2336_7_0 http://i.imgur.com/CoGeSgN.jpg
# 2336_7_0 already exist
# Processing image: 2336_7_0 http://i.imgur.com/LgBbWHo.jpg
# 2336_7_0 already exist
# Processing image: 2336_7_0 http://i.imgur.com/occ9Aby.jpg
# 2336_7_0 already exist
# Processing image: 2336_7_0 http://i.imgur.com/sMewyDV.jpg
# 2336_7_0 already exist
# Processing image: 2336_7_0 http://i.imgur.com/f9BPdga.jpg
# 2336_7_0 already exist
# Processing image: 2336_7_0 http://i.imgur.com/PiBQ6ix.jpg
# 2336_7_0 already exist
# Processing image: 2336_7_0 http://i.imgur.com/5eLF29h.jpg
# 2336_7_0 already exist
# Processing image: 2336_7_0 http://i.imgur.com/apTxkju.jpg
# 2336_7_0 already exist
# Processing image: 2336_7_0 http://i.imgur.com/yY3B1X2.jpg
# 2336_7_0 already exist
# Processing image: 2336_7_0 http://i.imgur.com/xqTKfV5.jpg
# 2336_7_0 already exist
# Processing image: 2336_7_0 http://i.imgur.com/elDN5kA.jpg
# 2336_7_0 already exist
# Processing image: 2336_7_0 http://i.imgur.com/mKnT3AK.jpg
# 2336_7_0 already exist
# Processing image: 2336_7_0 http://i.imgur.com/0OJLzq3.jpg
# 2336_7_0 already exist
# Processing image: 2336_7_0 http://i.imgur.com/GXWYyOV.jpg
# 2336_7_0 already exist
# start article: [正妹] 長澤茉里奈 溫泉入浴
# Processing image: 2336_8_0 https://i.imgur.com/HyCsX3I.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-053cebec55a6> in <module>()
#      10             urls = re.findall('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', content)
#      11             print("start article:",titles[i])
# ---> 12             download_urls(urls,article_id,INDEX,i,FOLDER)
#      13         i=i+1
#      14     INDEX=INDEX-1
#
# <ipython-input-25-be080fbfdc43> in download_urls(urls, article_id, index, article_num, folder)
#       7             downloader = ImgurDownloader(url,FOLDER,filename)
#       8             if (not os.path.exists(folder+"/"+filename+".jpg")) and (not os.path.exists(folder+"/"+filename+".png")):
# ----> 9                 downloader.on_image_download(downloader.save_images())
#      10                 print("save",filename)
#      11             else:
#
# ~\evan\Learning\python\ptt_beauty\env\src\imgurdownloader.py in save_images(self, foldername)
#     332                 os.path.join(
#     333                     os.path.dirname(path),
# --> 334                     slugify(os.path.basename(path))))
#     335
#     336             downloaded += dl
#
# ~\evan\Learning\python\ptt_beauty\env\src\imgurdownloader.py in direct_download(self, image_url, path)
#     362         else:
#     363             try:
# --> 364                 request = urllib.request.urlopen(image_url)
#     365                 redirect_url = request.geturl()
#     366
#
# c:\program files\python35\Lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     161     else:
#     162         opener = _opener
# --> 163     return opener.open(url, data, timeout)
#     164
#     165 def install_opener(opener):
#
# c:\program files\python35\Lib\urllib\request.py in open(self, fullurl, data, timeout)
#     464             req = meth(req)
#     465
# --> 466         response = self._open(req, data)
#     467
#     468         # post-process response
#
# c:\program files\python35\Lib\urllib\request.py in _open(self, req, data)
#     482         protocol = req.type
#     483         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 484                                   '_open', req)
#     485         if result:
#     486             return result
#
# c:\program files\python35\Lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     442         for handler in handlers:
#     443             func = getattr(handler, meth_name)
# --> 444             result = func(*args)
#     445             if result is not None:
#     446                 return result
#
# c:\program files\python35\Lib\urllib\request.py in http_open(self, req)
#    1280
#    1281     def http_open(self, req):
# -> 1282         return self.do_open(http.client.HTTPConnection, req)
#    1283
#    1284     http_request = AbstractHTTPHandler.do_request_
#
# c:\program files\python35\Lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1255             except OSError as err: # timeout error
#    1256                 raise URLError(err)
# -> 1257             r = h.getresponse()
#    1258         except:
#    1259             h.close()
#
# c:\program files\python35\Lib\http\client.py in getresponse(self)
#    1196         try:
#    1197             try:
# -> 1198                 response.begin()
#    1199             except ConnectionError:
#    1200                 self.close()
#
# c:\program files\python35\Lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# c:\program files\python35\Lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# c:\program files\python35\Lib\socket.py in readinto(self, b)
#     574         while True:
#     575             try:
# --> 576                 return self._sock.recv_into(b)
#     577             except timeout:
#     578                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
# !jupyter nbconvert --to script PttBeautyDownload.ipynb
# Out:
# [NbConvertApp] Converting notebook PttBeautyDownload.ipynb to script
# [NbConvertApp] Writing 2146 bytes to PttBeautyDownload.py
