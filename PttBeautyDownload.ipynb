# %%
# -*- coding: MS950 -*-
import unittest
from PttWebCrawler.crawler import *
import codecs, json, os
from imgurdownloader import *
import re,os
from connectSQL import *

# %%
FROM=2250
FOLDER="newDownload"
TO=2200

# %%
def get_articles(index):
    c = PttWebCrawler(as_lib=True)
    t=c.parse_articles(index,index, 'beauty')
    return (t)

# %%
def get_contents(t):
    with open(t, 'r',encoding = 'utf8') as f:
        data=json.load(f)
    contents=[]
    titles=[]
    article_id=[]
    for article in data['articles']:
        contents.append(article['content'])
        titles.append(article['article_title'])
        article_id.append(article['article_id'])
    print(article_id[1:5])
    return(contents,titles,article_id)

# %%
def download_urls(urls,article_id,index,article_num,folder):
    j=0
    for url in urls:
        if url.startswith(('https://i.imgur','http://i.imgur','https://imgur','http://imgur')):# or url.startswith('http://imgur') or url.startswith('https://imgur') or url.startswith('http://i.imgur'):
            filename=str(index)+"_"+str(article_num)+"_"+str(j)
            print("Processing image:",filename,url)
            downloader = ImgurDownloader(url,FOLDER,filename)
            if (not os.path.exists(folder+"/"+filename+".jpg")) and (not os.path.exists(folder+"/"+filename+".png")):
                downloader.on_image_download(downloader.save_images())
                connectSQL(filename,article_id[article_num])
                print("save",filename)
            else:
                print(filename,"already exist")
        j=j+1

# %%
INDEX=FROM
while(INDEX>TO):
    t=".\\beauty-"+str(INDEX)+"-"+str(INDEX)+".json"
    if not os.path.exists(t):
        t=get_articles(INDEX)
    contents,titles,article_id=get_contents(t)
    i=0
    for content in contents:
        if titles[i].startswith('[正妹]'):
            urls = re.findall('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', content)
            print("start article:",titles[i])
            download_urls(urls,article_id,INDEX,i,FOLDER)
        i=i+1
    INDEX=INDEX-1
    if INDEX!=FROM:
        os.remove(t)
# Out:
# ['M.1504751215.A.052', 'M.1504757263.A.F25', 'M.1504759131.A.902', 'M.1504763490.A.FC9']
# start article: [正妹] 斗魚主播陳一發
# start article: [正妹] Olesya Rulin
# Processing image: 2250_1_0 https://imgur.com/yVldhc8
# 2250_1_0 already exist
# Processing image: 2250_1_1 https://imgur.com/gyquxwT
# save 2250_1_1
# Processing image: 2250_1_2 https://imgur.com/ekHR8EX
# save 2250_1_2
# Processing image: 2250_1_3 https://imgur.com/OBIWWGo
# save 2250_1_3
# Processing image: 2250_1_4 https://imgur.com/zaAmA5U
# save 2250_1_4
# start article: [正妹] 人美心更美 郭婞淳
# Processing image: 2250_3_0 https://imgur.com/a/gWMOa
# 2250_3_0 already exist
# start article: [正妹] 洋妞
# Processing image: 2250_5_0 https://i.imgur.com/zvCIuB8.jpg
# save 2250_5_0
# Processing image: 2250_5_1 https://i.imgur.com/BDmn5rn.jpg
# save 2250_5_1
# Processing image: 2250_5_2 https://i.imgur.com/XFrRtPT.jpg
# save 2250_5_2
# Processing image: 2250_5_3 https://i.imgur.com/pUDUAdc.jpg
# save 2250_5_3
# Processing image: 2250_5_4 https://i.imgur.com/qMzdjJh.jpg
# save 2250_5_4
# Processing image: 2250_5_5 https://i.imgur.com/WfbxbKx.jpg
# save 2250_5_5
# Processing image: 2250_5_6 https://i.imgur.com/THkufFQ.jpg
# save 2250_5_6
# Processing image: 2250_5_7 https://i.imgur.com/F74ljeh.jpg
# save 2250_5_7
# Processing image: 2250_5_8 https://i.imgur.com/BGOikkl.jpg
# save 2250_5_8
# ['M.1504640882.A.FF8', 'M.1504668992.A.B1D', 'M.1504671065.A.9C6', 'M.1504672689.A.5CE']
# start article: [正妹] 甜中帶兇
# Processing image: 2249_0_0 http://i.imgur.com/gqptxII.jpg
# save 2249_0_0
# Processing image: 2249_0_1 http://i.imgur.com/JL3JAbO.jpg
# save 2249_0_1
# Processing image: 2249_0_2 http://i.imgur.com/E49AfRA.jpg
# save 2249_0_2
# Processing image: 2249_0_3 http://i.imgur.com/WMvVgNB.jpg
# save 2249_0_3
# Processing image: 2249_0_4 http://i.imgur.com/HIVVAIU.jpg
# save 2249_0_4
# start article: [正妹] OH 給妳我的心 為什麼妳卻給我了孤寂
# Processing image: 2249_1_0 https://i.imgur.com/xw6gp0L.jpg
# save 2249_1_0
# Processing image: 2249_1_1 https://i.imgur.com/kNSY3PU.jpg
# save 2249_1_1
# Processing image: 2249_1_2 https://i.imgur.com/ClnCQto.jpg
# save 2249_1_2
# Processing image: 2249_1_3 https://i.imgur.com/WKPOQpy.jpg
# save 2249_1_3
# Processing image: 2249_1_4 https://i.imgur.com/ih1xFwN.jpg
# save 2249_1_4
# Processing image: 2249_1_5 https://i.imgur.com/rjhvwlE.jpg
# save 2249_1_5
# Processing image: 2249_1_6 https://i.imgur.com/6oRvFgj.jpg
# save 2249_1_6
# Processing image: 2249_1_7 https://i.imgur.com/6vrnAwi.jpg
# save 2249_1_7
# Processing image: 2249_1_8 https://i.imgur.com/NMLfHPN.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-053cebec55a6> in <module>()
#      10             urls = re.findall('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', content)
#      11             print("start article:",titles[i])
# ---> 12             download_urls(urls,article_id,INDEX,i,FOLDER)
#      13         i=i+1
#      14     INDEX=INDEX-1
#
# <ipython-input-36-f7a6db4bec5b> in download_urls(urls, article_id, index, article_num, folder)
#       7             downloader = ImgurDownloader(url,FOLDER,filename)
#       8             if (not os.path.exists(folder+"/"+filename+".jpg")) and (not os.path.exists(folder+"/"+filename+".png")):
# ----> 9                 downloader.on_image_download(downloader.save_images())
#      10                 connectSQL(filename,article_id[article_num])
#      11                 print("save",filename)
#
# ~\evan\Learning\python\ptt_beauty\env\src\imgurdownloader.py in save_images(self, foldername)
#     332                 os.path.join(
#     333                     os.path.dirname(path),
# --> 334                     slugify(os.path.basename(path))))
#     335
#     336             downloaded += dl
#
# ~\evan\Learning\python\ptt_beauty\env\src\imgurdownloader.py in direct_download(self, image_url, path)
#     362         else:
#     363             try:
# --> 364                 request = urllib.request.urlopen(image_url)
#     365                 redirect_url = request.geturl()
#     366
#
# c:\program files\python35\Lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     161     else:
#     162         opener = _opener
# --> 163     return opener.open(url, data, timeout)
#     164
#     165 def install_opener(opener):
#
# c:\program files\python35\Lib\urllib\request.py in open(self, fullurl, data, timeout)
#     464             req = meth(req)
#     465
# --> 466         response = self._open(req, data)
#     467
#     468         # post-process response
#
# c:\program files\python35\Lib\urllib\request.py in _open(self, req, data)
#     482         protocol = req.type
#     483         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 484                                   '_open', req)
#     485         if result:
#     486             return result
#
# c:\program files\python35\Lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     442         for handler in handlers:
#     443             func = getattr(handler, meth_name)
# --> 444             result = func(*args)
#     445             if result is not None:
#     446                 return result
#
# c:\program files\python35\Lib\urllib\request.py in http_open(self, req)
#    1280
#    1281     def http_open(self, req):
# -> 1282         return self.do_open(http.client.HTTPConnection, req)
#    1283
#    1284     http_request = AbstractHTTPHandler.do_request_
#
# c:\program files\python35\Lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1255             except OSError as err: # timeout error
#    1256                 raise URLError(err)
# -> 1257             r = h.getresponse()
#    1258         except:
#    1259             h.close()
#
# c:\program files\python35\Lib\http\client.py in getresponse(self)
#    1196         try:
#    1197             try:
# -> 1198                 response.begin()
#    1199             except ConnectionError:
#    1200                 self.close()
#
# c:\program files\python35\Lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# c:\program files\python35\Lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# c:\program files\python35\Lib\socket.py in readinto(self, b)
#     574         while True:
#     575             try:
# --> 576                 return self._sock.recv_into(b)
#     577             except timeout:
#     578                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
# !jupyter nbconvert --to script PttBeautyDownload.ipynb
# Out:
# [NbConvertApp] Converting notebook PttBeautyDownload.ipynb to script
# [NbConvertApp] Writing 2286 bytes to PttBeautyDownload.py
