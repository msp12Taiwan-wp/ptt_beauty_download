# %%
# -*- coding: MS950 -*-
import unittest
from PttWebCrawler.crawler import *
import codecs, json, os
from imgurdownloader import *
import re,os
from connectSQL import *

# %%
FROM=2200
FOLDER="newDownload"
TO=2150

# %%
def get_articles(index):
    c = PttWebCrawler(as_lib=True)
    t=c.parse_articles(index,index, 'beauty')
    return (t)

# %%
def get_contents(t):
    with open(t, 'r',encoding = 'utf8') as f:
        data=json.load(f)
    contents=[]
    titles=[]
    article_id=[]
    for article in data['articles']:
        contents.append(article['content'])
        titles.append(article['article_title'])
        article_id.append(article['article_id'])
    print(article_id[1:5])
    return(contents,titles,article_id)

# %%
def download_urls(urls,article_id,index,article_num,folder):
    j=0
    conn,cursor=connectSQL()
    for url in urls:
        if url.startswith(('https://i.imgur','http://i.imgur','https://imgur','http://imgur')):# or url.startswith('http://imgur') or url.startswith('https://imgur') or url.startswith('http://i.imgur'):
            filename=str(index)+"_"+str(article_num)+"_"+str(j)
            print("Processing image:",filename,url)
            downloader = ImgurDownloader(url,FOLDER,filename)
            if (not os.path.exists(folder+"/"+filename+".jpg")) and (not os.path.exists(folder+"/"+filename+".png")):
                downloader.on_image_download(downloader.save_images())
                insertSQL(conn,cursor,filename+".jpg",article_id[article_num])
#                 connectSQL(filename+".jpg",article_id[article_num])
                print("save",filename)
            else:
                print(filename,"already exist")
        j=j+1
    disconnectSQL(conn)

# %%
INDEX=FROM
while(INDEX>TO):
    t=".\\beauty-"+str(INDEX)+"-"+str(INDEX)+".json"
    if not os.path.exists(t):
        t=get_articles(INDEX)
    contents,titles,article_id=get_contents(t)
    i=0
    for content in contents:
        if titles[i].startswith('[正妹]'):
            urls = re.findall('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', content)
            print("start article:",titles[i])
            download_urls(urls,article_id,INDEX,i,FOLDER)
        i=i+1
    INDEX=INDEX-1
    if INDEX!=FROM:
        os.remove(t)
# Out:
# Processing index: 2200
# Processing article: M.1499790734.A.833
# Processing article: M.1499817685.A.007
# Processing article: M.1499826430.A.6BC
# Processing article: M.1499833754.A.4BF
# Processing article: M.1499835900.A.9D7
# Processing article: M.1499836604.A.9FD
# Processing article: M.1499838828.A.2FE
# Processing article: M.1499839723.A.12E
# Processing article: M.1499840145.A.342
# Processing article: M.1499843437.A.911
# Processing article: M.1499845680.A.4EE
# Processing article: M.1499846911.A.560
# Processing article: M.1499848382.A.C19
# Processing article: M.1499850999.A.E8A
# Processing article: M.1499859090.A.DDA
# Processing article: M.1499864068.A.3DE
# Processing article: M.1499866815.A.5AD
# Processing article: M.1499866939.A.04D
# Processing article: M.1499871405.A.AF1
# Processing article: M.1499871669.A.886
# ['M.1499817685.A.007', 'M.1499826430.A.6BC', 'M.1499833754.A.4BF', 'M.1499835900.A.9D7']
# start article: [正妹] 橋本環奈
# Processing image: 2200_0_0 http://i.imgur.com/8vIcXNx.png
# 2200_0_0 already exist
# Processing image: 2200_0_1 http://i.imgur.com/0UE4np6.jpg
# 2200_0_1 already exist
# Processing image: 2200_0_2 http://i.imgur.com/Vi1Xvuu.jpg
# 2200_0_2 already exist
# Processing image: 2200_0_3 http://i.imgur.com/f20dwY9.jpg
# 2200_0_3 already exist
# Processing image: 2200_0_4 http://i.imgur.com/uIh1kX8.jpg
# 2200_0_4 already exist
# Processing image: 2200_0_5 http://i.imgur.com/mPJxAAa.jpg
# 2200_0_5 already exist
# Processing image: 2200_0_6 http://i.imgur.com/zijRRkK.jpg
# 2200_0_6 already exist
# Processing image: 2200_0_7 http://i.imgur.com/TuyeOd9.jpg
# 2200_0_7 already exist
# Processing image: 2200_0_8 http://i.imgur.com/aCQkViF.jpg
# save 2200_0_8
# start article: [正妹] 甜甜的
# Processing image: 2200_1_0 http://i.imgur.com/EJmDXoe.jpg
# 2200_1_0 already exist
# Processing image: 2200_1_1 http://i.imgur.com/qTGsc2R.jpg
# 2200_1_1 already exist
# Processing image: 2200_1_2 http://i.imgur.com/agmR5G8.jpg
# save 2200_1_2
# Processing image: 2200_1_3 http://i.imgur.com/ESlC275.jpg
# 2200_1_3 already exist
# Processing image: 2200_1_4 http://i.imgur.com/g72rmKw.jpg
# 2200_1_4 already exist
# Processing image: 2200_1_5 http://i.imgur.com/ssnqsPy.jpg
# 2200_1_5 already exist
# Processing image: 2200_1_6 http://i.imgur.com/TrZa5DB.jpg
# 2200_1_6 already exist
# start article: [正妹] 可愛嘟嘟臉
# Processing image: 2200_2_0 http://imgur.com/pTepCj7.jpg
# 2200_2_0 already exist
# Processing image: 2200_2_1 http://imgur.com/TK9q01a.jpg
# 2200_2_1 already exist
# Processing image: 2200_2_2 http://imgur.com/DmlpkC0.jpg
# 2200_2_2 already exist
# Processing image: 2200_2_3 http://imgur.com/yEhBbY8.jpg
# 2200_2_3 already exist
# Processing image: 2200_2_4 http://imgur.com/bKNEDwQ.jpg
# 2200_2_4 already exist
# Processing image: 2200_2_5 http://imgur.com/aONKgfr.jpg
# 2200_2_5 already exist
# start article: [正妹] 還不錯
# Processing image: 2200_3_0 http://i.imgur.com/KuNeeir.jpg
# 2200_3_0 already exist
# Processing image: 2200_3_1 http://i.imgur.com/OfxwDHj.jpg
# 2200_3_1 already exist
# Processing image: 2200_3_2 http://i.imgur.com/vwAG08K.jpg
# 2200_3_2 already exist
# Processing image: 2200_3_3 http://i.imgur.com/dk1x4sx.jpg
# 2200_3_3 already exist
# Processing image: 2200_3_4 http://i.imgur.com/KobJAcO.jpg
# 2200_3_4 already exist
# Processing image: 2200_3_5 http://i.imgur.com/8IgpmxX.jpg
# 2200_3_5 already exist
# start article: [正妹] 余霜
# Processing image: 2200_5_0 http://i.imgur.com/ulC6eAg.jpg
# 2200_5_0 already exist
# Processing image: 2200_5_1 http://i.imgur.com/emdFShB.jpg
# 2200_5_1 already exist
# Processing image: 2200_5_2 http://i.imgur.com/QxjBbm0.jpg
# 2200_5_2 already exist
# Processing image: 2200_5_3 http://i.imgur.com/uG6Tyt3.jpg
# 2200_5_3 already exist
# Processing image: 2200_5_4 http://i.imgur.com/11VFQi4.jpg
# 2200_5_4 already exist
# Processing image: 2200_5_5 http://i.imgur.com/XaNq8Bh.jpg
# 2200_5_5 already exist
# Processing image: 2200_5_6 http://i.imgur.com/8Qm3vU1.jpg
# 2200_5_6 already exist
# Processing image: 2200_5_7 http://i.imgur.com/6FTbJGt.jpg
# 2200_5_7 already exist
# Processing image: 2200_5_8 http://i.imgur.com/sImU4bz.jpg
# 2200_5_8 already exist
# Processing image: 2200_5_9 http://i.imgur.com/4YBn4pq.jpg
# 2200_5_9 already exist
# Processing image: 2200_5_10 http://i.imgur.com/2pNlFA6.jpg
# 2200_5_10 already exist
# start article: [正妹] 愛笑的女孩
# Processing image: 2200_6_0 http://i.imgur.com/HhH2xbW.jpg
# 2200_6_0 already exist
# Processing image: 2200_6_1 http://i.imgur.com/qoGkdoQ.jpg
# 2200_6_1 already exist
# Processing image: 2200_6_2 http://i.imgur.com/L4ITXXM.jpg
# 2200_6_2 already exist
# Processing image: 2200_6_3 http://i.imgur.com/e4HwdoK.jpg
# 2200_6_3 already exist
# Processing image: 2200_6_4 http://i.imgur.com/60ZVEh6.jpg
# 2200_6_4 already exist
# Processing image: 2200_6_5 http://i.imgur.com/kjnXcso.jpg
# 2200_6_5 already exist
# Processing image: 2200_6_6 http://i.imgur.com/VydYArS.jpg
# 2200_6_6 already exist
# Processing image: 2200_6_7 http://i.imgur.com/1rVR5Fy.jpg
# 2200_6_7 already exist
# Processing image: 2200_6_8 http://i.imgur.com/50KoyUu.jpg
# 2200_6_8 already exist
# start article: [正妹] 陋巷美女
# start article: [正妹] 鋼管
# Processing image: 2200_9_0 http://i.imgur.com/cQzIL44.jpg
# 2200_9_0 already exist
# Processing image: 2200_9_1 http://i.imgur.com/Qu4wEw9.jpg
# 2200_9_1 already exist
# Processing image: 2200_9_2 http://i.imgur.com/n1jVvqQ.jpg
# 2200_9_2 already exist
# Processing image: 2200_9_3 http://i.imgur.com/rTtAVQ1.jpg
# 2200_9_3 already exist
# Processing image: 2200_9_4 http://i.imgur.com/rULmv2v.jpg
# 2200_9_4 already exist
# Processing image: 2200_9_5 http://i.imgur.com/esKFxaW.png
# 2200_9_5 already exist
# start article: [正妹] 小畫家
# Processing image: 2200_10_0 http://i.imgur.com/undefined.jpg
# save 2200_10_0
# Processing image: 2200_10_1 http://i.imgur.com/Txpl50l.jpg
# 2200_10_1 already exist
# Processing image: 2200_10_2 http://i.imgur.com/8iO51Fi.jpg
# 2200_10_2 already exist
# Processing image: 2200_10_3 http://i.imgur.com/5Qe36iq.jpg
# 2200_10_3 already exist
# Processing image: 2200_10_4 http://i.imgur.com/OOLARAl.jpg
# 2200_10_4 already exist
# Processing image: 2200_10_5 http://i.imgur.com/ZZ4Yfhm.jpg
# 2200_10_5 already exist
# Processing image: 2200_10_6 http://i.imgur.com/CayqA7C.jpg
# 2200_10_6 already exist
# Processing image: 2200_10_7 http://i.imgur.com/a38FbAd.jpg
# save 2200_10_7
# start article: [正妹] 石原聰美
# Processing image: 2200_11_0 https://i.imgur.com/Omw7uC2.jpg
# 2200_11_0 already exist
# Processing image: 2200_11_1 https://i.imgur.com/uIRwAgN.jpg
# 2200_11_1 already exist
# Processing image: 2200_11_2 https://i.imgur.com/ZCzIkAW.jpg
# 2200_11_2 already exist
# Processing image: 2200_11_3 https://i.imgur.com/TyifMpK.jpg
# 2200_11_3 already exist
# Processing image: 2200_11_4 https://i.imgur.com/G54MnI2.jpg
# 2200_11_4 already exist
# Processing image: 2200_11_5 https://i.imgur.com/sh3Yxwv.jpg
# 2200_11_5 already exist
# Processing image: 2200_11_6 https://i.imgur.com/tVDEoi4.jpg
# 2200_11_6 already exist
# Processing image: 2200_11_7 https://i.imgur.com/7649RWf.jpg
# 2200_11_7 already exist
# Processing image: 2200_11_8 https://i.imgur.com/JBCmrgE.jpg
# 2200_11_8 already exist
# start article: [正妹] 甜美型運動正妹!
# Processing image: 2200_16_0 http://imgur.com/a/kSXqD
# 2200_16_0 already exist
# start article: [正妹] 中山女高
# Processing image: 2200_18_0 http://imgur.com/vA0yUqT
# 2200_18_0 already exist
# Processing image: 2200_18_1 http://imgur.com/bSYOxPg
# 2200_18_1 already exist
# Processing image: 2200_18_2 http://imgur.com/5HMBM3y
# 2200_18_2 already exist
# Processing image: 2200_18_3 http://imgur.com/EJGRJBm
# 2200_18_3 already exist
# Processing image: 2200_18_4 http://imgur.com/e7bmarL
# 2200_18_4 already exist
# Processing image: 2200_18_5 http://imgur.com/QP2SJ6h
# 2200_18_5 already exist
# Processing image: 2200_18_6 http://imgur.com/kUGMLls
# 2200_18_6 already exist
# Processing image: 2200_18_7 http://imgur.com/0lCPJEU
# 2200_18_7 already exist
# Processing image: 2200_18_8 http://imgur.com/Wyzh32v
# 2200_18_8 already exist
# Processing image: 2200_18_9 http://imgur.com/IClcT5a
# 2200_18_9 already exist
# Processing image: 2200_18_10 http://imgur.com/sXRUDdm
# 2200_18_10 already exist
# Processing image: 2200_18_11 http://imgur.com/MuG6urW
# 2200_18_11 already exist
# Processing image: 2200_18_12 http://imgur.com/18yvwja
# 2200_18_12 already exist
# Processing index: 2199
# Processing article: M.1499737722.A.816
# Processing article: M.1499746025.A.5E5
# Processing article: M.1499748000.A.2B2
# Processing article: M.1499748560.A.D37
# Processing article: M.1499750138.A.40C
# Processing article: M.1499750774.A.16E
# Processing article: M.1499750799.A.3EF
# Processing article: M.1499754681.A.4FA
# Processing article: M.1499760746.A.1C6
# Processing article: M.1499763964.A.EA5
# Processing article: M.1499765206.A.B25
# Processing article: M.1499767253.A.479
# Processing article: M.1499774715.A.4DF
# Processing article: M.1499776720.A.57E
# Processing article: M.1499781290.A.88C
# Processing article: M.1499782809.A.1B3
# Processing article: M.1499783486.A.1CD
# Processing article: M.1499785143.A.A98
# Processing article: M.1499786484.A.B9E
# Processing article: M.1499787821.A.01D
# ['M.1499746025.A.5E5', 'M.1499748000.A.2B2', 'M.1499748560.A.D37', 'M.1499750138.A.40C']
# start article: [正妹] 最簡單不過了
# Processing image: 2199_0_0 http://i.imgur.com/ALJOxjU.jpg
# 2199_0_0 already exist
# Processing image: 2199_0_1 http://i.imgur.com/A6GgX92.jpg
# 2199_0_1 already exist
# Processing image: 2199_0_2 http://i.imgur.com/9MgLA9C.jpg
# 2199_0_2 already exist
# Processing image: 2199_0_3 http://i.imgur.com/Falv1ZB.jpg
# 2199_0_3 already exist
# Processing image: 2199_0_4 http://i.imgur.com/YxPhXoQ.jpg
# 2199_0_4 already exist
# Processing image: 2199_0_5 http://i.imgur.com/ikF1sJf.jpg
# 2199_0_5 already exist
# Processing image: 2199_0_6 http://i.imgur.com/vhi9EHy.jpg
# 2199_0_6 already exist
# start article: [正妹] 好身形
# Processing image: 2199_1_0 http://imgur.com/Awf9sO2.jpg
# 2199_1_0 already exist
# Processing image: 2199_1_1 http://imgur.com/Gbi4xHX.jpg
# 2199_1_1 already exist
# Processing image: 2199_1_2 http://imgur.com/0qFg5pq.jpg
# 2199_1_2 already exist
# Processing image: 2199_1_3 http://imgur.com/Mmd9JUs.jpg
# 2199_1_3 already exist
# Processing image: 2199_1_4 http://imgur.com/TJYLNBK.jpg
# 2199_1_4 already exist
# Processing image: 2199_1_5 http://imgur.com/1rT9s2r.jpg
# 2199_1_5 already exist
# Processing image: 2199_1_6 http://imgur.com/72Jm8IB.jpg
# 2199_1_6 already exist
# Processing image: 2199_1_7 http://imgur.com/oLniT2d.jpg
# 2199_1_7 already exist
# Processing image: 2199_1_8 http://imgur.com/ez99K7o.jpg
# 2199_1_8 already exist
# Processing image: 2199_1_9 http://imgur.com/Bno2ssx.jpg
# 2199_1_9 already exist
# Processing image: 2199_1_10 http://imgur.com/TRLfheu.jpg
# 2199_1_10 already exist
# start article: [正妹] fb 看到的
# Processing image: 2199_4_0 http://i.imgur.com/UO6YcIM.jpg
# 2199_4_0 already exist
# Processing image: 2199_4_1 http://i.imgur.com/Lm9z9E9.jpg
# 2199_4_1 already exist
# Processing image: 2199_4_2 http://i.imgur.com/s3C9A46.jpg
# 2199_4_2 already exist
# Processing image: 2199_4_3 http://i.imgur.com/3qj21Gs.jpg
# 2199_4_3 already exist
# Processing image: 2199_4_4 http://i.imgur.com/VjeAjtz.jpg
# 2199_4_4 already exist
# start article: [正妹] FB上的假帳號
# Processing image: 2199_6_0 http://i.imgur.com/4QrX1o6.jpg
# 2199_6_0 already exist
# Processing image: 2199_6_1 http://i.imgur.com/4atcFAn.jpg
# 2199_6_1 already exist
# Processing image: 2199_6_2 http://i.imgur.com/hVGzwK7.jpg
# 2199_6_2 already exist
# Processing image: 2199_6_3 http://i.imgur.com/exRGFKM.jpg
# 2199_6_3 already exist
# Processing image: 2199_6_4 http://i.imgur.com/CVNKqed.jpg
# 2199_6_4 already exist
# Processing image: 2199_6_5 http://i.imgur.com/8sd2G9L.jpg
# 2199_6_5 already exist
# start article: [正妹] 巨大神奇寶貝
# Processing image: 2199_14_0 http://i.imgur.com/jYO3173.jpg
# 2199_14_0 already exist
# Processing image: 2199_14_1 http://i.imgur.com/8zaahcb.jpg
# 2199_14_1 already exist
# Processing image: 2199_14_2 http://i.imgur.com/sSMIEOP.jpg
# 2199_14_2 already exist
# Processing image: 2199_14_3 http://i.imgur.com/uPjphGz.jpg
# 2199_14_3 already exist
# start article: [正妹] 本土劇女星
# Processing image: 2199_17_0 http://imgur.com/gYL4A5p
# 2199_17_0 already exist
# Processing image: 2199_17_1 http://imgur.com/YuZiGjY
# 2199_17_1 already exist
# start article: [正妹] 清新可愛小隻馬
# Processing image: 2199_18_0 http://i.imgur.com/D9cPyjp.jpg
# 2199_18_0 already exist
# Processing image: 2199_18_1 http://i.imgur.com/FsiwWqt.jpg
# 2199_18_1 already exist
# Processing image: 2199_18_2 http://i.imgur.com/r9NAt8u.jpg
# 2199_18_2 already exist
# Processing image: 2199_18_3 http://i.imgur.com/ejo5tkd.jpg
# 2199_18_3 already exist
# Processing image: 2199_18_4 http://i.imgur.com/LA4vALS.jpg
# 2199_18_4 already exist
# Processing image: 2199_18_5 http://i.imgur.com/rlt2XPj.jpg
# 2199_18_5 already exist
# Processing image: 2199_18_6 http://i.imgur.com/Zhc7CWP.jpg
# 2199_18_6 already exist
# Processing image: 2199_18_7 http://i.imgur.com/uC881Ga.jpg
# 2199_18_7 already exist
# Processing image: 2199_18_8 http://i.imgur.com/cXEGPLP.jpg
# 2199_18_8 already exist
# Processing image: 2199_18_9 http://i.imgur.com/icYiZpP.jpg
# 2199_18_9 already exist
# start article: [正妹] 可以好好入眠了......
# Processing image: 2199_19_0 http://i.imgur.com/2mUlWor.jpg
# 2199_19_0 already exist
# Processing image: 2199_19_1 http://i.imgur.com/3huJQhd.jpg
# 2199_19_1 already exist
# Processing image: 2199_19_2 http://i.imgur.com/PZF44AS.jpg
# 2199_19_2 already exist
# Processing image: 2199_19_3 http://i.imgur.com/UAYU0SR.jpg
# 2199_19_3 already exist
# Processing image: 2199_19_4 http://i.imgur.com/tybSvTL.jpg
# 2199_19_4 already exist
# Processing image: 2199_19_5 http://i.imgur.com/UWC0JEn.jpg
# 2199_19_5 already exist
# Processing image: 2199_19_6 http://i.imgur.com/CBce0Tv.jpg
# 2199_19_6 already exist
# Processing image: 2199_19_7 http://i.imgur.com/6LirQYt.jpg
# 2199_19_7 already exist
# Processing image: 2199_19_8 http://i.imgur.com/4fERKct.jpg
# 2199_19_8 already exist
# Processing image: 2199_19_9 http://i.imgur.com/JP4I9YF.jpg
# 2199_19_9 already exist
# Processing image: 2199_19_10 http://i.imgur.com/nvH3WiI.jpg
# 2199_19_10 already exist
# Processing image: 2199_19_11 http://i.imgur.com/VQ8BmLe.jpg
# 2199_19_11 already exist
# Processing index: 2198
# Processing article: M.1499653887.A.C56
# Processing article: M.1499658886.A.654
# Processing article: M.1499664133.A.40C
# Processing article: M.1499667287.A.CC4
# Processing article: M.1499671438.A.614
# Processing article: M.1499675275.A.E64
# Processing article: M.1499677683.A.A46
# Processing article: M.1499678078.A.7A7
# Processing article: M.1499684731.A.26D
# Processing article: M.1499688561.A.DCD
# Processing article: M.1499693589.A.A2B
# Processing article: M.1499696636.A.095
# Processing article: M.1499699086.A.142
# Processing article: M.1499699320.A.D3A
# Processing article: M.1499701494.A.D0D
# Processing article: M.1499704450.A.301
# Processing article: M.1499704746.A.21A
# Processing article: M.1499731401.A.426
# Processing article: M.1499733684.A.BCF
# Processing article: M.1499734124.A.76D
# ['M.1499658886.A.654', 'M.1499664133.A.40C', 'M.1499667287.A.CC4', 'M.1499671438.A.614']
# start article: [正妹] 陽光般的笑容
# Processing image: 2198_0_0 http://i.imgur.com/sYqVpiM.jpg
# 2198_0_0 already exist
# Processing image: 2198_0_1 http://i.imgur.com/E1JJO7l.jpg
# 2198_0_1 already exist
# Processing image: 2198_0_2 http://i.imgur.com/aiEywmr.jpg
# 2198_0_2 already exist
# Processing image: 2198_0_3 http://i.imgur.com/ShYlN4S.jpg
# 2198_0_3 already exist
# Processing image: 2198_0_4 http://i.imgur.com/7gVASyE.jpg
# 2198_0_4 already exist
# Processing image: 2198_0_5 http://i.imgur.com/SK6A6na.jpg
# 2198_0_5 already exist
# Processing image: 2198_0_6 http://i.imgur.com/x6k7297.jpg
# 2198_0_6 already exist
# Processing image: 2198_0_7 http://i.imgur.com/n0Q2Ok4.jpg
# 2198_0_7 already exist
# Processing image: 2198_0_8 http://i.imgur.com/dLVwKch.jpg
# 2198_0_8 already exist
# Processing image: 2198_0_9 http://i.imgur.com/90Llsyw.jpg
# 2198_0_9 already exist
# start article: [正妹] 白皙清新
# Processing image: 2198_2_0 http://i.imgur.com/MwEt8f8.jpg
# 2198_2_0 already exist
# Processing image: 2198_2_1 http://i.imgur.com/vLSlBbG.jpg
# 2198_2_1 already exist
# Processing image: 2198_2_2 http://i.imgur.com/Cwe4l04.jpg
# 2198_2_2 already exist
# Processing image: 2198_2_3 http://i.imgur.com/6Ozc98J.jpg
# 2198_2_3 already exist
# Processing image: 2198_2_4 http://i.imgur.com/Pl3wrRc.jpg
# 2198_2_4 already exist
# Processing image: 2198_2_5 http://i.imgur.com/OJ7QmEX.jpg
# 2198_2_5 already exist
# Processing image: 2198_2_6 http://i.imgur.com/YNL8Qk5.jpg
# 2198_2_6 already exist
# start article: [正妹] 首po雖然只有側臉
# Processing image: 2198_3_0 http://i.imgur.com/LsIEFrb.jpg
# 2198_3_0 already exist
# start article: [正妹] 吉岡里帆（新圖）
# Processing image: 2198_6_0 http://imgur.com/e1c4m5Z
# 2198_6_0 already exist
# Processing image: 2198_6_1 http://imgur.com/PEgz9Kq
# 2198_6_1 already exist
# Processing image: 2198_6_2 http://imgur.com/3jgvIJU
# 2198_6_2 already exist
# Processing image: 2198_6_3 http://imgur.com/K9dFbWI
# 2198_6_3 already exist
# Processing image: 2198_6_4 http://imgur.com/lLJOgsU
# 2198_6_4 already exist
# Processing image: 2198_6_5 http://imgur.com/KrWKYiR
# 2198_6_5 already exist
# Processing image: 2198_6_6 http://imgur.com/WwvylV4
# 2198_6_6 already exist
# Processing image: 2198_6_7 http://imgur.com/E3WrNhc
# 2198_6_7 already exist
# Processing image: 2198_6_8 http://imgur.com/sMTGrJr
# 2198_6_8 already exist
# Processing image: 2198_6_9 http://imgur.com/GOzScJS
# 2198_6_9 already exist
# Processing image: 2198_6_10 http://imgur.com/qc8RBIn
# 2198_6_10 already exist
# Processing image: 2198_6_11 http://imgur.com/Is9Iq5e
# 2198_6_11 already exist
# Processing image: 2198_6_12 http://imgur.com/z6xxJfD
# 2198_6_12 already exist
# Processing image: 2198_6_13 http://imgur.com/2O4zj4l
# 2198_6_13 already exist
# Processing image: 2198_6_14 http://imgur.com/AzZSNsU
# 2198_6_14 already exist
# Processing image: 2198_6_15 http://imgur.com/3xsWhgd
# 2198_6_15 already exist
# Processing image: 2198_6_16 http://imgur.com/fymGsxE
# 2198_6_16 already exist
# Processing image: 2198_6_17 http://imgur.com/EeHMznr
# 2198_6_17 already exist
# Processing image: 2198_6_18 http://imgur.com/VGXA9wL
# 2198_6_18 already exist
# Processing image: 2198_6_19 http://imgur.com/wsEulNm
# 2198_6_19 already exist
# Processing image: 2198_6_20 http://imgur.com/emDErME
# 2198_6_20 already exist
# start article: [正妹] 短髮兩張
# Processing image: 2198_8_0 http://i.imgur.com/ofYuELl.jpg
# 2198_8_0 already exist
# Processing image: 2198_8_1 http://i.imgur.com/4SKUobc.jpg
# 2198_8_1 already exist
# start article: [正妹] 喜歡你
# Processing image: 2198_11_0 http://i.imgur.com/VGnEorZ.jpg
# 2198_11_0 already exist
# Processing image: 2198_11_1 http://i.imgur.com/3ndA3J0.jpg
# 2198_11_1 already exist
# Processing image: 2198_11_2 http://i.imgur.com/E49R2dU.jpg
# 2198_11_2 already exist
# Processing image: 2198_11_3 http://i.imgur.com/bHqpy91.jpg
# 2198_11_3 already exist
# Processing image: 2198_11_4 http://i.imgur.com/aK2giPe.jpg
# save 2198_11_4
# Processing image: 2198_11_5 http://i.imgur.com/HVUyFtH.jpg
# 2198_11_5 already exist
# Processing image: 2198_11_6 http://i.imgur.com/JcUBJ7f.jpg
# 2198_11_6 already exist
# Processing image: 2198_11_7 http://i.imgur.com/jh9JjAw.jpg
# 2198_11_7 already exist
# Processing image: 2198_11_8 http://i.imgur.com/4z498eN.jpg
# 2198_11_8 already exist
# Processing image: 2198_11_9 http://i.imgur.com/yQ75fm8.jpg
# 2198_11_9 already exist
# Processing image: 2198_11_10 http://i.imgur.com/iSmcNko.jpg
# 2198_11_10 already exist
# Processing image: 2198_11_11 http://i.imgur.com/mT4uCxr.jpg
# 2198_11_11 already exist
# Processing image: 2198_11_12 http://i.imgur.com/daPbvXA.jpg
# 2198_11_12 already exist
# Processing image: 2198_11_13 http://i.imgur.com/wPZM4VX.jpg
# 2198_11_13 already exist
# Processing image: 2198_11_14 http://i.imgur.com/mIXf5es.jpg
# 2198_11_14 already exist
# Processing image: 2198_11_15 http://i.imgur.com/wdGELHh.jpg
# 2198_11_15 already exist
# Processing image: 2198_11_16 http://i.imgur.com/BftlolO.jpg
# 2198_11_16 already exist
# Processing image: 2198_11_17 http://i.imgur.com/Pb3vpxB.jpg
# 2198_11_17 already exist
# Processing image: 2198_11_18 http://i.imgur.com/T4ZuHUG.jpg
# 2198_11_18 already exist
# Processing image: 2198_11_19 http://i.imgur.com/99FxKXb.jpg
# 2198_11_19 already exist
# Processing image: 2198_11_20 http://i.imgur.com/En1dD9u.jpg
# 2198_11_20 already exist
# Processing image: 2198_11_21 http://i.imgur.com/2pOUaAp.jpg
# 2198_11_21 already exist
# Processing image: 2198_11_22 http://i.imgur.com/tz858zN.jpg
# 2198_11_22 already exist
# Processing image: 2198_11_23 http://i.imgur.com/MlyTFWg.jpg
# 2198_11_23 already exist
# Processing image: 2198_11_24 http://i.imgur.com/5JCVSIP.jpg
# 2198_11_24 already exist
# Processing image: 2198_11_25 http://i.imgur.com/ZjPLA24.jpg
# 2198_11_25 already exist
# Processing image: 2198_11_26 http://i.imgur.com/qLPKLHS.jpg
# 2198_11_26 already exist
# Processing image: 2198_11_27 http://i.imgur.com/1eKTZUM.jpg
# 2198_11_27 already exist
# Processing image: 2198_11_28 http://i.imgur.com/G9Na5Sh.jpg
# 2198_11_28 already exist
# Processing image: 2198_11_29 http://i.imgur.com/U8b96wP.jpg
# 2198_11_29 already exist
# Processing image: 2198_11_30 http://i.imgur.com/hm82UDe.jpg
# 2198_11_30 already exist
# Processing image: 2198_11_31 http://i.imgur.com/LwamuzU.jpg
# 2198_11_31 already exist
# Processing image: 2198_11_32 http://i.imgur.com/0FG8OS3.jpg
# 2198_11_32 already exist
# Processing image: 2198_11_33 http://i.imgur.com/ESRlbYr.jpg
# 2198_11_33 already exist
# Processing image: 2198_11_34 http://i.imgur.com/ZuJCnRF.jpg
# 2198_11_34 already exist
# Processing image: 2198_11_35 http://i.imgur.com/jYTx7DG.jpg
# 2198_11_35 already exist
# Processing image: 2198_11_36 http://i.imgur.com/8xbvAkL.jpg
# 2198_11_36 already exist
# Processing image: 2198_11_37 http://i.imgur.com/FTEbjXZ.jpg
# 2198_11_37 already exist
# Processing image: 2198_11_38 http://i.imgur.com/uOkbC2o.jpg
# 2198_11_38 already exist
# Processing image: 2198_11_39 http://i.imgur.com/W5rMTaN.jpg
# 2198_11_39 already exist
# Processing image: 2198_11_40 http://i.imgur.com/g51vwyu.jpg
# 2198_11_40 already exist
# Processing image: 2198_11_41 http://i.imgur.com/YfQBlyI.jpg
# 2198_11_41 already exist
# Processing image: 2198_11_42 http://i.imgur.com/bbZ1IBL.jpg
# 2198_11_42 already exist
# start article: [正妹] 獨角獸
# Processing image: 2198_12_0 http://i.imgur.com/G2scgK1.jpg
# 2198_12_0 already exist
# Processing image: 2198_12_1 http://i.imgur.com/0EVJrgw.jpg
# 2198_12_1 already exist
# Processing image: 2198_12_2 http://i.imgur.com/buqH7UR.jpg
# 2198_12_2 already exist
# Processing image: 2198_12_3 http://i.imgur.com/meJFBvS.jpg
# 2198_12_3 already exist
# start article: [正妹] 網路不知名美女
# Processing image: 2198_14_0 http://imgur.com/a/auMl6
# 2198_14_0 already exist
# Processing image: 2198_14_1 http://imgur.com/a/4BpRn
# 2198_14_1 already exist
# Processing image: 2198_14_2 http://imgur.com/a/YnYbJ
# 2198_14_2 already exist
# start article: [正妹] 睡前來幾張.......
# Processing image: 2198_15_0 http://i.imgur.com/hXJHVeY.jpg
# 2198_15_0 already exist
# Processing image: 2198_15_1 http://i.imgur.com/5EGxwDH.jpg
# 2198_15_1 already exist
# Processing image: 2198_15_2 http://i.imgur.com/LeVVUyv.jpg
# 2198_15_2 already exist
# Processing image: 2198_15_3 http://i.imgur.com/80mOcEn.jpg
# 2198_15_3 already exist
# Processing image: 2198_15_4 http://i.imgur.com/ni2rgRl.jpg
# 2198_15_4 already exist
# Processing image: 2198_15_5 http://i.imgur.com/TWFN1mR.jpg
# 2198_15_5 already exist
# Processing image: 2198_15_6 http://i.imgur.com/qLDPJdu.jpg
# 2198_15_6 already exist
# Processing image: 2198_15_7 http://i.imgur.com/yIsyWv7.jpg
# 2198_15_7 already exist
# Processing image: 2198_15_8 http://i.imgur.com/HRK6n8e.jpg
# 2198_15_8 already exist
# Processing image: 2198_15_9 http://i.imgur.com/U1lpJE4.jpg
# 2198_15_9 already exist
# Processing image: 2198_15_10 http://i.imgur.com/GKwcC8H.jpg
# 2198_15_10 already exist
# Processing image: 2198_15_11 http://i.imgur.com/lIG5Bto.jpg
# 2198_15_11 already exist
# Processing image: 2198_15_12 http://i.imgur.com/u72M7RC.jpg
# 2198_15_12 already exist
# Processing image: 2198_15_13 http://i.imgur.com/rcFTu03.jpg
# 2198_15_13 already exist
# Processing image: 2198_15_14 http://i.imgur.com/hAvuwrj.jpg
# 2198_15_14 already exist
# Processing image: 2198_15_15 http://i.imgur.com/o2GKtDq.jpg
# 2198_15_15 already exist
# Processing image: 2198_15_16 http://i.imgur.com/DMldkcX.jpg
# 2198_15_16 already exist
# Processing image: 2198_15_17 http://i.imgur.com/zp2GNtY.jpg
# 2198_15_17 already exist
# Processing image: 2198_15_18 http://i.imgur.com/Umd9Wxr.jpg
# 2198_15_18 already exist
# start article: [正妹] 五張決勝負
# Processing image: 2198_17_0 http://imgur.com/IGoXwbF
# 2198_17_0 already exist
# Processing image: 2198_17_1 http://imgur.com/CVur7nx
# 2198_17_1 already exist
# Processing image: 2198_17_2 http://imgur.com/O9BJRA9
# 2198_17_2 already exist
# Processing image: 2198_17_3 http://imgur.com/3Mu0y6l
# 2198_17_3 already exist
# Processing image: 2198_17_4 http://imgur.com/hqaoapq
# 2198_17_4 already exist
# start article: [正妹] 荻野由佳
# Processing image: 2198_18_0 http://i.imgur.com/9CHT5jH.jpg
# 2198_18_0 already exist
# Processing image: 2198_18_1 http://i.imgur.com/QeWJvhl.jpg
# 2198_18_1 already exist
# Processing image: 2198_18_2 http://i.imgur.com/knXHAog.jpg
# 2198_18_2 already exist
# Processing image: 2198_18_3 http://i.imgur.com/dqGD6za.jpg
# 2198_18_3 already exist
# Processing image: 2198_18_4 http://i.imgur.com/Lx2Z8zn.jpg
# 2198_18_4 already exist
# Processing image: 2198_18_5 http://i.imgur.com/GOQtf37.jpg
# 2198_18_5 already exist
# Processing image: 2198_18_6 http://i.imgur.com/4pEyuMu.jpg
# 2198_18_6 already exist
# Processing image: 2198_18_7 http://i.imgur.com/YwFtaH2.jpg
# 2198_18_7 already exist
# Processing index: 2197
# Processing article: M.1499571288.A.ECD
# Processing article: M.1499575210.A.9EF
# Processing article: M.1499575238.A.ACF
# Processing article: M.1499576615.A.990
# Processing article: M.1499585985.A.4DD
# Processing article: M.1499586758.A.4CD
# Processing article: M.1499589006.A.CD7
# Processing article: M.1499589156.A.7D5
# Processing article: M.1499593070.A.6BF
# Processing article: M.1499594811.A.2D7
# Processing article: M.1499596403.A.1D0
# Processing article: M.1499603330.A.ED9
# Processing article: M.1499608889.A.E8C
# Processing article: M.1499611820.A.B1C
# Processing article: M.1499614760.A.809
# Processing article: M.1499615000.A.0C2
# Processing article: M.1499615636.A.EE7
# Processing article: M.1499619420.A.C81
# Processing article: M.1499650577.A.295
# Processing article: M.1499652045.A.F57
# ['M.1499575210.A.9EF', 'M.1499575238.A.ACF', 'M.1499576615.A.990', 'M.1499585985.A.4DD']
# start article: [正妹] 戶田惠梨香
# Processing image: 2197_4_0 http://imgur.com/5nVwZd8
# 2197_4_0 already exist
# Processing image: 2197_4_1 http://imgur.com/ybNIW30
# 2197_4_1 already exist
# Processing image: 2197_4_2 http://imgur.com/5S9EluO
# 2197_4_2 already exist
# Processing image: 2197_4_3 http://imgur.com/RKo6f9J
# 2197_4_3 already exist
# Processing image: 2197_4_4 http://imgur.com/V47KPJs
# 2197_4_4 already exist
# Processing image: 2197_4_5 http://imgur.com/QXxAdpM
# 2197_4_5 already exist
# Processing image: 2197_4_6 http://imgur.com/9pcii28
# 2197_4_6 already exist
# Processing image: 2197_4_7 http://imgur.com/q9QwzEz
# 2197_4_7 already exist
# Processing image: 2197_4_8 http://imgur.com/soRRSHC
# 2197_4_8 already exist
# start article: [正妹] 假日解解悶……
# Processing image: 2197_5_0 http://i.imgur.com/8KV2YIh.jpg
# 2197_5_0 already exist
# Processing image: 2197_5_1 http://i.imgur.com/q7hCPes.jpg
# 2197_5_1 already exist
# Processing image: 2197_5_2 http://i.imgur.com/KuAInN4.jpg
# 2197_5_2 already exist
# Processing image: 2197_5_3 http://i.imgur.com/5zHNREl.jpg
# 2197_5_3 already exist
# Processing image: 2197_5_4 http://i.imgur.com/gjLh6Nx.jpg
# 2197_5_4 already exist
# Processing image: 2197_5_5 http://i.imgur.com/DorClum.jpg
# 2197_5_5 already exist
# Processing image: 2197_5_6 http://i.imgur.com/VqpN8ZK.jpg
# 2197_5_6 already exist
# Processing image: 2197_5_7 http://i.imgur.com/gMwpSQg.jpg
# 2197_5_7 already exist
# Processing image: 2197_5_8 http://i.imgur.com/r1VCI8v.jpg
# 2197_5_8 already exist
# Processing image: 2197_5_9 http://i.imgur.com/buNwH8x.jpg
# 2197_5_9 already exist
# Processing image: 2197_5_10 http://i.imgur.com/DoB6hyg.jpg
# 2197_5_10 already exist
# Processing image: 2197_5_11 http://i.imgur.com/Dt7SwzF.jpg
# 2197_5_11 already exist
# start article: [正妹] 巨乳蘿莉臉小隻馬
# Processing image: 2197_6_0 http://i.imgur.com/n7K7cws.jpg
# 2197_6_0 already exist
# Processing image: 2197_6_1 http://i.imgur.com/NXA5IW8.jpg
# 2197_6_1 already exist
# Processing image: 2197_6_2 http://i.imgur.com/ghSHupa.jpg
# 2197_6_2 already exist
# Processing image: 2197_6_3 http://i.imgur.com/jHUy0JJ.jpg
# 2197_6_3 already exist
# Processing image: 2197_6_4 http://i.imgur.com/ouf3ebW.jpg
# 2197_6_4 already exist
# Processing image: 2197_6_5 http://i.imgur.com/IVCIX6f.jpg
# 2197_6_5 already exist
# Processing image: 2197_6_6 http://i.imgur.com/Ex8CD58.jpg
# 2197_6_6 already exist
# Processing image: 2197_6_7 http://i.imgur.com/Vth5Cis.jpg
# 2197_6_7 already exist
# Processing image: 2197_6_8 http://i.imgur.com/RaGxK2H.jpg
# 2197_6_8 already exist
# Processing image: 2197_6_9 http://i.imgur.com/YbUPwGi.jpg
# 2197_6_9 already exist
# Processing image: 2197_6_10 http://i.imgur.com/fK7hPTJ.jpg
# 2197_6_10 already exist
# Processing image: 2197_6_11 http://i.imgur.com/QQDODP6.jpg
# 2197_6_11 already exist
# start article: [正妹] Nicole Lodl 美國模特兒 177cm
# Processing image: 2197_7_0 http://i.imgur.com/SZaO48h.jpg
# 2197_7_0 already exist
# Processing image: 2197_7_1 http://i.imgur.com/5c50OC3.jpg
# 2197_7_1 already exist
# Processing image: 2197_7_2 http://i.imgur.com/vQGZTE4.jpg
# 2197_7_2 already exist
# Processing image: 2197_7_3 http://i.imgur.com/B770nCV.jpg
# 2197_7_3 already exist
# Processing image: 2197_7_4 http://i.imgur.com/Mh8N7kx.jpg
# 2197_7_4 already exist
# start article: [正妹] 假日小確幸
# Processing image: 2197_8_0 http://i.imgur.com/T1HwoGf.jpg
# 2197_8_0 already exist
# Processing image: 2197_8_1 http://i.imgur.com/qZKuNQe.jpg
# 2197_8_1 already exist
# Processing image: 2197_8_2 http://i.imgur.com/1Rv5N18.jpg
# 2197_8_2 already exist
# Processing image: 2197_8_3 http://i.imgur.com/hIQ2h4d.jpg
# 2197_8_3 already exist
# Processing image: 2197_8_4 http://i.imgur.com/WQa3mDp.jpg
# 2197_8_4 already exist
# Processing image: 2197_8_5 http://i.imgur.com/8IUsWXW.jpg
# 2197_8_5 already exist
# Processing image: 2197_8_6 http://i.imgur.com/xylhlbf.jpg
# 2197_8_6 already exist
# Processing image: 2197_8_7 http://i.imgur.com/tLkzwyU.jpg
# 2197_8_7 already exist
# Processing image: 2197_8_8 http://i.imgur.com/uJqbOWm.jpg
# 2197_8_8 already exist
# start article: [正妹] 奉獻我老婆一張
# Processing image: 2197_9_0 http://i.imgur.com/R11sQdP.jpg
# 2197_9_0 already exist
# start article: [正妹] 「國民情婦」 森咲智美
# Processing image: 2197_11_0 http://i.imgur.com/uGoXgZx.jpg
# 2197_11_0 already exist
# Processing image: 2197_11_1 http://i.imgur.com/z3s4RBe.jpg
# 2197_11_1 already exist
# Processing image: 2197_11_2 http://i.imgur.com/ZQRbFIZ.jpg
# 2197_11_2 already exist
# Processing image: 2197_11_3 http://i.imgur.com/SUlAm9h.jpg
# 2197_11_3 already exist
# Processing image: 2197_11_4 http://i.imgur.com/62d4rQP.jpg
# 2197_11_4 already exist
# Processing image: 2197_11_5 http://i.imgur.com/k5uSCUb.jpg
# 2197_11_5 already exist
# Processing image: 2197_11_6 http://i.imgur.com/96tffhd.jpg
# 2197_11_6 already exist
# Processing image: 2197_11_7 http://i.imgur.com/VxqOGmw.jpg
# 2197_11_7 already exist
# Processing image: 2197_11_8 http://i.imgur.com/PFFzhvL.jpg
# 2197_11_8 already exist
# Processing image: 2197_11_9 http://i.imgur.com/gdLQIoX.jpg
# 2197_11_9 already exist
# Processing image: 2197_11_10 http://i.imgur.com/zQdfPw4.jpg
# 2197_11_10 already exist
# Processing image: 2197_11_11 http://i.imgur.com/roSenLx.jpg
# 2197_11_11 already exist
# Processing image: 2197_11_12 http://i.imgur.com/c5JEa9O.jpg
# 2197_11_12 already exist
# Processing image: 2197_11_13 http://i.imgur.com/03GmCOp.jpg
# 2197_11_13 already exist
# Processing image: 2197_11_14 http://i.imgur.com/pczwOEr.jpg
# 2197_11_14 already exist
# Processing image: 2197_11_15 http://i.imgur.com/2946KTU.jpg
# 2197_11_15 already exist
# Processing image: 2197_11_16 http://i.imgur.com/ctXUPz4.jpg
# 2197_11_16 already exist
# Processing image: 2197_11_17 http://i.imgur.com/1TRzOod.jpg
# 2197_11_17 already exist
# Processing image: 2197_11_18 http://i.imgur.com/rzfHqrl.jpg
# 2197_11_18 already exist
# Processing image: 2197_11_19 http://i.imgur.com/yXQ8MzQ.jpg
# 2197_11_19 already exist
# Processing image: 2197_11_20 http://i.imgur.com/j9T9zM5.jpg
# 2197_11_20 already exist
# Processing image: 2197_11_21 http://i.imgur.com/h904sKn.jpg
# 2197_11_21 already exist
# Processing image: 2197_11_22 http://i.imgur.com/ehLfBDb.jpg
# 2197_11_22 already exist
# Processing image: 2197_11_23 http://i.imgur.com/1h2q5oi.jpg
# 2197_11_23 already exist
# start article: [正妹] 那妳吉他先
# Processing image: 2197_13_0 http://i.imgur.com/pSzXbbG.jpg
# 2197_13_0 already exist
# start article: [正妹] 深夜 一張
# Processing image: 2197_14_0 http://i.imgur.com/f6KZbtM.jpg
# 2197_14_0 already exist
# start article: [正妹] 籃球美少女合輯
# Processing image: 2197_17_0 http://imgur.com/ayUvzAg
# 2197_17_0 already exist
# Processing image: 2197_17_1 http://imgur.com/rernmCa
# 2197_17_1 already exist
# Processing image: 2197_17_2 http://imgur.com/feHjNk0
# 2197_17_2 already exist
# Processing image: 2197_17_3 http://imgur.com/NB71dlZ
# 2197_17_3 already exist
# Processing image: 2197_17_4 http://imgur.com/HjBvSHG
# 2197_17_4 already exist
# Processing image: 2197_17_5 http://imgur.com/HBUVXGq
# 2197_17_5 already exist
# Processing image: 2197_17_6 http://imgur.com/HGkELFv
# 2197_17_6 already exist
# Processing image: 2197_17_7 http://imgur.com/bgYfqvc
# 2197_17_7 already exist
# Processing image: 2197_17_8 http://imgur.com/CYprqub
# 2197_17_8 already exist
# Processing image: 2197_17_9 http://imgur.com/3Xw9874
# 2197_17_9 already exist
# Processing image: 2197_17_10 http://imgur.com/Y4TJVLU
# 2197_17_10 already exist
# Processing image: 2197_17_11 http://imgur.com/xkrf7kC
# 2197_17_11 already exist
# Processing image: 2197_17_12 http://imgur.com/ul1v2Vd
# 2197_17_12 already exist
# Processing image: 2197_17_13 http://imgur.com/q6Npp3a
# 2197_17_13 already exist
# Processing image: 2197_17_14 http://imgur.com/Yzp6BVq
# 2197_17_14 already exist
# Processing image: 2197_17_15 http://imgur.com/uiCTGQH
# 2197_17_15 already exist
# Processing image: 2197_17_16 http://imgur.com/Bcujv9w
# 2197_17_16 already exist
# Processing image: 2197_17_17 http://imgur.com/dmZJEnQ
# 2197_17_17 already exist
# Processing image: 2197_17_18 http://imgur.com/f9BXMfW
# 2197_17_18 already exist
# Processing image: 2197_17_19 http://imgur.com/JBTRnQE
# 2197_17_19 already exist
# Processing image: 2197_17_20 http://imgur.com/cyuHHau
# 2197_17_20 already exist
# Processing image: 2197_17_21 http://imgur.com/oYJDKlV
# 2197_17_21 already exist
# Processing image: 2197_17_22 http://imgur.com/CbpNQUt
# 2197_17_22 already exist
# Processing image: 2197_17_23 http://imgur.com/gJQ6kNv
# 2197_17_23 already exist
# Processing image: 2197_17_24 http://imgur.com/sHC9wZr
# 2197_17_24 already exist
# Processing image: 2197_17_25 http://imgur.com/GWpIxhC
# 2197_17_25 already exist
# Processing image: 2197_17_26 http://imgur.com/gX1gNNM
# 2197_17_26 already exist
# Processing image: 2197_17_27 http://imgur.com/X8k5H77
# 2197_17_27 already exist
# Processing image: 2197_17_28 http://imgur.com/r6J6HUi
# 2197_17_28 already exist
# Processing image: 2197_17_29 http://imgur.com/MKonMMT
# 2197_17_29 already exist
# Processing image: 2197_17_30 http://imgur.com/dntK5uh
# 2197_17_30 already exist
# Processing image: 2197_17_31 http://imgur.com/UTIKjbQ
# 2197_17_31 already exist
# Processing image: 2197_17_32 http://imgur.com/WfTdIGE
# 2197_17_32 already exist
# Processing image: 2197_17_33 http://imgur.com/S6bsgHO
# 2197_17_33 already exist
# Processing image: 2197_17_34 http://imgur.com/wCD19Dh
# 2197_17_34 already exist
# Processing image: 2197_17_35 http://imgur.com/rJMz53H
# 2197_17_35 already exist
# Processing image: 2197_17_36 http://imgur.com/XdMXQ24
# 2197_17_36 already exist
# Processing image: 2197_17_37 http://imgur.com/q4vtU0r
# 2197_17_37 already exist
# Processing image: 2197_17_38 http://imgur.com/VdOAqaq
# 2197_17_38 already exist
# Processing image: 2197_17_39 http://imgur.com/u371Yw5
# 2197_17_39 already exist
# Processing image: 2197_17_40 http://imgur.com/RNHxiQd
# 2197_17_40 already exist
# Processing image: 2197_17_41 http://imgur.com/2ixcwbk
# 2197_17_41 already exist
# Processing image: 2197_17_42 http://imgur.com/39ShhXO
# 2197_17_42 already exist
# Processing image: 2197_17_43 http://imgur.com/e5voZ0O
# 2197_17_43 already exist
# Processing image: 2197_17_44 http://imgur.com/ZClUhXN
# 2197_17_44 already exist
# Processing image: 2197_17_45 http://imgur.com/Uk1wRVo
# 2197_17_45 already exist
# Processing image: 2197_17_46 http://imgur.com/3qLE8gy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-053cebec55a6> in <module>()
#      10             urls = re.findall('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', content)
#      11             print("start article:",titles[i])
# ---> 12             download_urls(urls,article_id,INDEX,i,FOLDER)
#      13         i=i+1
#      14     INDEX=INDEX-1
#
# <ipython-input-9-0c2b9af83449> in download_urls(urls, article_id, index, article_num, folder)
#       6             filename=str(index)+"_"+str(article_num)+"_"+str(j)
#       7             print("Processing image:",filename,url)
# ----> 8             downloader = ImgurDownloader(url,FOLDER,filename)
#       9             if (not os.path.exists(folder+"/"+filename+".jpg")) and (not os.path.exists(folder+"/"+filename+".png")):
#      10                 downloader.on_image_download(downloader.save_images())
#
# ~\evan\Learning\python\env-ptt_beauty\src\imgurdownloader.py in __init__(self, imgur_url, dir_download, file_name, delete_dne, debug)
#     122         # e.g.: imgur.com/a/p5wLR -> imgur.com/a/p5wLR/all
#     123         try:
# --> 124             self.response = urllib.request.urlopen(url=imgur_url)
#     125             response_code = self.response.getcode()
#     126         except Exception as e:
#
# c:\program files\python35\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     161     else:
#     162         opener = _opener
# --> 163     return opener.open(url, data, timeout)
#     164
#     165 def install_opener(opener):
#
# c:\program files\python35\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     470         for processor in self.process_response.get(protocol, []):
#     471             meth = getattr(processor, meth_name)
# --> 472             response = meth(req, response)
#     473
#     474         return response
#
# c:\program files\python35\lib\urllib\request.py in http_response(self, request, response)
#     580         if not (200 <= code < 300):
#     581             response = self.parent.error(
# --> 582                 'http', request, response, code, msg, hdrs)
#     583
#     584         return response
#
# c:\program files\python35\lib\urllib\request.py in error(self, proto, *args)
#     502             http_err = 0
#     503         args = (dict, proto, meth_name) + args
# --> 504         result = self._call_chain(*args)
#     505         if result:
#     506             return result
#
# c:\program files\python35\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     442         for handler in handlers:
#     443             func = getattr(handler, meth_name)
# --> 444             result = func(*args)
#     445             if result is not None:
#     446                 return result
#
# c:\program files\python35\lib\urllib\request.py in http_error_302(self, req, fp, code, msg, headers)
#     694         fp.close()
#     695
# --> 696         return self.parent.open(new, timeout=req.timeout)
#     697
#     698     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# c:\program files\python35\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     464             req = meth(req)
#     465
# --> 466         response = self._open(req, data)
#     467
#     468         # post-process response
#
# c:\program files\python35\lib\urllib\request.py in _open(self, req, data)
#     482         protocol = req.type
#     483         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 484                                   '_open', req)
#     485         if result:
#     486             return result
#
# c:\program files\python35\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     442         for handler in handlers:
#     443             func = getattr(handler, meth_name)
# --> 444             result = func(*args)
#     445             if result is not None:
#     446                 return result
#
# c:\program files\python35\lib\urllib\request.py in https_open(self, req)
#    1295         def https_open(self, req):
#    1296             return self.do_open(http.client.HTTPSConnection, req,
# -> 1297                 context=self._context, check_hostname=self._check_hostname)
#    1298
#    1299         https_request = AbstractHTTPHandler.do_request_
#
# c:\program files\python35\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1252         try:
#    1253             try:
# -> 1254                 h.request(req.get_method(), req.selector, req.data, headers)
#    1255             except OSError as err: # timeout error
#    1256                 raise URLError(err)
#
# c:\program files\python35\lib\http\client.py in request(self, method, url, body, headers)
#    1105     def request(self, method, url, body=None, headers={}):
#    1106         """Send a complete request to the server."""
# -> 1107         self._send_request(method, url, body, headers)
#    1108
#    1109     def _set_content_length(self, body, method):
#
# c:\program files\python35\lib\http\client.py in _send_request(self, method, url, body, headers)
#    1150             # default charset of iso-8859-1.
#    1151             body = _encode(body, 'body')
# -> 1152         self.endheaders(body)
#    1153
#    1154     def getresponse(self):
#
# c:\program files\python35\lib\http\client.py in endheaders(self, message_body)
#    1101         else:
#    1102             raise CannotSendHeader()
# -> 1103         self._send_output(message_body)
#    1104
#    1105     def request(self, method, url, body=None, headers={}):
#
# c:\program files\python35\lib\http\client.py in _send_output(self, message_body)
#     932         del self._buffer[:]
#     933
# --> 934         self.send(msg)
#     935         if message_body is not None:
#     936             self.send(message_body)
#
# c:\program files\python35\lib\http\client.py in send(self, data)
#     875         if self.sock is None:
#     876             if self.auto_open:
# --> 877                 self.connect()
#     878             else:
#     879                 raise NotConnected()
#
# c:\program files\python35\lib\http\client.py in connect(self)
#    1259
#    1260             self.sock = self._context.wrap_socket(self.sock,
# -> 1261                                                   server_hostname=server_hostname)
#    1262             if not self._context.check_hostname and self._check_hostname:
#    1263                 try:
#
# c:\program files\python35\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     383                          suppress_ragged_eofs=suppress_ragged_eofs,
#     384                          server_hostname=server_hostname,
# --> 385                          _context=self)
#     386
#     387     def wrap_bio(self, incoming, outgoing, server_side=False,
#
# c:\program files\python35\lib\ssl.py in __init__(self, sock, keyfile, certfile, server_side, cert_reqs, ssl_version, ca_certs, do_handshake_on_connect, family, type, proto, fileno, suppress_ragged_eofs, npn_protocols, ciphers, server_hostname, _context)
#     758                         # non-blocking
#     759                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 760                     self.do_handshake()
#     761
#     762             except (OSError, ValueError):
#
# c:\program files\python35\lib\ssl.py in do_handshake(self, block)
#     994             if timeout == 0.0 and block:
#     995                 self.settimeout(None)
# --> 996             self._sslobj.do_handshake()
#     997         finally:
#     998             self.settimeout(timeout)
#
# c:\program files\python35\lib\ssl.py in do_handshake(self)
#     639     def do_handshake(self):
#     640         """Start the SSL/TLS handshake."""
# --> 641         self._sslobj.do_handshake()
#     642         if self.context.check_hostname:
#     643             if not self.server_hostname:
#
# KeyboardInterrupt:

# %%
# !jupyter nbconvert --to script PttBeautyDownload.ipynb
