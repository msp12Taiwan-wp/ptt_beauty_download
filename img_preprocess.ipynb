# %%
from sklearn import cluster, datasets
import cv2
from matplotlib import pyplot as plt
import numpy as np
from scipy import misc,ndimage

# %%
from scipy import misc,ndimage
import matplotlib.pyplot as plt
# scipy.ndimage
f = misc.face()
f = misc.imread('2195_1_8.jpg')
# blurred_face = ndimage.gaussian_filter(f, sigma=3)
img = cv2.imread('2196_8_18.jpg')
plt.imshow(img)
plt.show()
# Out:
# c:\program files\python35\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-bceed1a14ebe> in <module>()
#       3 # scipy.ndimage
#       4 f = misc.face()
# ----> 5 f = misc.imread('2195_1_8.jpg')
#       6 # blurred_face = ndimage.gaussian_filter(f, sigma=3)
#       7 img = cv2.imread('2196_8_18.jpg')
#
# c:\program files\python35\lib\site-packages\numpy\lib\utils.py in newfunc(*args, **kwds)
#      99             """`arrayrange` is deprecated, use `arange` instead!"""
#     100             warnings.warn(depdoc, DeprecationWarning, stacklevel=2)
# --> 101             return func(*args, **kwds)
#     102
#     103         newfunc = _set_function_name(newfunc, old_name)
#
# c:\program files\python35\lib\site-packages\scipy\misc\pilutil.py in imread(name, flatten, mode)
#     162     """
#     163
# --> 164     im = Image.open(name)
#     165     return fromimage(im, flatten=flatten, mode=mode)
#     166
#
# c:\program files\python35\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2528
#    2529     if filename:
# -> 2530         fp = builtins.open(filename, "rb")
#    2531         exclusive_fp = True
#    2532
#
# FileNotFoundError: [Errno 2] No such file or directory: '2195_1_8.jpg'

# %%
img = misc.imread('newDownload/2196_4_10.jpg')
sqrimg=img[0:img.shape[1],0:img.shape[1]]
# height, width =sqrimg.shape[:2]
res = cv2.resize(sqrimg,(256, 256), interpolation = cv2.INTER_AREA)
blured = cv2.blur(res,(5,5))  
mask = np.zeros((256+2, 256+2), np.uint8) 
cv2.floodFill(blured, mask, (256-1,256-1), (255,255,255), (2,2,2),(3,3,3),8)
plt.imshow(blured)
plt.show()
blured.shape
# Out:
# c:\program files\python35\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.
# (256, 256, 3)

# %%
img = blured#cv2.imread('2195_1_8.jpg',0)
sobelx8u = cv2.Sobel(img,cv2.CV_8U,1,0,ksize=5)

# Output dtype = cv2.CV_64F. Then take its absolute and convert to cv2.CV_8U
sobelx64f = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)
abs_sobel64f = np.absolute(sobelx64f)
sobel_8u = np.uint8(abs_sobel64f)

plt.subplot(1,3,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(1,3,2),plt.imshow(sobelx8u,cmap = 'gray')
plt.title('Sobel CV_8U'), plt.xticks([]), plt.yticks([])
plt.subplot(1,3,3),plt.imshow(sobel_8u,cmap = 'gray')
plt.title('Sobel abs(CV_64F)'), plt.xticks([]), plt.yticks([])
plt.show()
