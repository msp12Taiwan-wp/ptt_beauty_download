# %%
# -*- coding: MS950 -*-
import unittest
from PttWebCrawler.crawler import *
import codecs, json, os
from imgurdownloader import *
import re,os

# %%
FROM=2110
TO=2110
FOLDER='./Download'

# %%
c = PttWebCrawler(as_lib=True)
t=c.parse_articles(FROM, TO, 'beauty')
# Out:
# Processing index: 2110
# Processing article: M.1491381183.A.5CE
# Processing article: M.1491385033.A.403
# Processing article: M.1491391628.A.8C8
# Processing article: M.1491395882.A.530
# Processing article: M.1491396940.A.FBC
# Processing article: M.1491396979.A.F77
# Processing article: M.1491399355.A.C0B
# Processing article: M.1491399818.A.3C4
# Processing article: M.1491400585.A.FFE
# Processing article: M.1491400812.A.F7A
# Processing article: M.1491405514.A.A9F
# Processing article: M.1491407585.A.3F3
# Processing article: M.1491407872.A.F17
# Processing article: M.1491412000.A.75B
# Processing article: M.1491414529.A.809
# Processing article: M.1491416306.A.596
# Processing article: M.1491416336.A.D98
# Processing article: M.1491418475.A.319
# Processing article: M.1491427487.A.A93
# Processing article: M.1491435318.A.780

# %%
with open(t, 'r',encoding = 'utf8') as f:
    data=json.load(f)
content=[]
title=[]
for article in data['articles']:
    content.append(article['content'])
    title.append(article['article_title'])
# content[2]
data
# Out:
# {'articles': [{'article_id': 'M.1491381183.A.5CE',
#    'article_title': '[正妹] 楊羽霓',
#    'author': 'PrinceBamboo (竹取駙馬)',
#    'board': 'beauty',
#    'content': '演藝圈辣媽 楊羽霓 最近在健康節目上常看到她教來賓做瑜珈 身材好 分享幾張正照 http://img.ltn.com.tw/Upload/ent/page/800/2016/12/08/1911681_4.jpg http://cdn2.ettoday.net/images/2199/d2199046.jpg https://fsp.youthwant.com/images/580_537120446385771.jpg http://img.ltn.com.tw/Upload/liveNews/BigPic/600_1295007_1.jpg http://cdn2.ettoday.net/images/666/d666537.jpg http://cdn2.ettoday.net/images/666/d666534.jpg http://twimg.edgesuite.net//images/twapple/640pix/20160619/EN05/EN05_004.jpg 跟老公阿建 https://goo.gl/gQFbmu 跟兒子Peter ',
#    'date': 'Wed Apr  5 16:32:53 2017',
#    'ip': '114.25.177.76',
#    'message_conut': {'all': 14,
#     'boo': 0,
#     'count': 14,
#     'neutral': 0,
#     'push': 14},
#    'messages': [{'push_content': '臉讚',
#      'push_ipdatetime': '04/05 16:38',
#      'push_tag': '推',
#      'push_userid': 'jawill'},
#     {'push_content': '正正的人妻！',
#      'push_ipdatetime': '04/05 16:39',
#      'push_tag': '推',
#      'push_userid': 'sure0219'},
#     {'push_content': '推',
#      'push_ipdatetime': '04/05 16:41',
#      'push_tag': '推',
#      'push_userid': 'Dream624'},
#     {'push_content': '兒子真的帥！',
#      'push_ipdatetime': '04/05 17:15',
#      'push_tag': '推',
#      'push_userid': 'durian0308'},
#     {'push_content': '以前剛出來覺得超正',
#      'push_ipdatetime': '04/05 17:32',
#      'push_tag': '推',
#      'push_userid': 'darren2586'},
#     {'push_content': '原名 好多了  楊鷺',
#      'push_ipdatetime': '04/05 17:36',
#      'push_tag': '推',
#      'push_userid': 'chienk'},
#     {'push_content': '極品!!!',
#      'push_ipdatetime': '04/05 17:45',
#      'push_tag': '推',
#      'push_userid': 'NIKO0913'},
#     {'push_content': '超哈她',
#      'push_ipdatetime': '04/05 18:24',
#      'push_tag': '推',
#      'push_userid': 'DamnKobe'},
#     {'push_content': '蠻早就注意到這位頗正的人妻！',
#      'push_ipdatetime': '04/05 19:14',
#      'push_tag': '推',
#      'push_userid': 'telescopy'},
#     {'push_content': '太太我喜歡妳啊',
#      'push_ipdatetime': '04/05 21:53',
#      'push_tag': '推',
#      'push_userid': 'Krishna'},
#     {'push_content': '她超美的 <3',
#      'push_ipdatetime': '04/05 22:22',
#      'push_tag': '推',
#      'push_userid': 'pinkhua'},
#     {'push_content': '哇賽 挺壯的 不賴不賴',
#      'push_ipdatetime': '04/06 11:38',
#      'push_tag': '推',
#      'push_userid': 'bightb56913'},
#     {'push_content': '覺得性感',
#      'push_ipdatetime': '04/06 22:16',
#      'push_tag': '推',
#      'push_userid': 'skylion'},
#     {'push_content': '長髮比較好看',
#      'push_ipdatetime': '04/06 22:35',
#      'push_tag': '推',
#      'push_userid': 'fireguard119'}],
#    'url': 'https://www.ptt.cc/bbs/Beauty/M.1491381183.A.5CE.html'},
#   {'article_id': 'M.1491385033.A.403',
#    'article_title': '[正妹] 前凸後翹 極品美尻 泰國美女 Round 16',
#    'author': 'jason1904 (忍者龜頭痛)',
#    'board': 'beauty',
#    'content': '來看泰國美女吧 http://i.imgur.com/vqN6kE6.jpg http://i.imgur.com/hY4masI.jpg http://i.imgur.com/qdonbu7.jpg http://i.imgur.com/mtECXP5.jpg 原文 >> http://bit.ly/2o8OaHG (12P) 出處 >> https://www.facebook.com/ThaiBeauty7/ (曼谷幫泰國美女推送) ',
#    'date': 'Wed Apr  5 17:37:10 2017',
#    'ip': '36.230.32.103',
#    'message_conut': {'all': 9, 'boo': 0, 'count': 6, 'neutral': 3, 'push': 6},
#    'messages': [{'push_content': '真的很怕.....凸在不該凸的地方...',
#      'push_ipdatetime': '04/05 17:48',
#      'push_tag': '→',
#      'push_userid': 'aponderek'},
#     {'push_content': '這麼正，一定是',
#      'push_ipdatetime': '04/05 17:49',
#      'push_tag': '推',
#      'push_userid': 'pchunters123'},
#     {'push_content': '想必大家都有共識吧…(-ι_- )',
#      'push_ipdatetime': '04/05 17:57',
#      'push_tag': '推',
#      'push_userid': 'Teamo0209'},
#     {'push_content': '弓單出來(？)',
#      'push_ipdatetime': '04/05 18:28',
#      'push_tag': '推',
#      'push_userid': 'force5566'},
#     {'push_content': '彈出來啦',
#      'push_ipdatetime': '04/05 18:51',
#      'push_tag': '→',
#      'push_userid': 'p7837302'},
#     {'push_content': 'Yoyodiy好久不見了',
#      'push_ipdatetime': '04/05 20:45',
#      'push_tag': '推',
#      'push_userid': 'icewindwu'},
#     {'push_content': '會被下降頭',
#      'push_ipdatetime': '04/05 21:42',
#      'push_tag': '推',
#      'push_userid': 'lion917029'},
#     {'push_content': '不知道是民族血統差異還是怎樣，越看越奇怪…給箭頭',
#      'push_ipdatetime': '04/05 23:38',
#      'push_tag': '→',
#      'push_userid': 'OrangeKuMa'},
#     {'push_content': '1樓笑死',
#      'push_ipdatetime': '04/07 17:33',
#      'push_tag': '推',
#      'push_userid': 'lobarbrother'}],
#    'url': 'https://www.ptt.cc/bbs/Beauty/M.1491385033.A.403.html'},
#   {'article_id': 'M.1491391628.A.8C8',
#    'article_title': '[正妹] 潛水熊',
#    'author': 'yingrenhao (chrisying1114)',
#    'board': 'beauty',
#    'content': 'http://i.imgur.com/c5wXZC6.jpg http://i.imgur.com/YJYPB1S.jpg http://i.imgur.com/A4rFRq3.jpg http://i.imgur.com/g32eFFe.jpg',
#    'date': 'Wed Apr  5 19:27:06 2017',
#    'ip': '223.136.95.181',
#    'message_conut': {'all': 206,
#     'boo': 17,
#     'count': 152,
#     'neutral': 20,
#     'push': 169},
#    'messages': [{'push_content': '推!推!推!',
#      'push_ipdatetime': '04/05 19:28',
#      'push_tag': '→',
#      'push_userid': 'LAUNFEI'},
#     {'push_content': '有熊有推',
#      'push_ipdatetime': '04/05 19:33',
#      'push_tag': '推',
#      'push_userid': 'twTesla'},
#     {'push_content': '請開門',
#      'push_ipdatetime': '04/05 19:35',
#      'push_tag': '推',
#      'push_userid': 'whatupjk'},
#     {'push_content': '中國人?',
#      'push_ipdatetime': '04/05 19:43',
#      'push_tag': '→',
#      'push_userid': 'n123456n'},
#     {'push_content': '可愛',
#      'push_ipdatetime': '04/05 19:44',
#      'push_tag': '推',
#      'push_userid': 'yoyonigo'},
#     {'push_content': 'push',
#      'push_ipdatetime': '04/05 19:49',
#      'push_tag': '推',
#      'push_userid': 'ishigakis'},
#     {'push_content': '四樓煩請去谷歌',
#      'push_ipdatetime': '04/05 19:50',
#      'push_tag': '推',
#      'push_userid': 'aluelue'},
#     {'push_content': '不推不行',
#      'push_ipdatetime': '04/05 19:54',
#      'push_tag': '推',
#      'push_userid': 'lovelife8410'},
#     {'push_content': '開台了',
#      'push_ipdatetime': '04/05 19:56',
#      'push_tag': '推',
#      'push_userid': 'Chengyi1998'},
#     {'push_content': 'Yuniko正翻了！！！',
#      'push_ipdatetime': '04/05 19:58',
#      'push_tag': '推',
#      'push_userid': 'ui9317'},
#     {'push_content': '她的便當好大一盒..',
#      'push_ipdatetime': '04/05 20:01',
#      'push_tag': '推',
#      'push_userid': 't909092'},
#     {'push_content': 'yuniko推個',
#      'push_ipdatetime': '04/05 20:04',
#      'push_tag': '推',
#      'push_userid': 'ap8034578'},
#     {'push_content': '還我小熊  雅琪我愛妳',
#      'push_ipdatetime': '04/05 20:07',
#      'push_tag': '推',
#      'push_userid': 'zz0920648284'},
#     {'push_content': '推',
#      'push_ipdatetime': '04/05 20:08',
#      'push_tag': '推',
#      'push_userid': 'joker00507'},
#     {'push_content': '正',
#      'push_ipdatetime': '04/05 20:11',
#      'push_tag': '推',
#      'push_userid': 'star1739456'},
#     {'push_content': '\\  ‧    ‧  /熊起來\\  ‧    ‧  /',
#      'push_ipdatetime': '04/05 20:16',
#      'push_tag': '推',
#      'push_userid': 'woven1017'},
#     {'push_content': '老婆推一個',
#      'push_ipdatetime': '04/05 20:19',
#      'push_tag': '推',
#      'push_userid': 'criminal'},
#     {'push_content': '小熊推',
#      'push_ipdatetime': '04/05 20:20',
#      'push_tag': '推',
#      'push_userid': 'xup6tp6u4'},
#     {'push_content': '小胸<3',
#      'push_ipdatetime': '04/05 20:23',
#      'push_tag': '推',
#      'push_userid': 'Aggro'},
#     {'push_content': '好正',
#      'push_ipdatetime': '04/05 20:26',
#      'push_tag': '推',
#      'push_userid': 'tabrisPTT'},
#     {'push_content': '已戀愛',
#      'push_ipdatetime': '04/05 20:27',
#      'push_tag': '推',
#      'push_userid': 'Krishna'},
#     {'push_content': '推',
#      'push_ipdatetime': '04/05 20:27',
#      'push_tag': '推',
#      'push_userid': 'F0011010101'},
#     {'push_content': '之前說自己失業，結果馬上找到工作QQ，人正真好',
#      'push_ipdatetime': '04/05 20:28',
#      'push_tag': '→',
#      'push_userid': 'noobismeok'},
#     {'push_content': '推推推~~~~~',
#      'push_ipdatetime': '04/05 20:47',
#      'push_tag': '推',
#      'push_userid': 'freedom1128'},
#     {'push_content': '小熊',
#      'push_ipdatetime': '04/05 20:47',
#      'push_tag': '推',
#      'push_userid': 'lck0'},
#     {'push_content': '熊起來!!',
#      'push_ipdatetime': '04/05 20:49',
#      'push_tag': '推',
#      'push_userid': 'lungyu'},
#     {'push_content': '樓下噓過氣',
#      'push_ipdatetime': '04/05 20:51',
#      'push_tag': '→',
#      'push_userid': 'eric910005'},
#     {'push_content': '疝氣',
#      'push_ipdatetime': '04/05 20:53',
#      'push_tag': '噓',
#      'push_userid': 'Ethan23131'},
#     {'push_content': '還我小熊',
#      'push_ipdatetime': '04/05 20:53',
#      'push_tag': '推',
#      'push_userid': 'katoai'},
#     {'push_content': '這我一定虎',
#      'push_ipdatetime': '04/05 20:55',
#      'push_tag': '推',
#      'push_userid': 'APC'},
#     {'push_content': '推',
#      'push_ipdatetime': '04/05 20:57',
#      'push_tag': '推',
#      'push_userid': 'asd07633'},
#     {'push_content': '只能推了',
#      'push_ipdatetime': '04/05 20:57',
#      'push_tag': '推',
#      'push_userid': 'spinebuster'},
#     {'push_content': 'Yuniko推一個',
#      'push_ipdatetime': '04/05 21:00',
#      'push_tag': '推',
#      'push_userid': 'ohmygod18812'},
#     {'push_content': '我熊威武',
#      'push_ipdatetime': '04/05 21:00',
#      'push_tag': '推',
#      'push_userid': 'billy870302'},
#     {'push_content': '小熊我老婆',
#      'push_ipdatetime': '04/05 21:00',
#      'push_tag': '推',
#      'push_userid': 'a34842482'},
#     {'push_content': '那第四張阿斯',
#      'push_ipdatetime': '04/05 21:01',
#      'push_tag': '推',
#      'push_userid': 'xinlu81'},
#     {'push_content': 'G8熊~ <3',
#      'push_ipdatetime': '04/05 21:01',
#      'push_tag': '推',
#      'push_userid': 'leosthanatos'},
#     {'push_content': '小熊小於三',
#      'push_ipdatetime': '04/05 21:02',
#      'push_tag': '推',
#      'push_userid': 'st880005'},
#     {'push_content': '求門',
#      'push_ipdatetime': '04/05 21:03',
#      'push_tag': '推',
#      'push_userid': 'Twicejeff'},
#     {'push_content': '正正對',
#      'push_ipdatetime': '04/05 21:04',
#      'push_tag': '推',
#      'push_userid': 'TitanEric'},
#     {'push_content': 'https://www.twitch.tv/yuniko0720',
#      'push_ipdatetime': '04/05 21:04',
#      'push_tag': '推',
#      'push_userid': 'leosthanatos'},
#     {'push_content': '深潛熊',
#      'push_ipdatetime': '04/05 21:07',
#      'push_tag': '推',
#      'push_userid': 'condition0'},
#     {'push_content': '還我小熊',
#      'push_ipdatetime': '04/05 21:08',
#      'push_tag': '推',
#      'push_userid': 'taya16'},
#     {'push_content': '受不了',
#      'push_ipdatetime': '04/05 21:09',
#      'push_tag': '推',
#      'push_userid': 'Xenos134'},
#     {'push_content': '小熊推~~~',
#      'push_ipdatetime': '04/05 21:09',
#      'push_tag': '推',
#      'push_userid': 'makodo0803'},
#     {'push_content': '還我小熊 小熊李星＞丁特李星',
#      'push_ipdatetime': '04/05 21:11',
#      'push_tag': '推',
#      'push_userid': 'mosquitokyoz'},
#     {'push_content': '推潛水熊~',
#      'push_ipdatetime': '04/05 21:14',
#      'push_tag': '推',
#      'push_userid': 'jk901815'},
#     {'push_content': '小熊我可以',
#      'push_ipdatetime': '04/05 21:21',
#      'push_tag': '推',
#      'push_userid': 't781226'},
#     {'push_content': '看到好多呼吸器，好懷念',
#      'push_ipdatetime': '04/05 21:21',
#      'push_tag': '推',
#      'push_userid': 'swahusky4NI'},
#     {'push_content': '大琪小於3',
#      'push_ipdatetime': '04/05 21:24',
#      'push_tag': '推',
#      'push_userid': 'eric0210'},
#     {'push_content': '可愛<3',
#      'push_ipdatetime': '04/05 21:25',
#      'push_tag': '推',
#      'push_userid': 'fyxt'},
#     {'push_content': '工讀生到',
#      'push_ipdatetime': '04/05 21:26',
#      'push_tag': '推',
#      'push_userid': 'zzz55597'},
#     {'push_content': '大琪♥♥♥♥♥♥',
#      'push_ipdatetime': '04/05 21:27',
#      'push_tag': '→',
#      'push_userid': 'a8347x15'},
#     {'push_content': '小熊我老婆 其他人請自重',
#      'push_ipdatetime': '04/05 21:33',
#      'push_tag': '推',
#      'push_userid': 'myptttime'},
#     {'push_content': '潛水熊',
#      'push_ipdatetime': '04/05 21:39',
#      'push_tag': '推',
#      'push_userid': 'mdsgcjky'},
#     {'push_content': '過氣熊',
#      'push_ipdatetime': '04/05 21:40',
#      'push_tag': '推',
#      'push_userid': 'hawaii987'},
#     {'push_content': '還我小熊= =',
#      'push_ipdatetime': '04/05 21:43',
#      'push_tag': '推',
#      'push_userid': 'ttttttts'},
#     {'push_content': '還我小熊= =',
#      'push_ipdatetime': '04/05 21:48',
#      'push_tag': '推',
#      'push_userid': 'secret0409'},
#     {'push_content': '還我小熊= =',
#      'push_ipdatetime': '04/05 21:49',
#      'push_tag': '推',
#      'push_userid': 'webbkiller'},
#     {'push_content': '我熊威武',
#      'push_ipdatetime': '04/05 21:50',
#      'push_tag': '推',
#      'push_userid': 'hashbrownnn'},
#     {'push_content': '小胸',
#      'push_ipdatetime': '04/05 21:50',
#      'push_tag': '推',
#      'push_userid': 'lime1207'},
#     {'push_content': '熊起來',
#      'push_ipdatetime': '04/05 21:53',
#      'push_tag': '推',
#      'push_userid': 'ks007'},
#     {'push_content': '推',
#      'push_ipdatetime': '04/05 21:57',
#      'push_tag': '推',
#      'push_userid': 'ghj10625'},
#     {'push_content': '還我小熊= =',
#      'push_ipdatetime': '04/05 22:00',
#      'push_tag': '推',
#      'push_userid': 'LeafBlue'},
#     {'push_content': '超正買尬',
#      'push_ipdatetime': '04/05 22:01',
#      'push_tag': '→',
#      'push_userid': 'pukai'},
#     {'push_content': '推',
#      'push_ipdatetime': '04/05 22:01',
#      'push_tag': '推',
#      'push_userid': 'i81lisyol528'},
#     {'push_content': '老婆小熊好正啊 <3',
#      'push_ipdatetime': '04/05 22:01',
#      'push_tag': '推',
#      'push_userid': 'LoveDears'},
#     {'push_content': '我老婆 勿搶',
#      'push_ipdatetime': '04/05 22:04',
#      'push_tag': '推',
#      'push_userid': 'johnnyisyou'},
#     {'push_content': '有小熊有推',
#      'push_ipdatetime': '04/05 22:07',
#      'push_tag': '推',
#      'push_userid': 'Johnny51117'},
#     {'push_content': '\\⊙▽⊙/ 還我小熊 \\⊙▽⊙/',
#      'push_ipdatetime': '04/05 22:08',
#      'push_tag': '推',
#      'push_userid': 'Comebuy'},
#     {'push_content': '我老婆不要亂po',
#      'push_ipdatetime': '04/05 22:08',
#      'push_tag': '推',
#      'push_userid': 'shinink'},
#     {'push_content': '還我小熊= =',
#      'push_ipdatetime': '04/05 22:08',
#      'push_tag': '推',
#      'push_userid': 'a22224738'},
#     {'push_content': '小熊我老婆',
#      'push_ipdatetime': '04/05 22:11',
#      'push_tag': '推',
#      'push_userid': 'eric900311'},
#     {'push_content': '熊爺先推',
#      'push_ipdatetime': '04/05 22:23',
#      'push_tag': '推',
#      'push_userid': 'a24573165'},
#     {'push_content': '小熊推一個',
#      'push_ipdatetime': '04/05 22:26',
#      'push_tag': '推',
#      'push_userid': 'DENNISJHENG'},
#     {'push_content': '不錯',
#      'push_ipdatetime': '04/05 22:28',
#      'push_tag': '推',
#      'push_userid': 'kavalan1979'},
#     {'push_content': '好想當她的氧氣筒',
#      'push_ipdatetime': '04/05 22:29',
#      'push_tag': '推',
#      'push_userid': 'linniagy'},
#     {'push_content': '有熊就推',
#      'push_ipdatetime': '04/05 22:34',
#      'push_tag': '推',
#      'push_userid': 'zenuie'},
#     {'push_content': '\\⊙▽⊙/',
#      'push_ipdatetime': '04/05 22:40',
#      'push_tag': '推',
#      'push_userid': 'condition0'},
#     {'push_content': '推 我老婆',
#      'push_ipdatetime': '04/05 22:46',
#      'push_tag': '推',
#      'push_userid': 'diulelowmove'},
#     {'push_content': '推推',
#      'push_ipdatetime': '04/05 22:47',
#      'push_tag': '推',
#      'push_userid': 'littlesun543'},
#     {'push_content': '推推',
#      'push_ipdatetime': '04/05 22:50',
#      'push_tag': '推',
#      'push_userid': 'ing5623987'},
#     {'push_content': '我老婆不願上表特 請自刪 謝謝',
#      'push_ipdatetime': '04/05 22:55',
#      'push_tag': '推',
#      'push_userid': 'plokm1221'},
#     {'push_content': '推',
#      'push_ipdatetime': '04/05 23:04',
#      'push_tag': '推',
#      'push_userid': 'hsiao810512'},
#     {'push_content': '好正',
#      'push_ipdatetime': '04/05 23:04',
#      'push_tag': '推',
#      'push_userid': 'Oodoon13'},
#     {'push_content': '身材曲線真棒',
#      'push_ipdatetime': '04/05 23:05',
#      'push_tag': '→',
#      'push_userid': 'liaodon'},
#     {'push_content': '小熊推',
#      'push_ipdatetime': '04/05 23:12',
#      'push_tag': '推',
#      'push_userid': 'homepark'},
#     {'push_content': '誰?',
#      'push_ipdatetime': '04/05 23:23',
#      'push_tag': '噓',
#      'push_userid': 'Mryuan'},
#     {'push_content': '小胸',
#      'push_ipdatetime': '04/05 23:31',
#      'push_tag': '推',
#      'push_userid': 'g8429310'},
#     {'push_content': '黑熊',
#      'push_ipdatetime': '04/05 23:32',
#      'push_tag': '噓',
#      'push_userid': 'a5150593'},
#     {'push_content': '推',
#      'push_ipdatetime': '04/05 23:33',
#      'push_tag': '推',
#      'push_userid': 'lemon5043'},
#     {'push_content': '(′▽‵)ノ♪',
#      'push_ipdatetime': '04/05 23:35',
#      'push_tag': '推',
#      'push_userid': 'Teamo0209'},
#     {'push_content': '\\熊姐/',
#      'push_ipdatetime': '04/05 23:50',
#      'push_tag': '推',
#      'push_userid': 'funoway'},
#     {'push_content': '老婆來，我幫你CPR',
#      'push_ipdatetime': '04/05 23:55',
#      'push_tag': '→',
#      'push_userid': 'aa22456222'},
#     {'push_content': '推',
#      'push_ipdatetime': '04/06 00:02',
#      'push_tag': '推',
#      'push_userid': 'Luffy3428'},
#     {'push_content': '環我87小熊',
#      'push_ipdatetime': '04/06 00:02',
#      'push_tag': '推',
#      'push_userid': 'davidjay300'},
#     {'push_content': '小熊必推',
#      'push_ipdatetime': '04/06 00:03',
#      'push_tag': '推',
#      'push_userid': 'dctwo'},
#     {'push_content': 'https://www.instagram.com/yuniko0720/',
#      'push_ipdatetime': '04/06 00:05',
#      'push_tag': '推',
#      'push_userid': 'Twicejeff'},
#     {'push_content': '小熊只好推了~',
#      'push_ipdatetime': '04/06 00:23',
#      'push_tag': '推',
#      'push_userid': 'jonas736'},
#     {'push_content': '美翻了',
#      'push_ipdatetime': '04/06 00:24',
#      'push_tag': '推',
#      'push_userid': 'qredee224'},
#     {'push_content': '推啊~~',
#      'push_ipdatetime': '04/06 00:25',
#      'push_tag': '推',
#      'push_userid': 'tttggg'},
#     {'push_content': '小熊<3 是說，不知道她有沒有男朋友',
#      'push_ipdatetime': '04/06 00:28',
#      'push_tag': '推',
#      'push_userid': 'bryantchen'},
#     {'push_content': '樓上 沒有喔',
#      'push_ipdatetime': '04/06 00:34',
#      'push_tag': '推',
#      'push_userid': 'a24573165'},
#     {'push_content': '超普',
#      'push_ipdatetime': '04/06 00:35',
#      'push_tag': '噓',
#      'push_userid': 'lgsb1996x85'},
#     {'push_content': '宅宅最愛',
#      'push_ipdatetime': '04/06 00:40',
#      'push_tag': '噓',
#      'push_userid': 'Raskolnikov'},
#     {'push_content': '醜',
#      'push_ipdatetime': '04/06 00:44',
#      'push_tag': '→',
#      'push_userid': 'ENCOREH33456'},
#     {'push_content': '推推推',
#      'push_ipdatetime': '04/06 00:45',
#      'push_tag': '推',
#      'push_userid': 'ineedpeepee'},
#     {'push_content': '正',
#      'push_ipdatetime': '04/06 00:49',
#      'push_tag': '推',
#      'push_userid': 'johnny5414'},
#     {'push_content': '肛一個',
#      'push_ipdatetime': '04/06 00:55',
#      'push_tag': '推',
#      'push_userid': 'tfoxboy'},
#     {'push_content': '水喔!!!',
#      'push_ipdatetime': '04/06 01:04',
#      'push_tag': '推',
#      'push_userid': 'hsien918'},
#     {'push_content': '有熊出沒',
#      'push_ipdatetime': '04/06 01:05',
#      'push_tag': '推',
#      'push_userid': 'unimaybe'},
#     {'push_content': '推',
#      'push_ipdatetime': '04/06 01:07',
#      'push_tag': '推',
#      'push_userid': 'eric861007'},
#     {'push_content': '小熊推！！',
#      'push_ipdatetime': '04/06 01:10',
#      'push_tag': '推',
#      'push_userid': 'meowwwwwww'},
#     {'push_content': '最後一張 很漂亮',
#      'push_ipdatetime': '04/06 01:21',
#      'push_tag': '推',
#      'push_userid': 'aragakiwang'},
#     {'push_content': '正 推',
#      'push_ipdatetime': '04/06 01:27',
#      'push_tag': '推',
#      'push_userid': 'zhenglin'},
#     {'push_content': '小熊推',
#      'push_ipdatetime': '04/06 01:28',
#      'push_tag': '→',
#      'push_userid': 'yingrenhao'},
#     {'push_content': '熊姐',
#      'push_ipdatetime': '04/06 01:36',
#      'push_tag': '推',
#      'push_userid': 'InMemoria'},
#     {'push_content': '小熊很可愛呀～',
#      'push_ipdatetime': '04/06 01:36',
#      'push_tag': '推',
#      'push_userid': 'vivishe'},
#     {'push_content': '99',
#      'push_ipdatetime': '04/06 01:40',
#      'push_tag': '推',
#      'push_userid': 'rightmask'},
#     {'push_content': '我熊威武',
#      'push_ipdatetime': '04/06 01:44',
#      'push_tag': '推',
#      'push_userid': 'ether4615'},
#     {'push_content': '小熊～不推不行',
#      'push_ipdatetime': '04/06 01:51',
#      'push_tag': '推',
#      'push_userid': 'keliko'},
#     {'push_content': '還我小熊= =',
#      'push_ipdatetime': '04/06 01:55',
#      'push_tag': '→',
#      'push_userid': 'toby629a'},
#     {'push_content': '小熊世界冠軍',
#      'push_ipdatetime': '04/06 02:07',
#      'push_tag': '推',
#      'push_userid': 'ases60909'},
#     {'push_content': '推文好臭喔',
#      'push_ipdatetime': '04/06 02:15',
#      'push_tag': '噓',
#      'push_userid': 'edison9311'},
#     {'push_content': '小熊 <3',
#      'push_ipdatetime': '04/06 02:19',
#      'push_tag': '推',
#      'push_userid': 'blacksnow'},
#     {'push_content': '推',
#      'push_ipdatetime': '04/06 02:19',
#      'push_tag': '推',
#      'push_userid': 'chen0604z'},
#     {'push_content': '呃',
#      'push_ipdatetime': '04/06 02:31',
#      'push_tag': '噓',
#      'push_userid': 'babyMclaren'},
#     {'push_content': '幹超普   一堆肥宅的味',
#      'push_ipdatetime': '04/06 02:39',
#      'push_tag': '噓',
#      'push_userid': 'zxcc'},
#     {'push_content': '還你老婆哩   早就有男友肥宅洗洗睡吧',
#      'push_ipdatetime': '04/06 02:41',
#      'push_tag': '→',
#      'push_userid': 'zxcc'},
#     {'push_content': '小熊看這邊(=ﾟωﾟ)ﾉ♥',
#      'push_ipdatetime': '04/06 02:41',
#      'push_tag': '推',
#      'push_userid': 'charoro'},
#     {'push_content': '幹 就說沒男友',
#      'push_ipdatetime': '04/06 02:51',
#      'push_tag': '→',
#      'push_userid': 'a24573165'},
#     {'push_content': '有點像鄭爽',
#      'push_ipdatetime': '04/06 03:32',
#      'push_tag': '推',
#      'push_userid': 'yafx4200p'},
#     {'push_content': '小熊我愛你',
#      'push_ipdatetime': '04/06 04:37',
#      'push_tag': '推',
#      'push_userid': 'uio13659876'},
#     {'push_content': '要斂財的哪個會說有男友，用腦想也知道一堆在說謊',
#      'push_ipdatetime': '04/06 04:46',
#      'push_tag': '推',
#      'push_userid': 'PainTT'},
#     {'push_content': '不管有沒有男友都支持小熊',
#      'push_ipdatetime': '04/06 05:19',
#      'push_tag': '推',
#      'push_userid': 'forever05520'},
#     {'push_content': '是擅長用大腦的朋友呢～',
#      'push_ipdatetime': '04/06 06:36',
#      'push_tag': '推',
#      'push_userid': 'wjaxpig'},
#     {'push_content': '',
#      'push_ipdatetime': '04/06 07:02',
#      'push_tag': '噓',
#      'push_userid': 'live147222'},
#     {'push_content': '有熊必推',
#      'push_ipdatetime': '04/06 07:16',
#      'push_tag': '推',
#      'push_userid': 'abc57120'},
#     {'push_content': '正點',
#      'push_ipdatetime': '04/06 07:38',
#      'push_tag': '推',
#      'push_userid': 'dkna'},
#     {'push_content': 'adorable',
#      'push_ipdatetime': '04/06 08:00',
#      'push_tag': '推',
#      'push_userid': 'gohow'},
#     {'push_content': '熊起來！',
#      'push_ipdatetime': '04/06 08:00',
#      'push_tag': '推',
#      'push_userid': 'Scorpio777'},
#     {'push_content': '推熊姐',
#      'push_ipdatetime': '04/06 08:16',
#      'push_tag': '推',
#      'push_userid': 'snsd1223'},
#     {'push_content': '小胸就是要推~',
#      'push_ipdatetime': '04/06 08:38',
#      'push_tag': '推',
#      'push_userid': 'tk88769'},
#     {'push_content': '還我小熊= =',
#      'push_ipdatetime': '04/06 08:40',
#      'push_tag': '推',
#      'push_userid': 'jeff872984'},
#     {'push_content': '推',
#      'push_ipdatetime': '04/06 08:58',
#      'push_tag': '推',
#      'push_userid': 'aqeghkmb'},
#     {'push_content': '便當在哪??',
#      'push_ipdatetime': '04/06 09:06',
#      'push_tag': '→',
#      'push_userid': 'evilplayer'},
#     {'push_content': '我熊',
#      'push_ipdatetime': '04/06 09:10',
#      'push_tag': '推',
#      'push_userid': 'mk1166jimmy'},
#     {'push_content': '沒有比基尼……',
#      'push_ipdatetime': '04/06 09:12',
#      'push_tag': '推',
#      'push_userid': 'zxnstu3104'},
#     {'push_content': '小熊<33',
#      'push_ipdatetime': '04/06 09:15',
#      'push_tag': '推',
#      'push_userid': 'obaka870'},
#     {'push_content': '推熊',
#      'push_ipdatetime': '04/06 09:25',
#      'push_tag': '推',
#      'push_userid': 'cbstgb'},
#     {'push_content': '以為是另一隻熊...',
#      'push_ipdatetime': '04/06 09:38',
#      'push_tag': '噓',
#      'push_userid': 'ai719007'},
#     {'push_content': '想看潛水二號',
#      'push_ipdatetime': '04/06 09:43',
#      'push_tag': '噓',
#      'push_userid': 'yayagogo109'},
#     {'push_content': '沒露奶 沒誠意',
#      'push_ipdatetime': '04/06 10:05',
#      'push_tag': '噓',
#      'push_userid': 'StanQoo'},
#     {'push_content': '小胸我老婆',
#      'push_ipdatetime': '04/06 10:09',
#      'push_tag': '推',
#      'push_userid': 'zjes40604'},
#     {'push_content': '小熊推',
#      'push_ipdatetime': '04/06 10:17',
#      'push_tag': '推',
#      'push_userid': 'ken7788441'},
#     {'push_content': '正推',
#      'push_ipdatetime': '04/06 10:28',
#      'push_tag': '推',
#      'push_userid': 'sulin209'},
#     {'push_content': '(′・ω・`)kuma~',
#      'push_ipdatetime': '04/06 10:30',
#      'push_tag': '推',
#      'push_userid': 'blueskier'},
#     {'push_content': '卡哇伊',
#      'push_ipdatetime': '04/06 10:30',
#      'push_tag': '推',
#      'push_userid': 'aaaa8247'},
#     {'push_content': 'RRRRRRRRR好正哦',
#      'push_ipdatetime': '04/06 10:57',
#      'push_tag': '推',
#      'push_userid': 'MYCOWB'},
#     {'push_content': '有熊有推',
#      'push_ipdatetime': '04/06 11:20',
#      'push_tag': '推',
#      'push_userid': 'james641702'},
#     {'push_content': '好熊呀！',
#      'push_ipdatetime': '04/06 11:30',
#      'push_tag': '推',
#      'push_userid': 'icecream5008'},
#     {'push_content': '好氣質',
#      'push_ipdatetime': '04/06 11:49',
#      'push_tag': '推',
#      'push_userid': 'kggg'},
#     {'push_content': '過氣<3',
#      'push_ipdatetime': '04/06 11:49',
#      'push_tag': '推',
#      'push_userid': 'zzk2671'},
#     {'push_content': '推',
#      'push_ipdatetime': '04/06 11:59',
#      'push_tag': '推',
#      'push_userid': 'gshot140830'},
#     {'push_content': '還我小熊= =',
#      'push_ipdatetime': '04/06 12:44',
#      'push_tag': '推',
#      'push_userid': 'jefflien8'},
#     {'push_content': '熊',
#      'push_ipdatetime': '04/06 12:52',
#      'push_tag': '推',
#      'push_userid': 'sticky91626'},
#     {'push_content': '熊~~~',
#      'push_ipdatetime': '04/06 12:54',
#      'push_tag': '推',
#      'push_userid': 'icenivek'},
#     {'push_content': '正翻',
#      'push_ipdatetime': '04/06 12:56',
#      'push_tag': '推',
#      'push_userid': 'poi09832000'},
#     {'push_content': '啊',
#      'push_ipdatetime': '04/06 12:56',
#      'push_tag': '→',
#      'push_userid': 'kai6366'},
#     {'push_content': '反詐騙',
#      'push_ipdatetime': '04/06 12:57',
#      'push_tag': '噓',
#      'push_userid': 'help1268'},
#     {'push_content': '戴潛水衣還看的到奶真的猛',
#      'push_ipdatetime': '04/06 12:57',
#      'push_tag': '推',
#      'push_userid': 'njunju'},
#     {'push_content': '推',
#      'push_ipdatetime': '04/06 13:16',
#      'push_tag': '推',
#      'push_userid': 'gawgaw'},
#     {'push_content': '好鬆                                      的潛水衣',
#      'push_ipdatetime': '04/06 13:22',
#      'push_tag': '推',
#      'push_userid': 'xxxkoalala'},
#     {'push_content': '虎熊',
#      'push_ipdatetime': '04/06 13:28',
#      'push_tag': '→',
#      'push_userid': 'kennyop'},
#     {'push_content': '小熊推',
#      'push_ipdatetime': '04/06 14:02',
#      'push_tag': '推',
#      'push_userid': 'w10211'},
#     {'push_content': '平衡打擊',
#      'push_ipdatetime': '04/06 14:07',
#      'push_tag': '噓',
#      'push_userid': 'CmDawn'},
#     {'push_content': '推',
#      'push_ipdatetime': '04/06 14:22',
#      'push_tag': '推',
#      'push_userid': 'sun10814'},
#     {'push_content': '酸民撤退，小熊迷站粗乃',
#      'push_ipdatetime': '04/06 15:43',
#      'push_tag': '推',
#      'push_userid': 'zxnstu3104'},
#     {'push_content': '身材有曲線耶',
#      'push_ipdatetime': '04/06 16:26',
#      'push_tag': '推',
#      'push_userid': 'kipi91718'},
#     {'push_content': '有曲線有推 太神啦',
#      'push_ipdatetime': '04/06 16:29',
#      'push_tag': '推',
#      'push_userid': 'staynero8007'},
#     {'push_content': '小熊~~~~~~',
#      'push_ipdatetime': '04/06 16:34',
#      'push_tag': '推',
#      'push_userid': 'roger50409'},
#     {'push_content': '小熊～～',
#      'push_ipdatetime': '04/06 16:40',
#      'push_tag': '推',
#      'push_userid': 'ant0210'},
#     {'push_content': '????\\',
#      'push_ipdatetime': '04/06 20:10',
#      'push_tag': '噓',
#      'push_userid': 'e821017'},
#     {'push_content': '100推',
#      'push_ipdatetime': '04/06 20:23',
#      'push_tag': '推',
#      'push_userid': 'cliff880528'},
#     {'push_content': '我是個簡單的人',
#      'push_ipdatetime': '04/06 22:08',
#      'push_tag': '推',
#      'push_userid': 'zxp930110'},
#     {'push_content': '扯',
#      'push_ipdatetime': '04/06 22:42',
#      'push_tag': '噓',
#      'push_userid': 'fishfi'},
#     {'push_content': '推',
#      'push_ipdatetime': '04/06 23:35',
#      'push_tag': '推',
#      'push_userid': 'LoveloliLee'},
#     {'push_content': '要爆了',
#      'push_ipdatetime': '04/06 23:36',
#      'push_tag': '→',
#      'push_userid': 'LoveloliLee'},
#     {'push_content': '還我小熊',
#      'push_ipdatetime': '04/07 02:15',
#      'push_tag': '推',
#      'push_userid': 'pmmp'},
#     {'push_content': '直笛熊～現在變成含氧氣筒熊',
#      'push_ipdatetime': '04/07 03:33',
#      'push_tag': '→',
#      'push_userid': 'hupangpang'},
#     {'push_content': '讚讚讚',
#      'push_ipdatetime': '04/07 07:10',
#      'push_tag': '→',
#      'push_userid': 'Ikladi'},
#     {'push_content': '有小熊就推',
#      'push_ipdatetime': '04/07 10:39',
#      'push_tag': '推',
#      'push_userid': 'sorry555'},
#     {'push_content': 'BEAR 正 !!',
#      'push_ipdatetime': '04/07 18:29',
#      'push_tag': '推',
#      'push_userid': 'piging22'},
#     {'push_content': '推',
#      'push_ipdatetime': '04/07 19:23',
#      'push_tag': '推',
#      'push_userid': 'h587922000'},
#     {'push_content': '正',
#      'push_ipdatetime': '04/07 21:58',
#      'push_tag': '推',
#      'push_userid': 'peter5253'},
#     {'push_content': '推',
#      'push_ipdatetime': '04/08 00:22',
#      'push_tag': '推',
#      'push_userid': 'Wei880116'},
#     {'push_content': '聊天室 熊起來跔E跔E胬‧跔E胬‧跔E',
#      'push_ipdatetime': '04/08 01:05',
#      'push_tag': '→',
#      'push_userid': 'james0318tw'},
#     {'push_content': '有熊有推',
#      'push_ipdatetime': '04/08 12:07',
#      'push_tag': '推',
#      'push_userid': 'leslie121212'},
#     {'push_content': '臉歪嘴斜',
#      'push_ipdatetime': '04/08 18:39',
#      'push_tag': '推',
#      'push_userid': 'qqq3232'},
#     {'push_content': '我',
#      'push_ipdatetime': '04/08 20:39',
#      'push_tag': '推',
#      'push_userid': 'condition0'},
#     {'push_content': '推',
#      'push_ipdatetime': '04/09 23:43',
#      'push_tag': '推',
#      'push_userid': 'McBirdy03'},
#     {'push_content': '不要鬧了',
#      'push_ipdatetime': '04/10 18:55',
#      'push_tag': '噓',
#      'push_userid': 'lunqun35'},
#     {'push_content': '小熊必推',
#      'push_ipdatetime': '04/11 17:52',
#      'push_tag': '推',
#      'push_userid': 'chialeaf'},
#     {'push_content': '推',
#      'push_ipdatetime': '04/11 21:13',
#      'push_tag': '推',
#      'push_userid': 'TyrantTex'},
#     {'push_content': '老婆推',
#      'push_ipdatetime': '04/21 12:16',
#      'push_tag': '推',
#      'push_userid': 'a07504205'},
#     {'push_content': '推 噓的都只想看奶',
#      'push_ipdatetime': '04/23 02:16',
#      'push_tag': '推',
#      'push_userid': 'hong8593'}],
#    'url': 'https://www.ptt.cc/bbs/Beauty/M.1491391628.A.8C8.html'},
#   {'article_id': 'M.1491395882.A.530',
#    'article_title': '[正妹] Ebony Hunter 澳洲模特兒 178cm',
#    'author': 'Aotearoa (長白雲之鄉)',
#    'board': 'beauty',
#    'content': 'Ebony Hunter 澳洲模特兒 178公分 三圍：32 25 36 http://i.imgur.com/BD2iU3q.png http://i.imgur.com/iSK0SUV.jpg http://i.imgur.com/jEqFFSe.jpg http://i.imgur.com/VA6jrNA.jpg http://i.imgur.com/e2aIpKz.jpg http://i.imgur.com/S96GfEJ.jpg http://i.imgur.com/rdbvowM.jpg http://i.imgur.com/gM9jFqr.jpg http://i.imgur.com/sdzZq84.jpg http://i.imgur.com/T46wlP8.jpg http://i.imgur.com/e9OXn6f.jpg http://i.imgur.com/VyUIOnd.jpg http://i.imgur.com/wIb4qcV.jpg http://i.imgur.com/7Repdf3.jpg http://i.imgur.com/6wYwEBS.jpg http://i.imgur.com/B6TYMMY.jpg http://i.imgur.com/31VJiIx.jpg http://i.imgur.com/mCJFhaM.jpg http://i.imgur.com/NUSrdoW.jpg http://i.imgur.com/4eh2sby.jpg',
#    'date': 'Wed Apr  5 20:37:59 2017',
#    'ip': '122.100.82.143',
#    'message_conut': {'all': 12, 'boo': 0, 'count': 9, 'neutral': 3, 'push': 9},
#    'messages': [{'push_content': '沒想到澳洲也有老虎',
#      'push_ipdatetime': '04/05 20:48',
#      'push_tag': '推',
#      'push_userid': 'hitman0527'},
#     {'push_content': '今晚打老虎',
#      'push_ipdatetime': '04/05 20:50',
#      'push_tag': '推',
#      'push_userid': 'DamnKobe'},
#     {'push_content': 'Bice',
#      'push_ipdatetime': '04/05 21:00',
#      'push_tag': '推',
#      'push_userid': 'pussycat2009'},
#     {'push_content': 'Nice',
#      'push_ipdatetime': '04/05 21:01',
#      'push_tag': '→',
#      'push_userid': 'pussycat2009'},
#     {'push_content': 'T-T',
#      'push_ipdatetime': '04/05 22:17',
#      'push_tag': '推',
#      'push_userid': 'Refauth'},
#     {'push_content': '好可愛',
#      'push_ipdatetime': '04/05 22:22',
#      'push_tag': '推',
#      'push_userid': 'guenhwyvar'},
#     {'push_content': '這個屌',
#      'push_ipdatetime': '04/05 22:34',
#      'push_tag': '推',
#      'push_userid': 'xyzboom'},
#     {'push_content': '讚!',
#      'push_ipdatetime': '04/05 23:44',
#      'push_tag': '→',
#      'push_userid': 'LAUNFEI'},
#     {'push_content': '正翻',
#      'push_ipdatetime': '04/05 23:56',
#      'push_tag': '→',
#      'push_userid': 'kai6366'},
#     {'push_content': '快去了',
#      'push_ipdatetime': '04/06 20:55',
#      'push_tag': '推',
#      'push_userid': 'KlausaLiao'},
#     {'push_content': '超時尚的',
#      'push_ipdatetime': '04/08 02:29',
#      'push_tag': '推',
#      'push_userid': 'tf00417783'},
#     {'push_content': '好正',
#      'push_ipdatetime': '04/08 12:19',
#      'push_tag': '推',
#      'push_userid': 'kenny610'}],
#    'url': 'https://www.ptt.cc/bbs/Beauty/M.1491395882.A.530.html'},
#   {'article_id': 'M.1491396940.A.FBC',
#    'article_title': '[正妹] 清純可愛 ',
#    'author': 'teramars (tomorrow never knows)',
#    'board': 'beauty',
#    'content': 'http://i.imgur.com/9FNdvvx.jpg http://i.imgur.com/vSbiELz.jpg http://i.imgur.com/jhsPK1y.jpg http://i.imgur.com/lUbVHkG.jpg http://i.imgur.com/UtRGXT2.jpg',
#    'date': 'Wed Apr  5 20:55:37 2017',
#    'ip': '182.235.128.136',
#    'message_conut': {'all': 18,
#     'boo': 0,
#     'count': 12,
#     'neutral': 6,
#     'push': 12},
#    'messages': [{'push_content': '求認識',
#      'push_ipdatetime': '04/05 20:56',
#      'push_tag': '推',
#      'push_userid': 'DamnKobe'},
#     {'push_content': '好像看過',
#      'push_ipdatetime': '04/05 20:59',
#      'push_tag': '→',
#      'push_userid': 'noobismeok'},
#     {'push_content': '推！',
#      'push_ipdatetime': '04/05 21:14',
#      'push_tag': '推',
#      'push_userid': 'SeraphKJ'},
#     {'push_content': '優',
#      'push_ipdatetime': '04/05 21:22',
#      'push_tag': '推',
#      'push_userid': 'PUHU'},
#     {'push_content': '求門',
#      'push_ipdatetime': '04/05 21:23',
#      'push_tag': '推',
#      'push_userid': 'lck0'},
#     {'push_content': '美',
#      'push_ipdatetime': '04/05 21:35',
#      'push_tag': '推',
#      'push_userid': 'candy234'},
#     {'push_content': '我好想要那張電影海報...',
#      'push_ipdatetime': '04/05 22:12',
#      'push_tag': '推',
#      'push_userid': 'lockchad'},
#     {'push_content': '你又要刪文了對吧',
#      'push_ipdatetime': '04/05 22:30',
#      'push_tag': '→',
#      'push_userid': 'xyzboom'},
#     {'push_content': '我好想要那個快龍',
#      'push_ipdatetime': '04/05 22:30',
#      'push_tag': '推',
#      'push_userid': 'trtc'},
#     {'push_content': '不錯',
#      'push_ipdatetime': '04/05 23:04',
#      'push_tag': '推',
#      'push_userid': 'yoyonigo'},
#     {'push_content': '夾得到快龍不容易耶',
#      'push_ipdatetime': '04/05 23:41',
#      'push_tag': '→',
#      'push_userid': 'heechulsalan'},
#     {'push_content': 'Nice',
#      'push_ipdatetime': '04/06 03:11',
#      'push_tag': '推',
#      'push_userid': 'nojydia'},
#     {'push_content': '這個好',
#      'push_ipdatetime': '04/06 08:56',
#      'push_tag': '→',
#      'push_userid': 'tabrisPTT'},
#     {'push_content': '清純',
#      'push_ipdatetime': '04/06 11:00',
#      'push_tag': '推',
#      'push_userid': 'sulin209'},
#     {'push_content': '還好',
#      'push_ipdatetime': '04/06 11:13',
#      'push_tag': '→',
#      'push_userid': 'n61208'},
#     {'push_content': '滿Q',
#      'push_ipdatetime': '04/06 13:30',
#      'push_tag': '推',
#      'push_userid': 'kai6366'},
#     {'push_content': '想當那隻快龍',
#      'push_ipdatetime': '04/06 20:04',
#      'push_tag': '→',
#      'push_userid': 'bb1490tw'},
#     {'push_content': '不錯 臥蠶很大',
#      'push_ipdatetime': '04/10 12:27',
#      'push_tag': '推',
#      'push_userid': 'tte09567'}],
#    'url': 'https://www.ptt.cc/bbs/Beauty/M.1491396940.A.FBC.html'},
#   {'article_id': 'M.1491396979.A.F77',
#    'article_title': '[神人] 馬迷',
#    'author': "fafewen (C'est la vie)",
#    'board': 'beauty',
#    'content': '之前看電視 看到一個人在電視上大膽示愛 覺得他好漂亮 可以幫我神這個人嗎? 謝謝大家 http://imgur.com/a/eD0ys',
#    'date': 'Wed Apr  5 20:56:16 2017',
#    'ip': '123.193.160.176',
#    'message_conut': {'all': 11,
#     'boo': 9,
#     'count': -9,
#     'neutral': 2,
#     'push': 0},
#    'messages': [{'push_content': '樓下說說這是不是反串？',
#      'push_ipdatetime': '04/05 21:21',
#      'push_tag': '噓',
#      'push_userid': 'gin010275'},
#     {'push_content': '5f的最愛 每天都不停的想著她',
#      'push_ipdatetime': '04/05 21:26',
#      'push_tag': '噓',
#      'push_userid': 'mmiyamoto'},
#     {'push_content': '不能只有我看到',
#      'push_ipdatetime': '04/05 22:06',
#      'push_tag': '噓',
#      'push_userid': 'treerris'},
#     {'push_content': '樓下的夢中情人',
#      'push_ipdatetime': '04/05 22:21',
#      'push_tag': '噓',
#      'push_userid': 'jerryadsl'},
#     {'push_content': '幹',
#      'push_ipdatetime': '04/05 22:35',
#      'push_tag': '噓',
#      'push_userid': 'jor03twtw'},
#     {'push_content': '好險',
#      'push_ipdatetime': '04/05 23:12',
#      'push_tag': '噓',
#      'push_userid': 'owen1005'},
#     {'push_content': '！？',
#      'push_ipdatetime': '04/05 23:40',
#      'push_tag': '噓',
#      'push_userid': 'heechulsalan'},
#     {'push_content': '阿彌陀佛!',
#      'push_ipdatetime': '04/05 23:40',
#      'push_tag': '→',
#      'push_userid': 'com45676'},
#     {'push_content': '肉特快來取材啊',
#      'push_ipdatetime': '04/05 23:42',
#      'push_tag': '噓',
#      'push_userid': 'lester36'},
#     {'push_content': '挑戰每日一噓?',
#      'push_ipdatetime': '04/05 23:43',
#      'push_tag': '→',
#      'push_userid': 'LAUNFEI'},
#     {'push_content': '幫XX',
#      'push_ipdatetime': '04/05 23:52',
#      'push_tag': '噓',
#      'push_userid': 'bwpi'}],
#    'url': 'https://www.ptt.cc/bbs/Beauty/M.1491396979.A.F77.html'},
#   {'article_id': 'M.1491399355.A.C0B',
#    'article_title': '[正妹] 甜美鄰家女孩 第一五零彈',
#    'author': 'ogc60110 (老蝦)',
#    'board': 'beauty',
#    'content': 'http://i.imgur.com/0ydtQ7k.jpg http://i.imgur.com/ycy7U9R.jpg http://i.imgur.com/vKCNluG.jpg http://i.imgur.com/THNYwrX.jpg http://i.imgur.com/C5FSYsT.jpg http://i.imgur.com/HRtzWrA.jpg http://i.imgur.com/a4LduNo.jpg http://i.imgur.com/gpTt8ZL.jpg http://i.imgur.com/lbXj0NM.jpg http://i.imgur.com/bKTHSLC.jpg http://i.imgur.com/t9DpbCH.jpg http://i.imgur.com/WHb0LPY.jpg',
#    'date': 'Wed Apr  5 21:35:52 2017',
#    'ip': '111.184.73.153',
#    'message_conut': {'all': 37,
#     'boo': 1,
#     'count': 27,
#     'neutral': 8,
#     'push': 28},
#    'messages': [{'push_content': '超正 會爆',
#      'push_ipdatetime': '04/05 21:41',
#      'push_tag': '推',
#      'push_userid': 'fatoil27'},
#     {'push_content': '第十張的眼神也太美了！',
#      'push_ipdatetime': '04/05 21:48',
#      'push_tag': '推',
#      'push_userid': 'SeraphKJ'},
#     {'push_content': '推',
#      'push_ipdatetime': '04/05 21:51',
#      'push_tag': '推',
#      'push_userid': 'zx123520zx'},
#     {'push_content': 'push',
#      'push_ipdatetime': '04/05 21:54',
#      'push_tag': '推',
#      'push_userid': 'ishigakis'},
#     {'push_content': '推',
#      'push_ipdatetime': '04/05 22:04',
#      'push_tag': '推',
#      'push_userid': 'shin123000'},
#     {'push_content': '給分啦',
#      'push_ipdatetime': '04/05 22:07',
#      'push_tag': '→',
#      'push_userid': 'Halolo'},
#     {'push_content': '可以當老婆，面相幫夫的!',
#      'push_ipdatetime': '04/05 22:32',
#      'push_tag': '推',
#      'push_userid': 'com45676'},
#     {'push_content': '面相師怎麼看的',
#      'push_ipdatetime': '04/05 22:39',
#      'push_tag': '→',
#      'push_userid': 'javamcgee'},
#     {'push_content': '正',
#      'push_ipdatetime': '04/05 22:40',
#      'push_tag': '→',
#      'push_userid': 's90382'},
#     {'push_content': '不錯',
#      'push_ipdatetime': '04/05 23:03',
#      'push_tag': '推',
#      'push_userid': 'yoyonigo'},
#     {'push_content': '清流',
#      'push_ipdatetime': '04/05 23:32',
#      'push_tag': '推',
#      'push_userid': 'gra232327'},
#     {'push_content': '正。氣質甜美',
#      'push_ipdatetime': '04/05 23:34',
#      'push_tag': '推',
#      'push_userid': 'meloxxl'},
#     {'push_content': '過關!',
#      'push_ipdatetime': '04/05 23:42',
#      'push_tag': '→',
#      'push_userid': 'LAUNFEI'},
#     {'push_content': '接',
#      'push_ipdatetime': '04/06 01:51',
#      'push_tag': '→',
#      'push_userid': 'feejia4ni'},
#     {'push_content': '穴道按摩神人勒 跑哪去了',
#      'push_ipdatetime': '04/06 03:09',
#      'push_tag': '推',
#      'push_userid': 'PerFrancis'},
#     {'push_content': '耐看',
#      'push_ipdatetime': '04/06 07:21',
#      'push_tag': '推',
#      'push_userid': 'ansonlin0722'},
#     {'push_content': 'good',
#      'push_ipdatetime': '04/06 08:22',
#      'push_tag': '推',
#      'push_userid': 'morgen'},
#     {'push_content': '正',
#      'push_ipdatetime': '04/06 08:56',
#      'push_tag': '→',
#      'push_userid': 'tabrisPTT'},
#     {'push_content': '推',
#      'push_ipdatetime': '04/06 08:58',
#      'push_tag': '推',
#      'push_userid': 'starryice'},
#     {'push_content': '可愛',
#      'push_ipdatetime': '04/06 11:12',
#      'push_tag': '推',
#      'push_userid': 'n61208'},
#     {'push_content': '笑容很迷人',
#      'push_ipdatetime': '04/06 11:56',
#      'push_tag': '推',
#      'push_userid': 'sulin209'},
#     {'push_content': '好!',
#      'push_ipdatetime': '04/06 12:01',
#      'push_tag': '推',
#      'push_userid': 'eastereaster'},
#     {'push_content': '氣質 第十張女友視角',
#      'push_ipdatetime': '04/06 12:48',
#      'push_tag': '推',
#      'push_userid': 'yao09172001'},
#     {'push_content': '正翻啊啊啊啊啊啊啊啊啊啊',
#      'push_ipdatetime': '04/06 13:32',
#      'push_tag': '推',
#      'push_userid': 'kai6366'},
#     {'push_content': '正',
#      'push_ipdatetime': '04/06 14:22',
#      'push_tag': '推',
#      'push_userid': 'mars1396'},
#     {'push_content': '自然',
#      'push_ipdatetime': '04/06 15:58',
#      'push_tag': '推',
#      'push_userid': 'ppp11248'},
#     {'push_content': '這女孩看起來很棒',
#      'push_ipdatetime': '04/06 16:47',
#      'push_tag': '推',
#      'push_userid': 'egg79117'},
#     {'push_content': '這位的推未免太少了。',
#      'push_ipdatetime': '04/06 17:05',
#      'push_tag': '推',
#      'push_userid': 'rogergon'},
#     {'push_content': '完全可以',
#      'push_ipdatetime': '04/06 18:19',
#      'push_tag': '推',
#      'push_userid': 'morgan1011'},
#     {'push_content': '真的漂亮',
#      'push_ipdatetime': '04/06 19:09',
#      'push_tag': '推',
#      'push_userid': 'j123456669'},
#     {'push_content': '求門',
#      'push_ipdatetime': '04/06 19:40',
#      'push_tag': '推',
#      'push_userid': 'jaminchang'},
#     {'push_content': '最後一張 爆',
#      'push_ipdatetime': '04/06 20:06',
#      'push_tag': '推',
#      'push_userid': 'bb1490tw'},
#     {'push_content': '超正的',
#      'push_ipdatetime': '04/06 20:54',
#      'push_tag': '→',
#      'push_userid': 'KlausaLiao'},
#     {'push_content': '這女孩真的太漂亮了好有氣質',
#      'push_ipdatetime': '04/06 21:10',
#      'push_tag': '推',
#      'push_userid': 'cychung'},
#     {'push_content': 'luweexxi',
#      'push_ipdatetime': '04/06 23:02',
#      'push_tag': '推',
#      'push_userid': 'qaz1235567'},
#     {'push_content': '很美～',
#      'push_ipdatetime': '04/06 23:02',
#      'push_tag': '→',
#      'push_userid': 'qaz1235567'},
#     {'push_content': '不是護理師失敗',
#      'push_ipdatetime': '04/07 03:32',
#      'push_tag': '噓',
#      'push_userid': 'hupangpang'}],
#    'url': 'https://www.ptt.cc/bbs/Beauty/M.1491399355.A.C0B.html'},
#   {'article_id': 'M.1491399818.A.3C4',
#    'article_title': '[正妹] 好身材',
#    'author': 'Note5edge (諾特五欸舉)',
#    'board': 'beauty',
#    'content': 'http://i.imgur.com/qBejJvw.jpg http://i.imgur.com/nOlwrrt.jpg http://i.imgur.com/MnADVXp.jpg http://i.imgur.com/SZcSqj1.jpg',
#    'date': 'Wed Apr  5 21:43:36 2017',
#    'ip': '1.34.211.147',
#    'message_conut': {'all': 75,
#     'boo': 3,
#     'count': 55,
#     'neutral': 14,
#     'push': 58},
#    'messages': [{'push_content': '讚 我喜歡',
#      'push_ipdatetime': '04/05 21:44',
#      'push_tag': '推',
#      'push_userid': 'DamnKobe'},
#     {'push_content': 'push',
#      'push_ipdatetime': '04/05 21:45',
#      'push_tag': '推',
#      'push_userid': 'ishigakis'},
#     {'push_content': '大推！',
#      'push_ipdatetime': '04/05 21:47',
#      'push_tag': '推',
#      'push_userid': 'SeraphKJ'},
#     {'push_content': '可惜沒腰窩 但肉肉的不錯',
#      'push_ipdatetime': '04/05 21:49',
#      'push_tag': '推',
#      'push_userid': 'Coolno9'},
#     {'push_content': '修杰楷',
#      'push_ipdatetime': '04/05 21:51',
#      'push_tag': '→',
#      'push_userid': 'xyzboom'},
#     {'push_content': '讚，有門嗎？',
#      'push_ipdatetime': '04/05 21:53',
#      'push_tag': '推',
#      'push_userid': 'nanshinner'},
#     {'push_content': '很漂亮',
#      'push_ipdatetime': '04/05 21:55',
#      'push_tag': '推',
#      'push_userid': 'F0011010101'},
#     {'push_content': '大D小E，讚！！',
#      'push_ipdatetime': '04/05 21:56',
#      'push_tag': '推',
#      'push_userid': 'Jr0000'},
#     {'push_content': '推推求門',
#      'push_ipdatetime': '04/05 22:00',
#      'push_tag': '推',
#      'push_userid': 'jeff520'},
#     {'push_content': '太棒啦',
#      'push_ipdatetime': '04/05 22:05',
#      'push_tag': '→',
#      'push_userid': 'Halolo'},
#     {'push_content': '噢噢噢 很可以',
#      'push_ipdatetime': '04/05 22:06',
#      'push_tag': '推',
#      'push_userid': 'TheDivision'},
#     {'push_content': '嗷嗷嗷嗷嗷嗷',
#      'push_ipdatetime': '04/05 22:10',
#      'push_tag': '推',
#      'push_userid': 'ken9527k'},
#     {'push_content': 'http://instagram.com/li_wei_chang',
#      'push_ipdatetime': '04/05 22:21',
#      'push_tag': '推',
#      'push_userid': 'kobebrian24'},
#     {'push_content': '本人 IG 鎖住……',
#      'push_ipdatetime': '04/05 22:21',
#      'push_tag': '→',
#      'push_userid': 'sy267180'},
#     {'push_content': '已是人妻，這我國中同學',
#      'push_ipdatetime': '04/05 22:22',
#      'push_tag': '推',
#      'push_userid': 's87269x'},
#     {'push_content': '甜美 讚',
#      'push_ipdatetime': '04/05 22:24',
#      'push_tag': '推',
#      'push_userid': 'icq7584'},
#     {'push_content': '這個我虎了',
#      'push_ipdatetime': '04/05 22:29',
#      'push_tag': '推',
#      'push_userid': 'poplpp'},
#     {'push_content': '虎',
#      'push_ipdatetime': '04/05 22:33',
#      'push_tag': '推',
#      'push_userid': 'goodzoro'},
#     {'push_content': '啊嘶',
#      'push_ipdatetime': '04/05 22:37',
#      'push_tag': '推',
#      'push_userid': 'javamcgee'},
#     {'push_content': '學姊',
#      'push_ipdatetime': '04/05 22:39',
#      'push_tag': '推',
#      'push_userid': 's90382'},
#     {'push_content': '這叫肉肉的.. 是要逼死多少女生阿',
#      'push_ipdatetime': '04/05 22:40',
#      'push_tag': '推',
#      'push_userid': 'turtleman'},
#     {'push_content': '正',
#      'push_ipdatetime': '04/05 22:56',
#      'push_tag': '推',
#      'push_userid': 'rucwmj273b'},
#     {'push_content': '我媽叫喔娶她',
#      'push_ipdatetime': '04/05 22:58',
#      'push_tag': '推',
#      'push_userid': 'kent0925'},
#     {'push_content': '優!!!',
#      'push_ipdatetime': '04/05 23:00',
#      'push_tag': '推',
#      'push_userid': 'malaimo'},
#     {'push_content': '啊我忘記一件很重要的事情，她爸是警察當初就是所長了，',
#      'push_ipdatetime': '04/05 23:00',
#      'push_tag': '推',
#      'push_userid': 's87269x'},
#     {'push_content': '現在不知道退休沒，各位推文要多加注意',
#      'push_ipdatetime': '04/05 23:00',
#      'push_tag': '→',
#      'push_userid': 's87269x'},
#     {'push_content': '大姐姐的味道',
#      'push_ipdatetime': '04/05 23:00',
#      'push_tag': '推',
#      'push_userid': 'seethefuture'},
#     {'push_content': '我高中學弟25歲就在當所長啊',
#      'push_ipdatetime': '04/05 23:08',
#      'push_tag': '→',
#      'push_userid': 'DamnKobe'},
#     {'push_content': '推',
#      'push_ipdatetime': '04/05 23:14',
#      'push_tag': '推',
#      'push_userid': 'Michal1204'},
#     {'push_content': '好',
#      'push_ipdatetime': '04/05 23:16',
#      'push_tag': '推',
#      'push_userid': 'bbflisky'},
#     {'push_content': '這老公看起來超有錢',
#      'push_ipdatetime': '04/05 23:17',
#      'push_tag': '→',
#      'push_userid': 'bruce666'},
#     {'push_content': '我想上她    的IG',
#      'push_ipdatetime': '04/05 23:24',
#      'push_tag': '→',
#      'push_userid': 'x8x895246'},
#     {'push_content': '非常好',
#      'push_ipdatetime': '04/05 23:29',
#      'push_tag': '推',
#      'push_userid': 'RealGarden'},
#     {'push_content': '這身材必須推',
# ...
#     {'push_content': '難得欸 鵰妹WoW',
#      'push_ipdatetime': '04/06 01:55',
#      'push_tag': '→',
#      'push_userid': 'qscxz'},
#     {'push_content': '猛猛dar',
#      'push_ipdatetime': '04/06 03:00',
#      'push_tag': '推',
#      'push_userid': 'sy267180'},
#     {'push_content': '鄧紫棋的fu',
#      'push_ipdatetime': '04/06 04:08',
#      'push_tag': '推',
#      'push_userid': 'tim82123'},
#     {'push_content': '嗨',
#      'push_ipdatetime': '04/06 07:21',
#      'push_tag': '推',
#      'push_userid': 'INNNNNNNNNNN'},
#     {'push_content': '最後一張沒穿？',
#      'push_ipdatetime': '04/06 09:21',
#      'push_tag': '→',
#      'push_userid': 'morgen'},
#     {'push_content': '樓上雷射眼!?',
#      'push_ipdatetime': '04/06 11:05',
#      'push_tag': '→',
#      'push_userid': 'LAUNFEI'},
#     {'push_content': '求開門',
#      'push_ipdatetime': '04/06 11:23',
#      'push_tag': '→',
#      'push_userid': 'Paodynaomi'},
#     {'push_content': '這個好',
#      'push_ipdatetime': '04/06 14:07',
#      'push_tag': '推',
#      'push_userid': 'sulin209'},
#     {'push_content': '正',
#      'push_ipdatetime': '04/06 14:51',
#      'push_tag': '推',
#      'push_userid': 'tphua'},
#     {'push_content': '正',
#      'push_ipdatetime': '04/06 20:48',
#      'push_tag': '推',
#      'push_userid': 'KlausaLiao'}],
#    'url': 'https://www.ptt.cc/bbs/Beauty/M.1491414529.A.809.html'},
#   {'article_id': 'M.1491416306.A.596',
#    'article_title': '[正妹] 肉特(45)',
#    'author': 'LaurenceS (Laurence of Formosa)',
#    'board': 'beauty',
#    'content': '英國著名的女優、麻豆、兼電視主持人 Kelly Brook 以前上過花花公子，所以暗黑圖應該找得到可以自己估狗 http://i.imgur.com/KeUStDc.jpg http://i.imgur.com/UbtR3xh.jpg http://i.imgur.com/cI2WUBx.jpg http://images.enstarz.com/data/images/full/10795/kellybrook.jpg http://www.speakerscorner.me/wpcontent/uploads/2016/04/kelly17.jpg http://i.imgur.com/FpUw8Zt.jpg http://i.imgur.com/NvgJdD0.jpg http://i.imgur.com/ki1qM2I.jpg http://cdn.images.express.co.uk/img/dynamic/79/590x/secondary/203409.jpg http://i.imgur.com/29YUUrJ.jpg http://i.imgur.com/5ohVq5h.jpg https://www.youtube.com/watch?v=lXUGsQv7mRs 其中一個壓箱寶這麼快就要出來嗎??',
#    'date': 'Thu Apr  6 02:18:20 2017',
#    'ip': '172.98.150.6',
#    'message_conut': {'all': 17, 'boo': 4, 'count': 5, 'neutral': 4, 'push': 9},
#    'messages': [{'push_content': '......',
#      'push_ipdatetime': '04/06 03:16',
#      'push_tag': '噓',
#      'push_userid': 'htc10'},
#     {'push_content': '這年輕超辣的 歪果忍怎麼腫這麼快',
#      'push_ipdatetime': '04/06 06:36',
#      'push_tag': '推',
#      'push_userid': 'dan5120'},
#     {'push_content': '這我勉強可以',
#      'push_ipdatetime': '04/06 07:26',
#      'push_tag': '推',
#      'push_userid': 'bcharles'},
#     {'push_content': '年輕時超正',
#      'push_ipdatetime': '04/06 07:41',
#      'push_tag': '推',
#      'push_userid': 'AYLiu'},
#     {'push_content': '有一部電影荒島驚魂超辣',
#      'push_ipdatetime': '04/06 07:41',
#      'push_tag': '→',
#      'push_userid': 'AYLiu'},
#     {'push_content': '可以',
#      'push_ipdatetime': '04/06 08:45',
#      'push_tag': '推',
#      'push_userid': 'yan12487'},
#     {'push_content': '這………太澎風了吧……還我食人魚kelly',
#      'push_ipdatetime': '04/06 08:49',
#      'push_tag': '噓',
#      'push_userid': 'dutch14'},
#     {'push_content': '回不去了',
#      'push_ipdatetime': '04/06 08:53',
#      'push_tag': '推',
#      'push_userid': 'killer113'},
#     {'push_content': '現在體重是當時的兩倍',
#      'push_ipdatetime': '04/06 11:00',
#      'push_tag': '推',
#      'push_userid': 'n61208'},
#     {'push_content': '第二張凸',
#      'push_ipdatetime': '04/06 15:59',
#      'push_tag': '→',
#      'push_userid': 'SmartCoconut'},
#     {'push_content': '1',
#      'push_ipdatetime': '04/06 21:06',
#      'push_tag': '噓',
#      'push_userid': 'bh0925'},
#     {'push_content': '2',
#      'push_ipdatetime': '04/06 21:08',
#      'push_tag': '噓',
#      'push_userid': 'bh0925'},
#     {'push_content': 'Gal Gadot',
#      'push_ipdatetime': '04/07 08:46',
#      'push_tag': '→',
#      'push_userid': 'hupangpang'},
#     {'push_content': '版主！推一個非暗黑的凱特.丹寧絲',
#      'push_ipdatetime': '04/07 17:14',
#      'push_tag': '推',
#      'push_userid': 'yoyo740325'},
#     {'push_content': '胖好多',
#      'push_ipdatetime': '04/08 01:38',
#      'push_tag': '推',
#      'push_userid': 'LZCMAN'},
#     {'push_content': '這大概是肉特系列唯二有資格可稱表特的 不過現在腫很大',
#      'push_ipdatetime': '04/08 17:02',
#      'push_tag': '→',
#      'push_userid': 'pase139'},
#     {'push_content': '還是超讚 我很愛！！！！',
#      'push_ipdatetime': '04/14 18:35',
#      'push_tag': '推',
#      'push_userid': 'Eroica321'}],
#    'url': 'https://www.ptt.cc/bbs/Beauty/M.1491416306.A.596.html'},
#   {'article_id': 'M.1491416336.A.D98',
#    'article_title': '[神人] Youtube外國人頻道裡面的台灣女大生!',
#    'author': 'Enigma1997 (Enigma1997)',
#    'board': 'beauty',
#    'content': '半夜看輕鬆的影片 就看到一個很清純的妹子 影片中算是有透露資訊吧 小弟是三國大學的 單純好奇這是不是學姐 還有她的臉書或是ig http://i.imgur.com/mrYES9x.jpg http://i.imgur.com/NO2bECh.jpg 往回找文章，好像沒看到這篇欸@@ 有可能噢',
#    'date': 'Thu Apr  6 02:18:54 2017',
#    'ip': '27.52.194.90',
#    'message_conut': {'all': 7, 'boo': 0, 'count': 3, 'neutral': 4, 'push': 3},
#    'messages': [{'push_content': '叩了 20170401 [神人] 不要鬧工作室的台灣學生妹',
#      'push_ipdatetime': '04/06 04:21',
#      'push_tag': '推',
#      'push_userid': 'andy199113'},
#     {'push_content': 'brokendays說他認識',
#      'push_ipdatetime': '04/06 04:21',
#      'push_tag': '→',
#      'push_userid': 'andy199113'},
#     {'push_content': '好正',
#      'push_ipdatetime': '04/06 06:35',
#      'push_tag': '推',
#      'push_userid': 'a910012002'},
#     {'push_content': 'Nice',
#      'push_ipdatetime': '04/06 10:58',
#      'push_tag': '推',
#      'push_userid': 'n61208'},
#     {'push_content': '東吳？',
#      'push_ipdatetime': '04/06 11:22',
#      'push_tag': '→',
#      'push_userid': 'Paodynaomi'},
#     {'push_content': '不過這樣東吳東華東海都有可能…吧？',
#      'push_ipdatetime': '04/06 15:07',
#      'push_tag': '→',
#      'push_userid': 'leo60703'},
#     {'push_content': '東西南北中也有可能',
#      'push_ipdatetime': '04/06 16:58',
#      'push_tag': '→',
#      'push_userid': 'nemies'}],
#    'url': 'https://www.ptt.cc/bbs/Beauty/M.1491416336.A.D98.html'},
#   {'article_id': 'M.1491418475.A.319',
#    'article_title': '[神人] 漢神巨蛋B1櫃姐',
#    'author': 'bbcOG (bbc)',
#    'board': 'beauty',
#    'content': '本肥連假的時候 到漢神巨蛋B1新開的某個專櫃 看到仙女 右邊的就無視了哈 http://i.imgur.com/HJ9SCTQ.jpg http://i.imgur.com/YA36YZ5.jpg 如果冒犯請來信告知 ',
#    'date': 'Thu Apr  6 02:54:32 2017',
#    'ip': '101.12.241.108',
#    'message_conut': {'all': 11, 'boo': 3, 'count': 3, 'neutral': 2, 'push': 6},
#    'messages': [{'push_content': '胸前有名牌不看來這邊觀落陰(′･_･`)',
#      'push_ipdatetime': '04/06 03:19',
#      'push_tag': '→',
#      'push_userid': 'Kristoflower'},
#     {'push_content': '如果你問右邊那個，可能又要通知警察叔叔了',
#      'push_ipdatetime': '04/06 03:22',
#      'push_tag': '推',
#      'push_userid': 'LAUNFEI'},
#     {'push_content': '右邊不是50粗寬路嗎',
#      'push_ipdatetime': '04/06 03:24',
#      'push_tag': '推',
#      'push_userid': 'nemies'},
#     {'push_content': '這叫仙女，你當兵很久了厚',
#      'push_ipdatetime': '04/06 07:14',
#      'push_tag': '噓',
#      'push_userid': 'Tbeck'},
#     {'push_content': '觀',
#      'push_ipdatetime': '04/06 07:23',
#      'push_tag': '噓',
#      'push_userid': 'bmchaos'},
#     {'push_content': '我只覺得她手臂好細',
#      'push_ipdatetime': '04/06 07:59',
#      'push_tag': '推',
#      'push_userid': 'SeraphKJ'},
#     {'push_content': '凱爾你又PO文了',
#      'push_ipdatetime': '04/06 08:38',
#      'push_tag': '噓',
#      'push_userid': 'cashwool'},
#     {'push_content': '怎麼總是有人愛說當兵 仙女定義見仁見智',
#      'push_ipdatetime': '04/06 11:22',
#      'push_tag': '→',
#      'push_userid': 'Paodynaomi'},
#     {'push_content': '不錯',
#      'push_ipdatetime': '04/06 11:57',
#      'push_tag': '推',
#      'push_userid': 'wwe20425'},
#     {'push_content': '不錯',
#      'push_ipdatetime': '04/06 14:10',
#      'push_tag': '推',
#      'push_userid': 'sulin209'},
#     {'push_content': "蠻仙的 我喜翻('‧_‧`)",
#      'push_ipdatetime': '04/06 23:56',
#      'push_tag': '推',
#      'push_userid': 'jhangcc'}],
#    'url': 'https://www.ptt.cc/bbs/Beauty/M.1491418475.A.319.html'},
#   {'article_id': 'M.1491427487.A.A93',
#    'article_title': '[正妹] 吊嘎女生',
#    'author': 'milkboy1211 (牛奶妹)',
#    'board': 'beauty',
#    'content': 'http://i.imgur.com/zIYvMdE.jpg http://i.imgur.com/gG5bhyZ.jpg http://i.imgur.com/dOVK6je.jpg http://i.imgur.com/rNuTQsN.jpg http://i.imgur.com/0ivju35.jpg http://i.imgur.com/UGof8MJ.jpg http://i.imgur.com/8faCS2E.jpg http://i.imgur.com/FBCFLp3.jpg http://i.imgur.com/cFcYN0G.jpg http://i.imgur.com/uesXRRE.jpg http://i.imgur.com/vXboj6U.jpg http://i.imgur.com/a1OWUcC.jpg http://i.imgur.com/kivihMM.jpg http://i.imgur.com/aVxgYsI.jpg http://i.imgur.com/hP6LvWH.jpg',
#    'date': 'Thu Apr  6 05:24:45 2017',
#    'ip': '49.214.225.211',
#    'message_conut': {'all': 50,
#     'boo': 20,
#     'count': -3,
#     'neutral': 13,
#     'push': 17},
#    'messages': [{'push_content': '8',
#      'push_ipdatetime': '04/06 05:52',
#      'push_tag': '→',
#      'push_userid': 'sikadear'},
#     {'push_content': '+',
#      'push_ipdatetime': '04/06 05:52',
#      'push_tag': '噓',
#      'push_userid': 'GGrunrundela'},
#     {'push_content': '9',
#      'push_ipdatetime': '04/06 05:54',
#      'push_tag': '→',
#      'push_userid': 'asdasd4522'},
#     {'push_content': '=',
#      'push_ipdatetime': '04/06 05:59',
#      'push_tag': '→',
#      'push_userid': 'chihju'},
#     {'push_content': '1',
#      'push_ipdatetime': '04/06 06:04',
#      'push_tag': '噓',
#      'push_userid': 'GGrunrundela'},
#     {'push_content': '7',
#      'push_ipdatetime': '04/06 06:08',
#      'push_tag': '→',
#      'push_userid': 'and5566183'},
#     {'push_content': '2',
#      'push_ipdatetime': '04/06 06:13',
#      'push_tag': '噓',
#      'push_userid': 'kungfutofu'},
#     {'push_content': '手動置底',
#      'push_ipdatetime': '04/06 06:16',
#      'push_tag': '噓',
#      'push_userid': 'lovegogi'},
#     {'push_content': '推',
#      'push_ipdatetime': '04/06 06:53',
#      'push_tag': '推',
#      'push_userid': 'htc10'},
#     {'push_content': '是山西店迷克夏的店員，這是你本人吧！？',
#      'push_ipdatetime': '04/06 07:18',
#      'push_tag': '推',
#      'push_userid': 'rul543'},
#     {'push_content': '我要虎了',
#      'push_ipdatetime': '04/06 07:22',
#      'push_tag': '推',
#      'push_userid': 'bcharles'},
#     {'push_content': '8',
#      'push_ipdatetime': '04/06 07:26',
#      'push_tag': '噓',
#      'push_userid': 'Oodoon13'},
#     {'push_content': '９',
#      'push_ipdatetime': '04/06 07:27',
#      'push_tag': '→',
#      'push_userid': 'moonzone'},
#     {'push_content': '',
#      'push_ipdatetime': '04/06 07:36',
#      'push_tag': '噓',
#      'push_userid': 'Viagra'},
#     {'push_content': '8+9',
#      'push_ipdatetime': '04/06 07:55',
#      'push_tag': '噓',
#      'push_userid': 'atuatu'},
#     {'push_content': '嗯',
#      'push_ipdatetime': '04/06 08:06',
#      'push_tag': '→',
#      'push_userid': 'yoyonigo'},
#     {'push_content': '其實我覺得不差呀',
#      'push_ipdatetime': '04/06 08:53',
#      'push_tag': '推',
#      'push_userid': 'encorek01231'},
#     {'push_content': '傳送門欸 我要讓他每天騎虎難下',
#      'push_ipdatetime': '04/06 09:06',
#      'push_tag': '推',
#      'push_userid': 'sevenzgod'},
#     {'push_content': '還不錯',
#      'push_ipdatetime': '04/06 09:20',
#      'push_tag': '推',
#      'push_userid': 'morgen'},
#     {'push_content': '昨天說告白失敗PO上來，今天又再次PO上來，妳是本人',
#      'push_ipdatetime': '04/06 09:29',
#      'push_tag': '噓',
#      'push_userid': 'noobismeok'},
#     {'push_content': '還是根本是想陷害照片本人？',
#      'push_ipdatetime': '04/06 09:29',
#      'push_tag': '→',
#      'push_userid': 'noobismeok'},
#     {'push_content': '純粹分享好嗎==',
#      'push_ipdatetime': '04/06 10:12',
#      'push_tag': '→',
#      'push_userid': 'milkboy1211'},
#     {'push_content': '不到表特但可以當女友',
#      'push_ipdatetime': '04/06 10:35',
#      'push_tag': '推',
#      'push_userid': 'wangtenghong'},
#     {'push_content': '8+9 鍾愛款',
#      'push_ipdatetime': '04/06 11:04',
#      'push_tag': '推',
#      'push_userid': 'LAUNFEI'},
#     {'push_content': '17',
#      'push_ipdatetime': '04/06 11:21',
#      'push_tag': '推',
#      'push_userid': 'Paodynaomi'},
#     {'push_content': '的確是數字妹',
#      'push_ipdatetime': '04/06 11:23',
#      'push_tag': '→',
#      'push_userid': 'gebaho'},
#     {'push_content': '',
#      'push_ipdatetime': '04/06 11:25',
#      'push_tag': '噓',
#      'push_userid': 'OCG5566'},
#     {'push_content': '不錯啊 素顏清純耶',
#      'push_ipdatetime': '04/06 11:36',
#      'push_tag': '推',
#      'push_userid': 'bightb56913'},
#     {'push_content': '8+9',
#      'push_ipdatetime': '04/06 11:37',
#      'push_tag': '推',
#      'push_userid': 'k5a'},
#     {'push_content': '性感',
#      'push_ipdatetime': '04/06 11:40',
#      'push_tag': '推',
#      'push_userid': 'Eashamozen'},
#     {'push_content': '露成這樣給推',
#      'push_ipdatetime': '04/06 12:04',
#      'push_tag': '推',
#      'push_userid': 'aaQWE'},
#     {'push_content': '不錯啊 很愛露剛好給大家看（？',
#      'push_ipdatetime': '04/06 12:10',
#      'push_tag': '推',
#      'push_userid': 'jiahongqu'},
#     {'push_content': '噓成這樣',
#      'push_ipdatetime': '04/06 12:20',
#      'push_tag': '→',
#      'push_userid': 'LaurieWalker'},
#     {'push_content': '...',
#      'push_ipdatetime': '04/06 13:13',
#      'push_tag': '噓',
#      'push_userid': 'icq7584'},
#     {'push_content': '很大',
#      'push_ipdatetime': '04/06 13:19',
#      'push_tag': '→',
#      'push_userid': 'bsb0331'},
#     {'push_content': '好',
#      'push_ipdatetime': '04/06 13:27',
#      'push_tag': '推',
#      'push_userid': 'kai6366'},
#     {'push_content': 'good',
#      'push_ipdatetime': '04/06 13:32',
#      'push_tag': '推',
#      'push_userid': 'SantanaJohan'},
#     {'push_content': '不錯',
#      'push_ipdatetime': '04/06 14:20',
#      'push_tag': '推',
#      'push_userid': 'sulin209'},
#     {'push_content': '有些角度像陳怡蓉',
#      'push_ipdatetime': '04/06 14:36',
#      'push_tag': '→',
#      'push_userid': 'lightpisces'},
#     {'push_content': '忽大忽小',
#      'push_ipdatetime': '04/06 14:54',
#      'push_tag': '噓',
#      'push_userid': 'Ga1axyNote7'},
#     {'push_content': '眉毛好奇怪= =',
#      'push_ipdatetime': '04/06 15:17',
#      'push_tag': '噓',
#      'push_userid': 'cxz123'},
#     {'push_content': '形狀',
#      'push_ipdatetime': '04/06 15:58',
#      'push_tag': '噓',
#      'push_userid': 'SmartCoconut'},
#     {'push_content': '真 8+9',
#      'push_ipdatetime': '04/06 16:34',
#      'push_tag': '噓',
#      'push_userid': 'ElbertWiFi'},
#     {'push_content': '8到靠北',
#      'push_ipdatetime': '04/06 17:15',
#      'push_tag': '噓',
#      'push_userid': 'tsengchih'},
#     {'push_content': '多出門走走看看好嗎',
#      'push_ipdatetime': '04/06 17:46',
#      'push_tag': '噓',
#      'push_userid': 'VincentKung'},
#     {'push_content': '普，別再擠奶了',
#      'push_ipdatetime': '04/06 18:09',
#      'push_tag': '→',
#      'push_userid': 'belongings'},
#     {'push_content': '8+9',
#      'push_ipdatetime': '04/06 18:47',
#      'push_tag': '噓',
#      'push_userid': 'lversonYA'},
#     {'push_content': '到底',
#      'push_ipdatetime': '04/06 19:36',
#      'push_tag': '噓',
#      'push_userid': 'cozycaribou'},
#     {'push_content': '...',
#      'push_ipdatetime': '04/06 22:04',
#      'push_tag': '噓',
#      'push_userid': 'lobo200000'},
#     {'push_content': '',
#      'push_ipdatetime': '04/08 02:13',
#      'push_tag': '噓',
#      'push_userid': 'tf00417783'}],
#    'url': 'https://www.ptt.cc/bbs/Beauty/M.1491427487.A.A93.html'},
#   {'article_id': 'M.1491435318.A.780',
#    'article_title': '[正妹] 蘋果氣象新聞路邊正妹',
#    'author': 'charles0939 (希望)',
#    'board': 'beauty',
#    'content': 'http://i.imgur.com/KPu3t94.jpg 夏天FU今西半部可達32 下周轉有雨 即時新聞 20170406 蘋果日報 早晚偏涼、白天溫暖天氣型態將持續到周末，下周一起因鋒面將轉為有雨。中央氣象局預 報員李孟軒指出，今天白天各地的高溫都在26、27以上，西半部、南部甚至估達29至32 ，會有一些中高層雲系通過台灣，使得各地的雲量增多，提醒日夜溫差約10，外出多 帶件衣。今天至下周日天氣大致穩定，西半部及東南部的高溫有機會來到31至33，非常 有夏天的味道。下周一至下周三隨鋒面接近及影響，北部、東半部地區將轉為有短暫陣雨 的天氣，中南部山區有局部短暫陣雨，高溫隨之下降。 （陳亮諭綜合報導） http://www.appledaily.com.tw/realtimenews/article/life/20170406/1091875',
#    'date': 'Thu Apr  6 07:35:15 2017',
#    'ip': '126.244.130.21',
#    'message_conut': {'all': 3, 'boo': 2, 'count': -1, 'neutral': 0, 'push': 1},
#    'messages': [{'push_content': '陸客？',
#      'push_ipdatetime': '04/06 07:43',
#      'push_tag': '推',
#      'push_userid': 'giayaib'},
#     {'push_content': '',
#      'push_ipdatetime': '04/06 11:27',
#      'push_tag': '噓',
#      'push_userid': 'OCG5566'},
#     {'push_content': '別鬧',
#      'push_ipdatetime': '04/06 16:59',
#      'push_tag': '噓',
#      'push_userid': 'belongings'}],
#    'url': 'https://www.ptt.cc/bbs/Beauty/M.1491435318.A.780.html'}]}

# %%
# if not os.path.exists(directory):
#     os.makedirs(directory)
i=0
j=40
for con in content[40:len(content)]:
    text = con
    urls = re.findall('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', text)
    folder=title[j].split(' ')[1].replace("?","")
#     filename
    directory='Download/'+folder
    if not os.path.exists(directory):
        os.makedirs(directory)    
    print(folder)
    i=0
    for url in urls:
        if url.startswith('http://i.imgur') or url.startswith('http://imgur'):
            filename=str(title[j]+str(i))
            
            print(filename)
            downloader = ImgurDownloader(url,FOLDER,filename)
#             i=i+1
            print("down",url)
            i=i+1
            downloader.on_image_download(downloader.save_images(folder))
            
    j=j+1

# %%
print(filename+"_"+str(i)+"_"+str(j),url)
# Out:
# [神人] 電蚊香廣告的叛逆少女0_1_40 http://imgur.com/NkrOkBY

# %%
FROM=2340
INDEX=FROM
FOLDER="Download"
while(INDEX>2300):
    t=".\\beauty-"+str(INDEX)+"-"+str(INDEX)+".json"
    if not os.path.exists(t):
        t=get_articles(INDEX)
    contents,titles,article_id=get_contents(t)
    i=0
    for content in contents:
        if titles[i].startswith('[正妹]'):
            urls = re.findall('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', content)
            if len(titles[i].split(' '))>1:
                folder=titles[i].strip()
                for k in ":;?*:<>\/|<.":
                    folder=folder.replace(k,"")
            else:
                folder="正妹"+str(INDEX)+" "+str(i)
            directory=('Download/'+folder).strip()
            if not os.path.exists(directory):
                os.makedirs(directory)
            print("start article:",folder)
            j=0
            for url in urls:
                if url.startswith(('https://i.imgur','http://i.imgur','https://imgur','http://imgur')):# or url.startswith('http://imgur') or url.startswith('https://imgur') or url.startswith('http://i.imgur'):
                    filename=str(INDEX)+"_"+str(i)+"_"+str(j)
                    print("Processing image:",filename,url)
                    downloader = ImgurDownloader(url,FOLDER,filename)
                    if (not os.path.exists(directory+"/"+filename+".jpg")) and (not os.path.exists(directory+"/"+filename+".png")):
                         if os.path.exists(directory):
                            downloader.on_image_download(downloader.save_images(folder))
                            print("save",directory,filename)
                            j=j+1
        i=i+1
    INDEX=INDEX-1
    if INDEX!=FROM:
        os.remove(t)
# Out:
# ['M.1513252164.A.691', 'M.1513253550.A.21C', 'M.1513255883.A.B1A', 'M.1513263825.A.7BB']
# start article: [正妹] 2張
# Processing image: 2340_0_0 https://i.imgur.com/46osbvP.jpg
# Processing image: 2340_0_0 https://i.imgur.com/2eV5ubX.jpg
# start article: [正妹] ＝中山女高＝
# Processing image: 2340_2_0 https://i.imgur.com/OAYbAJv.jpg
# Processing image: 2340_2_0 https://i.imgur.com/oijSEtn.jpg
# Processing image: 2340_2_0 https://i.imgur.com/p7mxhBw.jpg
# Processing image: 2340_2_0 https://i.imgur.com/BI0267r.jpg
# Processing image: 2340_2_0 https://i.imgur.com/EYWYTyn.jpg
# Processing image: 2340_2_0 https://i.imgur.com/9AiKeme.jpg
# Processing image: 2340_2_0 https://i.imgur.com/xkIBtOu.jpg
# Processing image: 2340_2_0 https://i.imgur.com/XEJnVAf.jpg
# Processing image: 2340_2_0 https://i.imgur.com/zsUTXVj.jpg
# Processing image: 2340_2_0 https://i.imgur.com/v6KRxYb.jpg
# Processing image: 2340_2_0 https://i.imgur.com/uUbegal.jpg
# Processing image: 2340_2_0 https://i.imgur.com/gV9IUVg.jpg
# Processing image: 2340_2_0 https://i.imgur.com/sXsyjE1.jpg
# Processing image: 2340_2_0 https://i.imgur.com/vs5qHtq.jpg
# Processing image: 2340_2_0 https://i.imgur.com/B6eQS94.jpg
# Processing image: 2340_2_0 https://i.imgur.com/74Ct4LM.jpg
# Processing image: 2340_2_0 https://i.imgur.com/s1uFbHj.jpg
# Processing image: 2340_2_0 https://i.imgur.com/hd5Fpuq.jpg
# Processing image: 2340_2_0 https://i.imgur.com/zValBLD.jpg
# Processing image: 2340_2_0 https://i.imgur.com/8sMUSgG.jpg
# Processing image: 2340_2_0 https://i.imgur.com/erG2t4u.jpg
# Processing image: 2340_2_0 https://i.imgur.com/JX1RTeq.jpg
# Processing image: 2340_2_0 https://i.imgur.com/1DkFi8N.jpg
# start article: [正妹] 這樣好嗎
# Processing image: 2340_3_0 https://i.imgur.com/QhYUTDA.jpg
# Processing image: 2340_3_0 https://i.imgur.com/mUZLMyq.jpg
# Processing image: 2340_3_0 https://i.imgur.com/X5D0GZS.jpg
# Processing image: 2340_3_0 https://i.imgur.com/tWRLtoq.jpg
# Processing image: 2340_3_0 https://i.imgur.com/2n2vJyh.jpg
# Processing image: 2340_3_0 https://i.imgur.com/sjLciYM.jpg
# Processing image: 2340_3_0 https://i.imgur.com/fYLinOS.jpg
# Processing image: 2340_3_0 https://i.imgur.com/9B23GSQ.jpg
# start article: [正妹] 拍賣網站看到的
# start article: [正妹] 笑容不錯的女孩
# Processing image: 2340_7_0 https://imgur.com/h5DXLxE.jpg
# Processing image: 2340_7_0 https://imgur.com/spE5TQh.jpg
# Processing image: 2340_7_0 https://imgur.com/QKwfQQL.jpg
# Processing image: 2340_7_0 https://imgur.com/UQoR0uG.jpg
# Processing image: 2340_7_0 https://imgur.com/tckg4jM.jpg
# Processing image: 2340_7_0 https://imgur.com/cXL5YKm.jpg
# Processing image: 2340_7_0 https://imgur.com/OM1PbFZ.jpg
# Processing image: 2340_7_0 https://imgur.com/1dfW523.jpg
# start article: [正妹] 上上禮拜天的玩具槍展 SHOW GIRL
# start article: [正妹] 道重沙由美
# Processing image: 2340_10_0 https://i.imgur.com/C0iTIoI.jpg
# Processing image: 2340_10_0 https://i.imgur.com/i74MKFN.jpg
# Processing image: 2340_10_0 https://i.imgur.com/Aamymba.jpg
# Processing image: 2340_10_0 https://i.imgur.com/Bo0kpXZ.jpg
# Processing image: 2340_10_0 https://i.imgur.com/eY3URWO.jpg
# Processing image: 2340_10_0 https://i.imgur.com/UEbsLr9.jpg
# Processing image: 2340_10_0 https://i.imgur.com/q0fEyY0.jpg
# Processing image: 2340_10_0 https://i.imgur.com/DtTGCBY.jpg
# Processing image: 2340_10_0 https://i.imgur.com/sJmRm34.jpg
# Processing image: 2340_10_0 https://i.imgur.com/5J8CW28.jpg
# start article: [正妹] 超美人卓君澤專訪
# Processing image: 2340_11_0 https://i.imgur.com/BUwHU4r.jpg
# start article: [正妹] 花蓮高農
# Processing image: 2340_12_0 https://i.imgur.com/01ayH5k.jpg
# Processing image: 2340_12_0 https://i.imgur.com/JnlBzC7.jpg
# Processing image: 2340_12_0 https://i.imgur.com/b8VLSuj.jpg
# Processing image: 2340_12_0 https://i.imgur.com/Y31y2vv.jpg
# Processing image: 2340_12_0 https://i.imgur.com/njaT0Hy.jpg
# Processing image: 2340_12_0 https://i.imgur.com/uwQaxbE.jpg
# Processing image: 2340_12_0 https://i.imgur.com/nr0RZSS.jpg
# Processing image: 2340_12_0 https://i.imgur.com/4YViTNK.jpg
# Processing image: 2340_12_0 https://i.imgur.com/sEXXs4s.jpg
# Processing image: 2340_12_0 https://i.imgur.com/i411zeA.jpg
# Processing image: 2340_12_0 https://i.imgur.com/6FnX4Rp.jpg
# Processing image: 2340_12_0 https://i.imgur.com/RjDpAsb.jpg
# Processing image: 2340_12_0 https://i.imgur.com/OarYVJH.jpg
# Processing image: 2340_12_0 https://i.imgur.com/hmkJKFL.jpg
# Processing image: 2340_12_0 https://i.imgur.com/lUDkKOW.jpg
# Processing image: 2340_12_0 https://i.imgur.com/REyxcVZ.jpg
# Processing image: 2340_12_0 https://i.imgur.com/BM9KrOd.jpg
# Processing image: 2340_12_0 https://i.imgur.com/kMmVtpF.jpg
# Processing image: 2340_12_0 https://i.imgur.com/e8pr0Gh.jpg
# Processing image: 2340_12_0 https://i.imgur.com/CyuSG2w.jpg
# Processing image: 2340_12_0 https://i.imgur.com/XoVlNed.jpg
# Processing image: 2340_12_0 https://i.imgur.com/rKuLpu7.jpg
# Processing image: 2340_12_0 https://i.imgur.com/wG5y5tg.jpg
# Processing image: 2340_12_0 https://i.imgur.com/958zGMe.jpg
# start article: [正妹] 淡淡
# Processing image: 2340_13_0 https://i.imgur.com/KoOLOj8.jpg
# Processing image: 2340_13_0 https://i.imgur.com/qki4XOY.jpg
# Processing image: 2340_13_0 https://i.imgur.com/avQAbBS.jpg
# Processing image: 2340_13_0 https://i.imgur.com/FGMycYE.jpg
# Processing image: 2340_13_0 https://i.imgur.com/Gyojfhf.jpg
# Processing image: 2340_13_0 https://i.imgur.com/jL24qA6.jpg
# Processing image: 2340_13_0 https://i.imgur.com/dPip9oN.jpg
# Processing image: 2340_13_0 https://i.imgur.com/bMHFyhi.jpg
# Processing image: 2340_13_0 https://i.imgur.com/M3Uzoho.jpg
# Processing image: 2340_13_0 https://i.imgur.com/hhy1mgp.jpg
# Processing image: 2340_13_0 https://i.imgur.com/oZxqlGW.jpg
# Processing image: 2340_13_0 https://i.imgur.com/8WFT4nm.jpg
# Processing image: 2340_13_0 https://i.imgur.com/Z35FVRy.jpg
# start article: [正妹] 眼鏡妹壞脾氣
# Processing image: 2340_14_0 https://i.imgur.com/uAR8UZ3.jpg
# Processing image: 2340_14_0 https://i.imgur.com/bwQQlY7.jpg
# Processing image: 2340_14_0 https://i.imgur.com/43oIikt.jpg
# Processing image: 2340_14_0 https://i.imgur.com/S9JkE56.jpg
# Processing image: 2340_14_0 https://i.imgur.com/fi82kXp.jpg
# Processing image: 2340_14_0 https://i.imgur.com/7BRcjkS.jpg
# Processing image: 2340_14_0 https://i.imgur.com/JWXcPnz.jpg
# Processing image: 2340_14_0 https://i.imgur.com/kAXlFO0.jpg
# start article: [正妹] 橋本環奈。常に全盛期
# Processing image: 2340_15_0 https://i.imgur.com/pRGtDbJ.jpg
# Processing image: 2340_15_0 https://i.imgur.com/38i2JUz.jpg
# Processing image: 2340_15_0 https://i.imgur.com/PN0k06z.jpg
# Processing image: 2340_15_0 https://i.imgur.com/4xuIKJb.jpg
# Processing image: 2340_15_0 https://i.imgur.com/HAMm1df.jpg
# Processing image: 2340_15_0 https://i.imgur.com/NXNPX3B.jpg
# Processing image: 2340_15_0 https://i.imgur.com/yLmSi8Y.jpg
# ['M.1513171107.A.76D', 'M.1513185981.A.437', 'M.1513210248.A.D37', 'M.1513211160.A.46E']
# start article: [正妹] 清純姊妹
# Processing image: 2339_0_0 https://i.imgur.com/mUZiZ2G.jpg
# Processing image: 2339_0_0 https://i.imgur.com/QHqVfbR.jpg
# Processing image: 2339_0_0 https://i.imgur.com/Ygotzp8.jpg
# Processing image: 2339_0_0 https://i.imgur.com/0Y2RKiL.jpg
# Processing image: 2339_0_0 https://i.imgur.com/Nr84W7f.jpg
# Processing image: 2339_0_0 https://i.imgur.com/bWYX7Lw.jpg
# Processing image: 2339_0_0 https://i.imgur.com/BcfUURf.jpg
# Processing image: 2339_0_0 https://i.imgur.com/9Vnj2iW.jpg
# Processing image: 2339_0_0 https://i.imgur.com/EtBUq0d.jpg
# Processing image: 2339_0_0 https://i.imgur.com/01tIBeX.jpg
# Processing image: 2339_0_0 https://i.imgur.com/0BhDWz6.jpg
# Processing image: 2339_0_0 https://i.imgur.com/7Rijg3S.jpg
# start article: [正妹] 餐飲女孩
# Processing image: 2339_1_0 https://i.imgur.com/5ZZlcj6.jpg
# Processing image: 2339_1_0 https://i.imgur.com/RKMFwq9.jpg
# Processing image: 2339_1_0 https://i.imgur.com/AF0LL9D.jpg
# start article: [正妹] 厭世眼神的清秀女孩
# Processing image: 2339_2_0 https://i.imgur.com/ZWAFbw9.jpg
# Processing image: 2339_2_0 https://i.imgur.com/UOIMOH5.jpg
# Processing image: 2339_2_0 https://i.imgur.com/CMFWjCJ.jpg
# Processing image: 2339_2_0 https://i.imgur.com/34XnVpS.jpg
# Processing image: 2339_2_0 https://i.imgur.com/zlDi0q2.jpg
# Processing image: 2339_2_0 https://i.imgur.com/yh9u7Wx.jpg
# Processing image: 2339_2_0 https://i.imgur.com/Wjjk7yU.jpg
# Processing image: 2339_2_0 https://i.imgur.com/uQ82ep0.jpg
# Processing image: 2339_2_0 https://i.imgur.com/6o263o5.jpg
# Processing image: 2339_2_0 https://i.imgur.com/RO0S6w4.jpg
# Processing image: 2339_2_0 https://i.imgur.com/mesy1Y1.jpg
# Processing image: 2339_2_0 https://i.imgur.com/RnGgqCk.jpg
# Processing image: 2339_2_0 https://i.imgur.com/SnXS5vY.jpg
# Processing image: 2339_2_0 https://i.imgur.com/krBPsbU.jpg
# Processing image: 2339_2_0 https://i.imgur.com/rn1g1Ux.jpg
# start article: [正妹] 蔡依珊
# Processing image: 2339_4_0 https://i.imgur.com/fCEHHgp.jpg
# Processing image: 2339_4_0 https://i.imgur.com/PqCE68x.jpg
# start article: [正妹] 三國手遊廣告大小喬
# Processing image: 2339_5_0 https://i.imgur.com/RwcSaF4.jpg
# Processing image: 2339_5_0 https://i.imgur.com/87Ml5lF.jpg
# Processing image: 2339_5_0 https://i.imgur.com/7L4r5FK.jpg
# start article: [正妹] 有點虎牙
# Processing image: 2339_6_0 https://i.imgur.com/hTQlPhG.jpg
# Processing image: 2339_6_0 https://i.imgur.com/NorFpe7.jpg
# Processing image: 2339_6_0 https://i.imgur.com/81VyjJF.jpg
# Processing image: 2339_6_0 https://i.imgur.com/TB4J4r8.jpg
# Processing image: 2339_6_0 https://i.imgur.com/PZplvv7.jpg
# Processing image: 2339_6_0 https://i.imgur.com/xSfLMlK.jpg
# Processing image: 2339_6_0 https://i.imgur.com/WKofkEA.jpg
# start article: [正妹] 啦啦隊朋友
# Processing image: 2339_7_0 https://i.imgur.com/Td72XhP.jpg
# save Download/[正妹] 啦啦隊朋友 2339_7_0
# Processing image: 2339_7_1 https://i.imgur.com/8W0U7HH.jpg
# save Download/[正妹] 啦啦隊朋友 2339_7_1
# Processing image: 2339_7_2 https://i.imgur.com/qJlFyLL.jpg
# save Download/[正妹] 啦啦隊朋友 2339_7_2
# Processing image: 2339_7_3 https://i.imgur.com/4UxsTBR.jpg
# save Download/[正妹] 啦啦隊朋友 2339_7_3
# Processing image: 2339_7_4 https://i.imgur.com/38XA3BO.jpg
# save Download/[正妹] 啦啦隊朋友 2339_7_4
# Processing image: 2339_7_5 https://i.imgur.com/mM0E0Nb.jpg
# save Download/[正妹] 啦啦隊朋友 2339_7_5
# Processing image: 2339_7_6 https://i.imgur.com/ow3JUci.jpg
# save Download/[正妹] 啦啦隊朋友 2339_7_6
# Processing image: 2339_7_7 https://i.imgur.com/PyA34vl.jpg
# save Download/[正妹] 啦啦隊朋友 2339_7_7
# Processing image: 2339_7_8 https://i.imgur.com/kIpMxvd.jpg
# save Download/[正妹] 啦啦隊朋友 2339_7_8
# Processing image: 2339_7_9 https://i.imgur.com/gRVOiBe.jpg
# save Download/[正妹] 啦啦隊朋友 2339_7_9
# Processing image: 2339_7_10 https://i.imgur.com/Ai2EhHr.jpg
# save Download/[正妹] 啦啦隊朋友 2339_7_10
# Processing image: 2339_7_11 https://i.imgur.com/jWL6o0V.jpg
# save Download/[正妹] 啦啦隊朋友 2339_7_11
# Processing image: 2339_7_12 https://i.imgur.com/IWjCRJ4.jpg
# save Download/[正妹] 啦啦隊朋友 2339_7_12
# Processing image: 2339_7_13 https://i.imgur.com/swIA7F2.jpg
# save Download/[正妹] 啦啦隊朋友 2339_7_13
# Processing image: 2339_7_14 https://i.imgur.com/2aUs0Sn.jpg
# save Download/[正妹] 啦啦隊朋友 2339_7_14
# Processing image: 2339_7_15 https://i.imgur.com/ZDq4qYF.jpg
# save Download/[正妹] 啦啦隊朋友 2339_7_15
# Processing image: 2339_7_16 https://i.imgur.com/IPKOe2g.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-bddcc7a914e6> in <module>()
#      40                     if (not os.path.exists(directory+"/"+filename+".jpg")) and (not os.path.exists(directory+"/"+filename+".png")):
#      41                          if os.path.exists(directory):
# ---> 42                             downloader.on_image_download(downloader.save_images(folder))
#      43                             print("save",directory,filename)
#      44                             j=j+1
#
# ~\evan\Learning\python\ptt_beauty\env\src\imgurdownloader.py in save_images(self, foldername)
#     332                 os.path.join(
#     333                     os.path.dirname(path),
# --> 334                     slugify(os.path.basename(path))))
#     335
#     336             downloaded += dl
#
# ~\evan\Learning\python\ptt_beauty\env\src\imgurdownloader.py in direct_download(self, image_url, path)
#     389
#     390                 # proceed with downloading
# --> 391                 urllib.request.urlretrieve(image_url, path)
#     392                 dl = 1
#     393             except (HTTPError, FileExistsError):
#
# c:\program files\python35\Lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     186     url_type, path = splittype(url)
#     187
# --> 188     with contextlib.closing(urlopen(url, data)) as fp:
#     189         headers = fp.info()
#     190
#
# c:\program files\python35\Lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     161     else:
#     162         opener = _opener
# --> 163     return opener.open(url, data, timeout)
#     164
#     165 def install_opener(opener):
#
# c:\program files\python35\Lib\urllib\request.py in open(self, fullurl, data, timeout)
#     464             req = meth(req)
#     465
# --> 466         response = self._open(req, data)
#     467
#     468         # post-process response
#
# c:\program files\python35\Lib\urllib\request.py in _open(self, req, data)
#     482         protocol = req.type
#     483         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 484                                   '_open', req)
#     485         if result:
#     486             return result
#
# c:\program files\python35\Lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     442         for handler in handlers:
#     443             func = getattr(handler, meth_name)
# --> 444             result = func(*args)
#     445             if result is not None:
#     446                 return result
#
# c:\program files\python35\Lib\urllib\request.py in http_open(self, req)
#    1280
#    1281     def http_open(self, req):
# -> 1282         return self.do_open(http.client.HTTPConnection, req)
#    1283
#    1284     http_request = AbstractHTTPHandler.do_request_
#
# c:\program files\python35\Lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1255             except OSError as err: # timeout error
#    1256                 raise URLError(err)
# -> 1257             r = h.getresponse()
#    1258         except:
#    1259             h.close()
#
# c:\program files\python35\Lib\http\client.py in getresponse(self)
#    1196         try:
#    1197             try:
# -> 1198                 response.begin()
#    1199             except ConnectionError:
#    1200                 self.close()
#
# c:\program files\python35\Lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# c:\program files\python35\Lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# c:\program files\python35\Lib\socket.py in readinto(self, b)
#     574         while True:
#     575             try:
# --> 576                 return self._sock.recv_into(b)
#     577             except timeout:
#     578                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
def get_articles(index):
    c = PttWebCrawler(as_lib=True)
    t=c.parse_articles(index,index, 'beauty')
    return (t)

# %%
def get_contents(t):
    with open(t, 'r',encoding = 'utf8') as f:
        data=json.load(f)
    contents=[]
    titles=[]
    article_id=[]
    for article in data['articles']:
        contents.append(article['content'])
        titles.append(article['article_title'])
        article_id.append(article['article_id'])
    print(article_id[1:5])
    return(contents,titles,article_id)

# %%
def get_urls(contents,titles):
    i=0
    for content in contents:
        if titles[i].startswith('[正妹]'):
            urls = re.findall('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', content)
    return(urls)

# %%
# !jupyter nbconvert --to script PttBeautyDownload_organize_folder.ipynb
# Out:
# [NbConvertApp] Converting notebook PttBeautyDownload_organize_folder.ipynb to script
# [NbConvertApp] Writing 4094 bytes to PttBeautyDownload_organize_folder.py
